# %%
import pandas as pd
import ast
from tqdm import tqdm

tqdm.pandas()
df = pd.read_csv('bond_docs.csv')
df['tagged'] = df['tagged'].progress_apply(ast.literal_eval)
# Out:
# 100%|██████████| 5367/5367 [00:47<00:00, 113.36it/s]

# %%
import pandas as pd
import ast
from tqdm import tqdm

tqdm.pandas()
df = pd.read_csv('economy_docs.csv')
df['tagged'] = df['tagged'].progress_apply(ast.literal_eval)
# Out:
# 100%|██████████| 7962/7962 [01:10<00:00, 112.30it/s]

# %%
# tagged 컬럼 삭제 버전
from collections import Counter
from tqdm import tqdm

def generate_ngrams(token_list, max_n=5):
    words = [token[0] for token in token_list]
    ngram_counter = Counter()
    for n in range(1, max_n + 1):
        ngrams = [tuple(words[i:i+n]) for i in range(len(words) - n + 1)]
        ngram_counter.update(ngrams)
    return ngram_counter

def sorted_ngrams(token_list, max_n=5):
    counter = generate_ngrams(token_list, max_n)
    sorted_ngrams = sorted(counter.items(), key=lambda x: x[1], reverse=True)
    return str(sorted_ngrams)

tqdm.pandas()
# 각 행별로 n-그램 결과를 'ngram' 컬럼에 추가
df['ngram'] = df['tagged'].progress_apply(lambda x: sorted_ngrams(x, max_n=5))
df[['date', 'ngram']].to_csv('ngram_bond_results.csv', index=False)
# Out:
# 100%|██████████| 5367/5367 [00:19<00:00, 281.57it/s]

# %%
# tagged 컬럼 미삭제 버전
from collections import Counter
from tqdm import tqdm

def generate_ngrams(token_list, max_n=5):

    words = [token[0] for token in token_list]
    ngram_counter = Counter()
    for n in range(1, max_n + 1):
        ngrams = [tuple(words[i:i+n]) for i in range(len(words) - n + 1)]
        ngram_counter.update(ngrams)
    return ngram_counter

def sorted_ngrams(token_list, max_n=5):
    counter = generate_ngrams(token_list, max_n)
    sorted_ngrams = sorted(counter.items(), key=lambda x: x[1], reverse=True)
    return str(sorted_ngrams)

tqdm.pandas()
# 각 행별로 n-그램 결과를 'ngram' 컬럼에 추가
df['ngram'] = df['tagged'].progress_apply(lambda x: sorted_ngrams(x, max_n=5))

df.to_csv('ngram_economy_results.csv', index=False)
# Out:
# 100%|██████████| 7962/7962 [00:29<00:00, 271.03it/s]

# %%
pd.read_csv('ngram_bond_results.csv')['ngram'][0]
# Out:
# "[(('금리',), 13), (('투자',), 10), (('회사',), 10), (('크레딧',), 7), (('롯데그룹',), 6), (('롯데케미칼',), 6), (('제공',), 6), (('신한',), 6), (('증권',), 6), (('신한', '투자'), 6), (('투자', '증권'), 6), (('신한', '투자', '증권'), 6), (('유동성',), 5), (('유효',), 5), (('회사채',), 5), (('축',), 5), (('상기',), 5), (('상기', '회사'), 5), (('추가',), 4), (('인하',), 4), (('금통위',), 4), (('사채',), 4), (('관련',), 4), (('은행',), 4), (('제시',), 4), (('판단',), 4), (('의견',), 4), (('국내',), 3), (('기대',), 3), (('우려',), 3), (('약세',), 3), (('거래',), 3), (('예금',), 3), (('대비',), 3), (('공사',), 3), (('주식',), 3), (('조사',), 3), (('분석',), 3), (('국내', '크레딧'), 3), (('롯데그룹', '유동성'), 3), (('금리', '축'), 3), (('조사', '분석'), 3), (('중심',), 2), (('이슈',), 2), (('일단락',), 2), (('시장',), 2), (('부각',), 2), (('하락',), 2), (('국채',), 2), (('했으며',), 2), (('속',), 2), (('신용스프레드',), 2), (('유지',), 2), (('스프레드',), 2), (('폭',), 2), (('확대',), 2), (('반',), 2), (('발생',), 2), (('채권',), 2), (('강세',), 2), (('재무비율',), 2), (('내용',), 2), (('사채권자',), 2), (('집회',), 2), (('소집',), 2), (('언론',), 2), (('보증',), 2), (('그룹',), 2), (('현금',), 2), (('포함',), 2), (('가용',), 2), (('자금',), 2), (('규모',), 2), (('보유',), 2), (('자산',), 2), (('남',), 2), (('압력',), 2), (('높',), 2), (('캐리',), 2), (('회복',), 2), (('매수',), 2), (('정혜진',), 2), (('자산시장',), 2), (('섹터별',), 2), (('추이',), 2), (('캐피탈',), 2), (('우축',), 2), (('순차입',), 2), (('EBITDA',), 2), (('정확',), 2), (('반영',), 2), (('없이',), 2), (('본',), 2), (('참고',), 2), (('발행',), 2), (('상',), 2), (('담당자',), 2), (('어떠',), 2), (('목적',), 2), (('투자자',), 2), (('배포',), 2), (('이슈', '일단락'), 2), (('추가', '인하'), 2), (('인하', '기대'), 2), (('유효', '금통위'), 2), (('금리', '하락'), 2), (('국채', '금리'), 2), (('유동성', '우려'), 2), (('롯데그룹', '채권'), 2), (('채권', '약세'), 2), (('약세', '거래'), 2), (('롯데케미칼', '재무비율'), 2), (('사채권자', '집회'), 2), (('집회', '소집'), 2), (('은행', '보증'), 2), (('현금', '예금'), 2), (('금리', '대비'), 2), (('자산시장', '국내'), 2), (('증권', '신한'), 2), (('회사', '제시'), 2), (('제시', '신한'), 2), (('공사', '은행'), 2), (('은행', '캐피탈'), 2), (('캐피탈', '회사'), 2), (('의견', '정확'), 2), (('정확', '반영'), 2), (('회사', '발행'), 2), (('발행', '주식'), 2), (('분석', '담당자'), 2), (('추가', '인하', '기대'), 2), (('롯데그룹', '채권', '약세'), 2), (('채권', '약세', '거래'), 2), (('사채권자', '집회', '소집'), 2), (('자산시장', '국내', '크레딧'), 2), (('투자', '증권', '신한'), 2), (('증권', '신한', '투자'), 2), (('회사', '제시', '신한'), 2), (('제시', '신한', '투자'), 2), (('공사', '은행', '캐피탈'), 2), (('은행', '캐피탈', '회사'), 2), (('의견', '정확', '반영'), 2), (('상기', '회사', '발행'), 2), (('회사', '발행', '주식'), 2), (('조사', '분석', '담당자'), 2), (('롯데그룹', '채권', '약세', '거래'), 2), (('신한', '투자', '증권', '신한'), 2), (('투자', '증권', '신한', '투자'), 2), (('증권', '신한', '투자', '증권'), 2), (('회사', '제시', '신한', '투자'), 2), (('제시', '신한', '투자', '증권'), 2), (('공사', '은행', '캐피탈', '회사'), 2), (('상기', '회사', '발행', '주식'), 2), (('신한', '투자', '증권', '신한', '투자'), 2), (('투자', '증권', '신한', '투자', '증권'), 2), (('회사', '제시', '신한', '투자', '증권'), 2), (('위험',), 1), (('이익',), 1), (('사이',), 1), (('무게',), 1), (('방향',), 1), (('잡',), 1), (('못하',), 1), (('박스권',), 1), (('등락',), 1), (('확산',), 1), (('급락',), 1), (('졌',), 1), (('트럼프',), 1), (('당선',), 1), (('후성',), 1), (('장',), 1), (('둔화',), 1), (('견인',), 1), (('마감',), 1), (('변동성',), 1), (('보합권',), 1), (('기준',), 1), (('동일등급',), 1), (('갭',), 1), (('좁혀져',), 1), (('급여',), 1), (('전채',), 1), (('기한이익상실',), 1), (('사유',), 1), (('으',), 1), (('역시',), 1), (('제약',), 1), (('요인',), 1), (('작용',), 1), (('관리',), 1), (('담당',), 1), (('기관',), 1), (('한국예탁결제원',), 1), (('위반',), 1), (('공고',), 1), (('예정',), 1), (('발표',), 1), (('공시',), 1), (('조항',), 1), (('삭제',), 1), (('롯데월드',), 1), (('타워',), 1), (('담보',), 1), (('받',), 1), (('안건',), 1), (('수수료',), 1), (('보도',), 1), (('통하',), 1), (('합산',), 1), (('밝히',), 1), (('전체',), 1), (('부동산',), 1), (('유사시',), 1), (('일축',), 1), (('노이즈',), 1), (('존재',), 1), (('연말',), 1), (('북클로징',), 1), (('유입',), 1), (('강도',), 1), (('약화',), 1), (('롤오버',), 1), (('차',), 1), (('PF',), 1), (('사업',), 1), (('평가',), 1), (('결과',), 1), (('CP',), 1), (('등급',), 1), (('정평',), 1), (('앞두',), 1), (('경계',), 1), (('특히',), 1), (('민평',), 1), (('초',), 1), (('매력',), 1), (('내년',), 1), (('점진적',), 1), (('접근',), 1), (('연속',), 1), ((' ...

# %%
pd.read_csv('ngram_economy_results.csv')['ngram'][0]
# Out:
# "[(('미국',), 59), (('대신증권',), 32), (('제조업',), 23), (('경기',), 18), (('지수',), 18), (('PMI',), 18), (('한국',), 14), (('소비',), 14), (('유로존',), 14), (('중국',), 13), (('PCEPI',), 13), (('지속',), 12), (('수출',), 11), (('상승',), 11), (('생산',), 11), (('상승률',), 11), (('일본',), 11), (('SP',), 10), (('독일',), 9), (('PMI', '미국'), 9), (('대신증권', '대신증권'), 9), (('서비스업',), 8), (('수요',), 8), (('증가',), 8), (('신규',), 8), (('스프레드',), 8), (('제조업', '경기'), 8), (('감소',), 7), (('했으나',), 7), (('기업',), 7), (('고용',), 7), (('파악',), 7), (('국내',), 7), (('기준',), 7), (('금리',), 7), (('물가',), 7), (('개인',), 7), (('주요국',), 7), (('기대',), 6), (('임금',), 6), (('둔화',), 6), (('확대',), 6), (('양호',), 6), (('흐름',), 6), (('우려',), 6), (('종합',), 6), (('서비스',), 6), (('CB',), 6), (('소비자',), 6), (('소득',), 6), (('측',), 6), (('비교',), 6), (('요인',), 6), (('판매',), 6), (('회의',), 6), (('임금', '상승률'), 6), (('제조업', 'PMI'), 6), (('ISM',), 5), (('크',), 5), (('증가율',), 5), (('판단',), 5), (('가운데',), 5), (('매크로',), 5), (('실업률',), 5), (('관련',), 5), (('압력',), 5), (('지출',), 5), (('국채',), 5), (('장단기스프레드',), 5), (('통화',), 5), (('산업',), 5), (('국내', '수출'), 5), (('서비스업', 'PMI'), 5), (('국채', '금리'), 5), (('금리', '장단기스프레드'), 5), (('미국', '신규'), 5), (('산업', '생산'), 5), (('개선',), 4), (('필요',), 4), (('연말',), 4), (('특히',), 4), (('수출입',), 4), (('무역',), 4), (('하락',), 4), (('어렵',), 4), (('신뢰지수',), 4), (('근원',), 4), (('차트',), 4), (('공급',), 4), (('성과',), 4), (('종가',), 4), (('위안',), 4), (('미국', '제조업'), 4), (('제조업', '생산'), 4), (('미국', 'ISM'), 4), (('CB', '소비자'), 4), (('소비자', '신뢰지수'), 4), (('소비', '지출'), 4), (('개인', '소득'), 4), (('PCEPI', '상승률'), 4), (('공급', '측'), 4), (('측', '요인'), 4), (('성과', '비교'), 4), (('대신증권', '종가'), 4), (('종가', '기준'), 4), (('판매', '미국'), 4), (('서비스업', 'PMI', '미국'), 4), (('대신증권', '종가', '기준'), 4), (('국채', '금리', '장단기스프레드'), 4), (('대선',), 3), (('차기',), 3), (('정부',), 3), (('정책',), 3), (('내년',), 3), (('긍정적',), 3), (('주목',), 3), (('일부',), 3), (('모습',), 3), (('전환',), 3), (('완화',), 3), (('시차',), 3), (('이벤트',), 3), (('건수',), 3), (('비농업',), 3), (('주요',), 3), (('최저',), 3), (('신뢰',), 3), (('경제',), 3), (('심리',), 3), (('소폭',), 3), (('내구재',), 3), (('재화',), 3), (('환율',), 3), (('유로',), 3), (('실업보험',), 3), (('청구자',), 3), (('소매',), 3), (('투자',), 3), (('주택',), 3), (('작성',), 3), (('경기', '상승'), 3), (('미국', '소비'), 3), (('연말', '소비'), 3), (('비농업', '신규'), 3), (('신규', '고용'), 3), (('종합', '지수'), 3), (('흐름', '지속'), 3), (('소비', '심리'), 3), (('PCEPI', '근원'), 3), (('근원', 'PCEPI'), 3), (('한국', '미국'), 3), (('신규', '실업보험'), 3), (('실업보험', '청구자'), 3), (('소매', '판매'), 3), (('회의', '미국'), 3), (('미국', '제조업', '경기'), 3), (('제조업', '경기', '상승'), 3), (('제조업', 'PMI', '미국'), 3), (('비농업', '신규', '고용'), 3), (('CB', '소비자', '신뢰지수'), 3), (('PCEPI', '근원', 'PCEPI'), 3), (('미국', '신규', '실업보험'), 3), (('신규', '실업보험', '청구자'), 3), (('미국', '신규', '실업보험', '청구자'), 3), (('불확실성',), 2), (('해소',), 2), (('뉴욕',), 2), (('포함',), 2), (('확장',), 2), (('추세',), 2), (('친화',), 2), (('발표',), 2), (('결과',), 2), (('사이클',), 2), (('트럼프',), 2), (('앞두',), 2), (('뒷받침',), 2), (('유입',), 2), (('PCE',), 2), (('여력',), 2), (('견',), 2), (('저조',), 2), (('으',), 2), (('금',), 2), (('주원',), 2), (('일자',), 2), (('국가',), 2), (('전치',), 2), (('차이신',), 2), (('비제조업',), 2), (('겪',), 2), (('설명',), 2), (('활동',), 2), (('빠르',), 2), (('산출량',), 2), (('간',), 2), (('불안',), 2), (('견조',), 2), (('인플레이션',), 2), (('언급',), 2), (('감안',), 2), (('전월',), 2), (('폭',), 2), (('평가',), 2), (('낙관',), 2), (('했으며',), 2), (('구매',), 2), (('높',), 2), (('사항',), 2), (('대비',), 2), (('금융',), 2), (('보험',), 2), (('글로벌',), 2), (('Fed',), 2), (('구분',), 2), (('SP500',), 2), (('코스피',), 2), (('msci',), 2), (('MSCI',), 2), (('독',), 2), (('달러인덱스',), 2), (('엔달러',), 2), (('신흥국',), 2), (('루피',), 2), (('원화',), 2), (('액',), 2), (('경상수지',), 2), (('도매',), 2), (('재고',), 2), (('영국',), 2), (('금융투자',), 2), (('분석',), 2), (('동',), 2), (('정확',), 2), (('대선', '불확실성'), 2), (('불확실성', '해소'), 2), (('지수', '상승'), 2), (('생산', '감소'), 2), (('감소', '추세'), 2), (('지속', '했으나'), 2), (('차기', '정부'), 2), (('기업', '친화'), 2), (('친화', '정책'), 2), (('서비스업', '임금'), 2), (('상승률', '둔화'), 2), (('둔화', '제조업'), 2), ...
