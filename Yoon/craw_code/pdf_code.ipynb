# %%
import requests
from bs4 import BeautifulSoup
import pdfplumber
from io import BytesIO
import time

# 기본 URL 설정
base_url = "https://finance.naver.com/research/debenture_list.naver?searchType=keyword&keyword=%B1%DD%B8%AE&brokerCode=&writeFromDate=&writeToDate=&x=0&y=0"
total_pages = 10  # 총 페이지 수

# PDF 링크와 데이터를 저장할 딕셔너리
research_data = {}
pdf_links = []

# 1. 페이지 크롤링
for page in range(1, total_pages + 1):
    url = f"{base_url}&page={page}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 모든 tr 태그 가져오기
    rows = soup.find_all('tr')
    
    # td class="file" 안의 a 태그에서 PDF 링크 추출 및 정보 매핑
    file_tds = soup.find_all('td', class_='file')
    for i, td in enumerate(file_tds):
        # PDF 링크 추출
        pdf_link = td.find('a')['href']
        
        # 같은 행에서 제목과 날짜 추출 (i+1은 헤더 행을 건너뛰기 위함)
        if i + 1 < len(rows):
            row = rows[i + 1]
            
            # 제목 추출: <a href="debenture_read.naver?...">제목</a>
            title_elem = row.find('a')  # href가 debenture_read.naver로 시작하는 링크
            title = title_elem.text.strip() if title_elem else f"Unknown_{i}"
            
            # 날짜 추출: <td class="date">25.02.20</td>
            date_elem = row.find('td', class_='date')
            date = date_elem.text.strip() if date_elem else "Unknown"
        else:
            title = f"Unknown_{i}"
            date = "Unknown"
        
        pdf_links.append((pdf_link, title, date))
    
    print(f"페이지 {page} 크롤링 완료, 현재 {len(pdf_links)}개의 PDF 링크 수집")
    time.sleep(1)

# 2. PDF에서 텍스트 추출 및 딕셔너리에 저장
for idx, (pdf_url, title, date) in enumerate(pdf_links, 1):
    try:
        # PDF 스트리밍 다운로드
        pdf_response = requests.get(pdf_url, stream=True, timeout=10)
        pdf_file = BytesIO(pdf_response.content)
        
        # pdfplumber로 텍스트 추출
        with pdfplumber.open(pdf_file) as pdf:
            contents = ""
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    contents += page_text
        
        # PDF 파일명에서 확장자 제거한 제목 추출
        pdf_title = pdf_url.split('/')[-1].replace('.pdf', '')
        
        # 딕셔너리에 저장
        research_data[title] = {
            'title': pdf_title,    # PDF 파일명에서 추출한 제목
            'contents': contents,  # PDF 내용
            'date': date          # 페이지에서 추출한 날짜
        }
        
        print(f"{idx}/{len(pdf_links)}: {title} 처리 완료")
    
    except Exception as e:
        print(f"{idx}/{len(pdf_links)}: {pdf_url} 처리 실패 - 오류: {e}")
    
    time.sleep(1)

print("모든 작업 완료!")
print(f"총 {len(research_data)}개의 리서치 데이터가 딕셔너리에 저장되었습니다.")

# 결과 예시 출력 (선택사항)
for title, data in list(research_data.items())[:3]:  # 처음 3개만 출력
    print(f"\nTitle (from page): {title}")
    print(f"PDF Title: {data['title']}")
    print(f"Date: {data['date']}")
    print(f"Contents preview: {data['contents'][:100]}...")
# Out:
# 페이지 1 크롤링 완료, 현재 30개의 PDF 링크 수집
# 페이지 2 크롤링 완료, 현재 60개의 PDF 링크 수집
# 페이지 3 크롤링 완료, 현재 90개의 PDF 링크 수집
# 페이지 4 크롤링 완료, 현재 120개의 PDF 링크 수집
# 페이지 5 크롤링 완료, 현재 150개의 PDF 링크 수집
# 페이지 6 크롤링 완료, 현재 180개의 PDF 링크 수집
# 페이지 7 크롤링 완료, 현재 210개의 PDF 링크 수집
# 페이지 8 크롤링 완료, 현재 240개의 PDF 링크 수집
# 페이지 9 크롤링 완료, 현재 270개의 PDF 링크 수집
# 페이지 10 크롤링 완료, 현재 300개의 PDF 링크 수집
# 1/300: Unknown_0 처리 완료
# 2/300: 1분기 10년 하단 4.20% 처리 완료
# 3/300: 미국채 10년물 금리 하락을 견인한 텀프리미엄 처리 완료
# 4/300: [2월 금통위 Review] 확장재정이 Key 처리 완료
# 5/300: Daily Bond Morning Brief(2025.02.26) 처리 완료
# 6/300: Eugenes FICC Update 처리 완료
# 7/300: Unknown_6 처리 완료
# 8/300: Unknown_7 처리 완료
# 9/300: Unknown_8 처리 완료
# 10/300: 2월 금통위 리뷰: 통화정책과 재정정책 공조 필요 처리 완료
# 11/300: [IBKS Bond Inside] 2025년 2월 금통위 리뷰 처리 완료
# 12/300: 2월 금통위; 정책 공조의 시간 처리 완료
# 13/300: 2월 금통위 Review: 비둘기와 매를 모두, 최종금리 2... 처리 완료
# 14/300: [금통위 리뷰] 최소 1.5% 처리 완료
# 15/300: Unknown_14 처리 완료
# 16/300: Unknown_15 처리 완료
# 17/300: Unknown_16 처리 완료
# 18/300: 2월 금통위: 핵심 지표는 여전히 추가 금리인하를 지.. 처리 완료
# 19/300: 2월 금통위: 금리 인하 더 한다. 국고 금리 뉴레인지 .. 처리 완료
# 20/300: Daily Bond Morning Brief(2025.02.25) 처리 완료
# 21/300: Eugenes FICC Update 처리 완료
# 22/300: 브라질, 연초 효과 지속 여부, 재정에 달렸다 처리 완료
# 23/300: Unknown_22 처리 완료
# 24/300: Unknown_23 처리 완료
# 25/300: Unknown_24 처리 완료
# 26/300: 채권 Daily (02.24) 처리 완료
# 27/300: [FI Weekly] 금통위 Preview: 만장일치 인하 처리 완료
# 28/300: Daily Bond Morning Brief(2025.02.24) 처리 완료
# 29/300: Eugenes FICC Update 처리 완료
# 30/300: 02/24 Kiwoom Fixed Income Weekly Review 처리 완료
# 31/300: Unknown_0 처리 완료
# 32/300: 2월 금통위 Preview: 최종금리 2.25%가 되려면 처리 완료
# 33/300: 채권 Daily (02.19) 처리 완료
# 34/300: Daily Bond Morning Brief(2025.02.19) 처리 완료
# 35/300: Eugenes FICC Update 처리 완료
# 36/300: 추경發 추가 약세 가능성 점검 처리 완료
# 37/300: Unknown_6 처리 완료
# 38/300: Unknown_7 처리 완료
# 39/300: Unknown_8 처리 완료
# 40/300: Daily Bond Morning Brief(2025.02.18) 처리 완료
# 41/300: Eugenes FICC Update 처리 완료
# 42/300: Daily Bond Morning Brief(2025.02.17) 처리 완료
# 43/300: Eugenes FICC Update 처리 완료
# 44/300: 02/17 Kiwoom Fixed Income Weekly Review 처리 완료
# 45/300: Unknown_14 처리 완료
# 46/300: Unknown_15 처리 완료
# 47/300: Unknown_16 처리 완료
# 48/300: 채권 Daily (02.14) 처리 완료
# 49/300: [Fed Monitor] 연준 대차대조표 뜯어보기 - 98 처리 완료
# 50/300: Eugenes FICC Update 처리 완료
# 51/300: Daily Bond Morning Brief(2025.02.14) 처리 완료
# 52/300: 관세전쟁, 물가 충격보다 더 걱정해야 할 것은? 처리 완료
# 53/300: Unknown_22 처리 완료
# 54/300: Unknown_23 처리 완료
# 55/300: Unknown_24 처리 완료
# 56/300: 연간/월별 국고채 30년물 발행 추정 처리 완료
# 57/300: Daily Bond Morning Brief(2025.02.13) 처리 완료
# 58/300: Eugenes FICC Update 처리 완료
# 59/300: 영국, 아직은 물가에 집중 처리 완료
# 60/300: 元大金利: 국채선물 수급 특성 / 모니터링 지표 정리 처리 완료
# 61/300: Unknown_0 처리 완료
# 62/300: 인하까지 한 걸음 처리 완료
# 63/300: Daily Bond Morning Brief(2025.02.06) 처리 완료
# 64/300: 채권 Daily (02.06) 처리 완료
# 65/300: [1분기 QRA Review] 텀프리미엄 우려 해소 처리 완료
# 66/300: Eugenes FICC Update 처리 완료
# 67/300: Unknown_6 처리 완료
# 68/300: Unknown_7 처리 완료
# 69/300: Unknown_8 처리 완료
# 70/300: [IBKS Bond Inside] 2025년 2월 채권/크레딧 전망 처리 완료
# 71/300: 미 재무부 차입 계획: 단기 공급 이슈 완화 처리 완료
# 72/300: 2월 채권 및 매크로 이슈 점검: 우려는 선반영, 그 다.. 처리 완료
# 73/300: Eugenes FICC Update 처리 완료
# 74/300: Daily Bond Morning Brief(2025.02.05) 처리 완료
# 75/300: Unknown_14 처리 완료
# 76/300: Unknown_15 처리 완료
# 77/300: Unknown_16 처리 완료
# 78/300: Daily Bond Morning Brief(2025.02.04) 처리 완료
# 79/300: 2월, 시장을 움직일 2개의 이슈 처리 완료
# 80/300: Narrow Gap, Narrow Path 처리 완료
# 81/300: 2월 채권시장 전망: 복잡해진 통화정책 방정식 처리 완료
# 82/300: Daily Bond Morning Brief(2025.02.03) 처리 완료
# 83/300: Unknown_22 처리 완료
# 84/300: Unknown_23 처리 완료
# 85/300: Unknown_24 처리 완료
# 86/300: 02/03 Kiwoom Fixed Income Weekly Review 처리 완료
# 87/300: Eugenes FICC Update 처리 완료
# 88/300: FOMC 이후 한미 채권시장 처리 완료
# 89/300: 1월 ECB, 남아있는 강세 여력 처리 완료
# 90/300: [한화 Fed Monitor] 연준 대차대조표 뜯어보기 - 96 처리 완료
# 91/300: Unknown_0 처리 완료
# 92/300: Daily Bond Morning Brief(2025.01.24) 처리 완료
# 93/300: Eugenes FICC Update 처리 완료
# 94/300: 1월 FOMC Preview: 아직 자리를 지키는 매 처리 완료
# 95/300: 원화표시 외평채, 성공적 복귀 처리 완료
# 96/300: 발행 온기 확산 처리 완료
# 97/300: Unknown_6 처리 완료
# 98/300: Unknown_7 처리 완료
# 99/300: Unknown_8 처리 완료
# 100/300: 채권 Daily (01.23) 처리 완료
# 101/300: 元大金利: 금리가 환율에 민감하게 반응하는 이유 처리 완료
# 102/300: LA 산불이 미국채 금리에 미치는 영향 점검 처리 완료
# 103/300: Daily Bond Morning Brief(2025.01.23) 처리 완료
# 104/300: Daily Bond Morning Brief(2025.01.22) 처리 완료
# 105/300: Unknown_14 처리 완료
# 106/300: Unknown_15 처리 완료
# 107/300: Unknown_16 처리 완료
# 108/300: Eugenes FICC Update 처리 완료
# 109/300: 호주, 과도한 기대는 금물 처리 완료
# 110/300: Daily Bond Morning Brief(2025.01.21) 처리 완료
# 111/300: 트럼프 취임과 1월 FOMC 처리 완료
# 112/300: [한화 FI Weekly] Unsung Hero, 중립금리 처리 완료
# 113/300: Unknown_22 처리 완료
# 114/300: Unknown_23 처리 완료
# 115/300: Unknown_24 처리 완료
# 116/300: [한화 FI UST] 3.80~4.60% 처리 완료
# 117/300: Daily Bond Morning Brief(2025.01.20) 처리 완료
# 118/300: Eugenes FICC Update 처리 완료
# 119/300: 01/20 Kiwoom Fixed Income Weekly Review 처리 완료
# 120/300: 1월 금통위: 기준금리 동결. 한 템포 쉬어가기 처리 완료
# 121/300: Unknown_0 처리 완료
# 122/300: Eugenes FICC Update 처리 완료
# 123/300: 미 국채 10년물, 고점 형성 과정 중 처리 완료
# 124/300: 수급과 가격의 조삼모사(朝三暮四) 처리 완료
# 125/300: Eugenes FICC Update 처리 완료
# 126/300: 영점조정 처리 완료
# 127/300: Unknown_6 처리 완료
# 128/300: Unknown_7 처리 완료
# 129/300: Unknown_8 처리 완료
# 130/300: Daily Bond Morning Brief(2025.01.15) 처리 완료
# 131/300: 영국, 재정 우려 속 매수 타이밍 잡기 처리 완료
# 132/300: 한미 금리 디커플링, 임계치에 대한 고민 처리 완료
# 133/300: 채권 Daily (01.14) 처리 완료
# 134/300: Daily Bond Morning Brief(2025.01.14) 처리 완료
# 135/300: Unknown_14 처리 완료
# 136/300: Unknown_15 처리 완료
# 137/300: Unknown_16 처리 완료
# 138/300: Eugenes FICC Update 처리 완료
# 139/300: 수요예측 안정적 모집, 연초효과에 근거 제공 처리 완료
# 140/300: [1월 금통위 Preview] 20bp 싸움 처리 완료
# 141/300: [한화 Fed Monitor] 연준 대차대조표 뜯어보기 - 93 처리 완료
# 142/300: 금통위 Preview: 동결 Paradox 처리 완료
# 143/300: Unknown_22 처리 완료
# 144/300: Unknown_23 처리 완료
# 145/300: Unknown_24 처리 완료
# 146/300: 1월 금통위와 한국 채권시장 처리 완료
# 147/300: Daily Bond Morning Brief(2025.01.13) 처리 완료
# 148/300: Eugenes FICC Update 처리 완료
# 149/300: 2025년 1월 금통위 프리뷰 처리 완료
# 150/300: 1월 금통위 Preview: 한국은 인하 처리 완료
# 151/300: Unknown_0 처리 완료
# 152/300: Daily Bond Morning Brief(2025.01.08) 처리 완료
# 153/300: 유로존, 천연가스 수급 우려 점검 처리 완료
# 154/300: 채권 Daily (01.07) 처리 완료
# 155/300: Eugenes FICC Update 처리 완료
# 156/300: Daily Bond Morning Brief(2025.01.07) 처리 완료
# 157/300: Unknown_6 처리 완료
# 158/300: Unknown_7 처리 완료
# 159/300: Unknown_8 처리 완료
# 160/300: 단기물 중심 강세와 연초효과 기대감 처리 완료
# 161/300: 속도 제한 구간 처리 완료
# 162/300: [한화 FI Weekly] 한국과 글로벌 금리 디커플링의 배.. 처리 완료
# 163/300: 1월 채권시장 전망: 쏠림 경계 처리 완료
# 164/300: Daily Bond Morning Brief(2025.01.06) 처리 완료
# 165/300: Unknown_14 처리 완료
# 166/300: Unknown_15 처리 완료
# 167/300: Unknown_16 처리 완료
# 168/300: 01/06 Kiwoom Fixed Income Weekly Review 처리 완료
# 169/300: Eugenes FICC Update 처리 완료
# 170/300: 채권 Daily (01.03) 처리 완료
# 171/300: 연초 적정레벨 추정 ① 소수의견 처리 완료
# 172/300: Daily Bond Morning Brief(2025.01.03) 처리 완료
# 173/300: Unknown_22 처리 완료
# 174/300: Unknown_23 처리 완료
# 175/300: Unknown_24 처리 완료
# 176/300: Eugenes FICC Update 처리 완료
# 177/300: KIWOOM 채권 및 매크로 이슈 점검: 금리 인하 지속 가.. 처리 완료
# 178/300: Eugenes FICC Update 처리 완료
# 179/300: Daily Bond Morning Brief(2024.12.31) 처리 완료
# 180/300: [1월] 정책 확인과 자신감 회복 처리 완료
# 181/300: Unknown_0 처리 완료
# 182/300: [한화 FI Weekly] 올해 산타 안 옵니다 처리 완료
# 183/300: Eugenes FICC Update 처리 완료
# 184/300: Daily Bond Morning Brief(2024.12.23) 처리 완료
# 185/300: 12/23 Kiwoom Fixed Income Weekly Review 처리 완료
# 186/300: 북서풍의 계절 처리 완료
# 187/300: Unknown_6 처리 완료
# 188/300: Unknown_7 처리 완료
# 189/300: Unknown_8 처리 완료
# 190/300: Eugenes FICC Update 처리 완료
# 191/300: Daily Bond Morning Brief(2024.12.20) 처리 완료
# 192/300: [한화 FOMC Review] Front-loading, 트럼프에 대비 처리 완료
# 193/300: 12월 FOMC: 매파적 금리인하와 신중해진 정책 스탠스 처리 완료
# 194/300: [12월 FOMC] 재조정 (recalibration) 일단락 처리 완료
# 195/300: Unknown_14 처리 완료
# 196/300: Unknown_15 처리 완료
# 197/300: Unknown_16 처리 완료
# 198/300: Daily Bond Morning Brief(2024.12.19) 처리 완료
# 199/300: 12월 FOMC Review: 기승전물가 처리 완료
# 200/300: 채권시장에 매우 비우호적 처리 완료
# 201/300: 미국 정책 포커스, 재정보다 통화로 가야 처리 완료
# 202/300: [CrediVille] ‘주홍글씨’의 알파벳은 A(Adultery) 처리 완료
# 203/300: Unknown_22 처리 완료
# 204/300: Unknown_23 처리 완료
# 205/300: Unknown_24 처리 완료
# 206/300: Daily Bond Morning Brief(2024.12.18) 처리 완료
# 207/300: Daily Bond Morning Brief(2024.12.17) 처리 완료
# 208/300: 채권 Daily (12.17) 처리 완료
# 209/300: Eugenes FICC Update 처리 완료
# 210/300: 12월, 남아있는 2개의 크레딧 시장 이슈 처리 완료
# 211/300: Unknown_0 처리 완료
# 212/300: 탄핵 정국에서의 적정레벨 추정과 금리 방향성 점검 처리 완료
# 213/300: Daily Bond Morning Brief(2024.12.12) 처리 완료
# 214/300: Eugenes FICC Update 처리 완료
# 215/300: Daily Bond Morning Brief(2024.12.11) 처리 완료
# 216/300: Eugenes FICC Update 처리 완료
# 217/300: Unknown_6 처리 완료
# 218/300: Unknown_7 처리 완료
# 219/300: Unknown_8 처리 완료
# 220/300: Daily Bond Morning Brief(2024.12.10) 처리 완료
# 221/300: 금리: 국내 정치 이슈보다 펀더멘털 처리 완료
# 222/300: 정치적 불확실성을 안고 가게 된 크레딧 시장 처리 완료
# 223/300: 프랑스 국채: 상대적 약세 지속 처리 완료
# 224/300: 채권 Daily (12.09) 처리 완료
# 225/300: Unknown_14 처리 완료
# 226/300: Unknown_15 처리 완료
# 227/300: Unknown_16 처리 완료
# 228/300: [한화 FI Weekly] 이벤트는 이벤트일 뿐 처리 완료
# 229/300: Daily Bond Morning Brief(2024.12.09) 처리 완료
# 230/300: Eugenes FICC Update 처리 완료
# 231/300: 정치리스크 장기화, 채권시장 반응은 차별화 처리 완료
# 232/300: 12/09 Kiwoom Fixed Income Weekly Review 처리 완료
# 233/300: Unknown_22 처리 완료
# 234/300: Unknown_23 처리 완료
# 235/300: Unknown_24 처리 완료
# 236/300: Daily Bond Morning Brief(2024.12.06) 처리 완료
# 237/300: Eugenes FICC Update 처리 완료
# 238/300: Daily Bond Morning Brief(2024.12.05) 처리 완료
# 239/300: Eugenes FICC Update 처리 완료
# 240/300: 소음 공해 처리 완료
# 241/300: Unknown_0 처리 완료
# 242/300: [한화 FI Monthly] 기준금리: 시장금리 상단의 기준 처리 완료
# 243/300: 12월 채권시장 전망: 달라진 전제, 달라지는 눈높이 처리 완료
# 244/300: Daily Bond Morning Brief(2024.12.02) 처리 완료
# 245/300: Eugenes FICC Update 처리 완료
# 246/300: 12/02 Kiwoom Fixed Income Weekly Review 처리 완료
# 247/300: Unknown_6 처리 완료
# 248/300: Unknown_7 처리 완료
# 249/300: Unknown_8 처리 완료
# 250/300: 연말을 준비하는 자세 처리 완료
# 251/300: 위험과 이익 사이 무게중심 처리 완료
# 252/300: Daily Bond Morning Brief(2024.11.29) 처리 완료
# 253/300: Eugenes FICC Update 처리 완료
# 254/300: 2024년 11월 금통위 리뷰 처리 완료
# 255/300: Unknown_14 처리 완료
# 256/300: Unknown_15 처리 완료
# 257/300: Unknown_16 처리 완료
# 258/300: 11월 금통위 Review: 추가 인하 불러오는 깜짝 인하 처리 완료
# 259/300: 11월 금통위: 2%대 기준금리는 선택아닌 필수 처리 완료
# 260/300: [한화 금통위 리뷰] 시선이동, 금융안정에서 경제로 처리 완료
# 261/300: 11월 금통위: 깜짝 25bp 인하. 그 때는 틀리고, 지금.. 처리 완료
# 262/300: [11월 금통위 Review] 10월에 못한 Super Dovish 기조.. 처리 완료
# 263/300: Unknown_22 처리 완료
# 264/300: Unknown_23 처리 완료
# 265/300: Unknown_24 처리 완료
# 266/300: 채권 Daily (11.28) 처리 완료
# 267/300: Daily Bond Morning Brief(2024.11.28) 처리 완료
# 268/300: Eugenes FICC Update 처리 완료
# 269/300: 11월 미국 회사채 시장 리뷰 처리 완료
# 270/300: [Readers’ Cut] 빨리 털고 싶은 RRP 처리 완료
# 271/300: Unknown_0 처리 완료
# 272/300: Daily Bond Morning Brief(2024.11.25) 처리 완료
# 273/300: Eugenes FICC Update 처리 완료
# 274/300: 11/25 Kiwoom Fixed Income Weekly Review 처리 완료
# 275/300: 11월 금통위 Preview: 금리 인하 기대는 유지 처리 완료
# 276/300: Daily Bond Morning Brief(2024.11.22) 처리 완료
# 277/300: Unknown_6 처리 완료
# 278/300: Unknown_7 처리 완료
# 279/300: Unknown_8 처리 완료
# 280/300: Eugenes FICC Update 처리 완료
# 281/300: Daily Bond Morning Brief(2024.11.21) 처리 완료
# 282/300: Eugenes FICC Update 처리 완료
# 283/300: 채권 Daily (11.20) 처리 완료
# 284/300: 우리에게 남아 있는 2척의 배 처리 완료
# 285/300: Unknown_14 처리 완료
# 286/300: Unknown_15 처리 완료
# 287/300: Unknown_16 처리 완료
# 288/300: Eugenes FICC Update 처리 완료
# 289/300: Daily Bond Morning Brief(2024.11.20) 처리 완료
# 290/300: 채권 Daily (11.19) 처리 완료
# 291/300: Daily Bond Morning Brief(2024.11.19) 처리 완료
# 292/300: Eugenes FICC Update 처리 완료
# 293/300: Unknown_22 처리 완료
# 294/300: Unknown_23 처리 완료
# 295/300: Unknown_24 처리 완료
# 296/300: 중장기적으로는 역시 기업 펀더멘탈 처리 완료
# 297/300: 가던 길을 가야할 때 처리 완료
# 298/300: [한화 FI Weekly] 하던 것부터 끝내기 처리 완료
# 299/300: Keep Calm and Buy Bond 처리 완료
# 300/300: Keep Calm and Buy Bond 처리 완료
# 모든 작업 완료!
# 총 172개의 리서치 데이터가 딕셔너리에 저장되었습니다.
#
# Title (from page): Unknown_0
# PDF Title: 20241125_debenture_154534000
# Date: Unknown
# Contents preview: 25 Nov. 2024
# ▪ : (3Y), (10Y) 0 0 0 0 0 0.000
# ▪ : 0 0 0 0 0 0.000
# ▪ (bp): 5/3 6.0 (0.5) 10/3: 16.3 (1...
#
# Title (from page): 1분기 10년 하단 4.20%
# PDF Title: 20250226_debenture_454438000
# Date: 25.02.26
# Contents preview: 2025년 2월 26일 I Global Asset Research
# BondView
# Fixed Income 미국채 10년물 금리 하락을 견인한 텀프리미엄
# Compliance Noti...
#
# Title (from page): 미국채 10년물 금리 하락을 견인한 텀프리미엄
# PDF Title: 20250226_debenture_399207000
# Date: 25.02.26
# Contents preview: 2025년 2월 25일 I Global Asset Research
# BondView
# Fixed Income [2월 금통위 Review] 확장재정이 Key
# Compliance Noti...

# %%
pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Using cached pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\yoons\anaconda3\lib\site-packages (from pdfplumber) (10.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\yoons\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\yoons\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (43.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\yoons\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\yoons\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)
# Using cached pdfplumber-0.11.5-py3-none-any.whl (59 kB)
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.5 pypdfium2-4.30.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
# 페이지 1 크롤링 완료, 현재 30개의 데이터 수집
# 1/30: Unknown_0 처리 완료
# 2/30: 1분기 10년 하단 4.20% 처리 완료
# 3/30: 미국채 10년물 금리 하락을 견인한 텀프리미엄 처리 완료
# 4/30: [2월 금통위 Review] 확장재정이 Key 처리 완료
# 5/30: Daily Bond Morning Brief(2025.02.26) 처리 완료
# 6/30: Eugenes FICC Update 처리 완료
# 7/30: Unknown_6 처리 완료
# 8/30: Unknown_7 처리 완료
# 9/30: Unknown_8 처리 완료
# 10/30: 2월 금통위 리뷰: 통화정책과 재정정책 공조 필요 처리 완료
# 11/30: [IBKS Bond Inside] 2025년 2월 금통위 리뷰 처리 완료
# 12/30: 2월 금통위; 정책 공조의 시간 처리 완료
# 13/30: 2월 금통위 Review: 비둘기와 매를 모두, 최종금리 2... 처리 완료
# 14/30: [금통위 리뷰] 최소 1.5% 처리 완료
# 15/30: Unknown_14 처리 완료
# 16/30: Unknown_15 처리 완료
# 17/30: Unknown_16 처리 완료
# 18/30: 2월 금통위: 핵심 지표는 여전히 추가 금리인하를 지.. 처리 완료
# 19/30: 2월 금통위: 금리 인하 더 한다. 국고 금리 뉴레인지 .. 처리 완료
# 20/30: Daily Bond Morning Brief(2025.02.25) 처리 완료
# 21/30: Eugenes FICC Update 처리 완료
# 22/30: 브라질, 연초 효과 지속 여부, 재정에 달렸다 처리 완료
# 23/30: Unknown_22 처리 완료
# 24/30: Unknown_23 처리 완료
# 25/30: Unknown_24 처리 완료
# 26/30: 채권 Daily (02.24) 처리 완료
# 27/30: [FI Weekly] 금통위 Preview: 만장일치 인하 처리 완료
# 28/30: Daily Bond Morning Brief(2025.02.24) 처리 완료
# 29/30: Eugenes FICC Update 처리 완료
# 30/30: 02/24 Kiwoom Fixed Income Weekly Review 처리 완료
# 모든 작업 완료!
# 데이터가 research_data.csv에 저장되었습니다.

# %%
import requests
from bs4 import BeautifulSoup
import pdfplumber
from io import BytesIO
import time
import csv

# 기본 URL 설정
base_url = "https://finance.naver.com/research/debenture_list.naver?searchType=keyword&keyword=%B1%DD%B8%AE&brokerCode=&writeFromDate=&writeToDate=&x=0&y=0"
total_pages = 1  # 총 페이지 수 (테스트용으로 1로 바꿀 수 있음)

# 데이터를 저장할 리스트
research_data = []

# 날짜 형식을 YYYY-MM-DD로 변환하는 함수
def format_date(date_str):
    try:
        year, month, day = date_str.split('.')
        full_year = f"20{year}"
        return f"{full_year}-{month.zfill(2)}-{day.zfill(2)}"
    except:
        return "Unknown"

# 1. 페이지 크롤링
for page in range(1, total_pages + 1):
    url = f"{base_url}&page={page}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    rows = soup.find_all('tr')
    file_tds = soup.find_all('td', class_='file')
    for i, td in enumerate(file_tds):
        pdf_link = td.find('a')['href']
        
        if i + 1 < len(rows):
            row = rows[i + 1]
            title_elem = row.find('a')
            title = title_elem.text.strip() if title_elem else f"Unknown_{i}"
            date_elem = row.find('td', class_='date')
            raw_date = date_elem.text.strip() if date_elem else "Unknown"
            date = format_date(raw_date)
        else:
            title = f"Unknown_{i}"
            date = "Unknown"
        
        research_data.append({
            'title': title,
            'date': date,
            'pdf_url': pdf_link,  # 임시로 저장
            'contents': ''
        })
    
    print(f"페이지 {page} 크롤링 완료, 현재 {len(research_data)}개의 데이터 수집")
    time.sleep(1)

# 2. PDF에서 텍스트 추출 (텍스트가 없으면 스킵)
final_data = []  # 텍스트가 있는 데이터만 저장할 최종 리스트
for idx, item in enumerate(research_data, 1):
    pdf_url = item['pdf_url']
    try:
        pdf_response = requests.get(pdf_url, stream=True, timeout=10)
        pdf_file = BytesIO(pdf_response.content)
        
        with pdfplumber.open(pdf_file) as pdf:
            contents = ""
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    contents += page_text.replace('\n', ' ')  # 한 줄로 변환
        
        # 텍스트가 있는 경우에만 추가
        if contents.strip():  # 공백만 있는 경우도 제외
            item['contents'] = contents
            del item['pdf_url']  # url 제거
            final_data.append(item)
            print(f"{idx}/{len(research_data)}: {item['title']} 처리 완료")
        else:
            print(f"{idx}/{len(research_data)}: {item['title']} 스킵 - 텍스트 없음")
    
    except Exception as e:
        print(f"{idx}/{len(research_data)}: {pdf_url} 처리 실패 - 오류: {e}")
    
    time.sleep(1)

# 3. CSV 파일로 저장 (텍스트가 있는 데이터만)
csv_file = "research_data.csv"
with open(csv_file, 'w', encoding='utf-8-sig', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['title', 'contents', 'date'])
    writer.writeheader()
    writer.writerows(final_data)

print("모든 작업 완료!")
print(f"총 {len(final_data)}개의 유효 데이터가 {csv_file}에 저장되었습니다.")
# Out:
# 페이지 1 크롤링 완료, 현재 30개의 데이터 수집
# 1/30: Unknown_0 처리 완료
# 2/30: 1분기 10년 하단 4.20% 처리 완료
# 3/30: 미국채 10년물 금리 하락을 견인한 텀프리미엄 처리 완료
# 4/30: [2월 금통위 Review] 확장재정이 Key 처리 완료
# 5/30: Daily Bond Morning Brief(2025.02.26) 처리 완료
# 6/30: Eugenes FICC Update 처리 완료
# 7/30: Unknown_6 처리 완료
# 8/30: Unknown_7 처리 완료
# 9/30: Unknown_8 처리 완료
# 10/30: 2월 금통위 리뷰: 통화정책과 재정정책 공조 필요 처리 완료
# 11/30: [IBKS Bond Inside] 2025년 2월 금통위 리뷰 처리 완료
# 12/30: 2월 금통위; 정책 공조의 시간 처리 완료
# 13/30: 2월 금통위 Review: 비둘기와 매를 모두, 최종금리 2... 처리 완료
# 14/30: [금통위 리뷰] 최소 1.5% 처리 완료
# 15/30: Unknown_14 처리 완료
# 16/30: Unknown_15 처리 완료
# 17/30: Unknown_16 처리 완료
# 18/30: 2월 금통위: 핵심 지표는 여전히 추가 금리인하를 지.. 처리 완료
# 19/30: 2월 금통위: 금리 인하 더 한다. 국고 금리 뉴레인지 .. 처리 완료
# 20/30: Daily Bond Morning Brief(2025.02.25) 처리 완료
# 21/30: Eugenes FICC Update 처리 완료
# 22/30: 브라질, 연초 효과 지속 여부, 재정에 달렸다 처리 완료
# 23/30: Unknown_22 처리 완료
# 24/30: Unknown_23 처리 완료
# 25/30: Unknown_24 처리 완료
# 26/30: 채권 Daily (02.24) 처리 완료
# 27/30: [FI Weekly] 금통위 Preview: 만장일치 인하 처리 완료
# 28/30: Daily Bond Morning Brief(2025.02.24) 처리 완료
# 29/30: Eugenes FICC Update 처리 완료
# 30/30: 02/24 Kiwoom Fixed Income Weekly Review 처리 완료
# 모든 작업 완료!
# 총 30개의 유효 데이터가 research_data.csv에 저장되었습니다.
