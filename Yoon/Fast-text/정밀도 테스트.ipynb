# %% [markdown]
# ### 내 사전으로 문장 라벨링

# %%
import pandas as pd
from ekonlpy.tag import Mecab
import ast
import logging

# 로깅 설정 (디버깅용)
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger(__name__)

# ekonlpy의 Mecab 토크나이저 객체 생성
mecab = Mecab()

# 1. 감정 사전 로드 및 전처리
try:
    dovish_dict = pd.read_csv('final_dovish.csv')  # 비둘기파 사전
    hawkish_dict = pd.read_csv('final_hawkish.csv')  # 매파 사전
except FileNotFoundError as e:
    print(f"파일 로드 오류: {e}")
    exit()

# 결측값 처리 및 단어 리스트 생성 (컬럼명 'Dovish', 'Hawkish' 가정)
dovish_dict = dovish_dict.dropna(subset=['Dovish'])
hawkish_dict = hawkish_dict.dropna(subset=['Hawkish'])

dovish_words = set(dovish_dict['Dovish'].str.strip())
hawkish_words = set(hawkish_dict['Hawkish'].str.strip())

# 감정 사전 내용 출력 (디버깅용)
logger.info(f"Dovish words (sample): {list(dovish_words)[:10]}")
logger.info(f"Hawkish words (sample): {list(hawkish_words)[:10]}")

# 2. 문장 데이터 로드
try:
    sentences_df = pd.read_csv('conferences_sentences.csv')  # 문장 데이터
except FileNotFoundError as e:
    print(f"파일 로드 오류: {e}")
    exit()

# 결측값 처리
sentences_df['sentences'] = sentences_df['sentences'].fillna('[]')

# 3. 리스트 형식의 문자열을 실제 리스트로 변환
def parse_sentences(sentences_str):
    try:
        # 문자열로 저장된 리스트를 실제 리스트로 변환
        sentences_list = ast.literal_eval(sentences_str)
        return sentences_list if isinstance(sentences_list, list) else [sentences_str]
    except (ValueError, SyntaxError):
        # 파싱 실패 시 원래 문자열을 리스트로 처리
        return [sentences_str]

# 문장 리스트를 개별 문장으로 분리
sentences_expanded = []
for idx, row in sentences_df.iterrows():
    sentences_list = parse_sentences(row['sentences'])
    for sentence in sentences_list:
        sentences_expanded.append({'sentence': sentence})

# 새로운 데이터프레임 생성
expanded_df = pd.DataFrame(sentences_expanded)

# 결측값 처리
expanded_df['sentence'] = expanded_df['sentence'].fillna('')

# 4. 문장을 라벨링하는 함수 정의 (디버깅 정보 포함)
def label_sentence(sentence):
    # 문장에서 단어 추출 (ekonlpy의 Mecab으로 토큰화)
    tokens = mecab.morphs(sentence)
    
    # 매파/비둘기파 단어 매칭
    dovish_matched = [token for token in tokens if token in dovish_words]
    hawkish_matched = [token for token in tokens if token in hawkish_words]
    
    # 매칭된 단어 카운트
    dovish_count = len(dovish_matched)
    hawkish_count = len(hawkish_matched)
    
    # 라벨링 기준
    if dovish_count > hawkish_count:
        label = 'Dovish'
    elif hawkish_count > dovish_count:
        label = 'Hawkish'
    else:
        label = 'Neutral'
    
    # 디버깅 정보 출력
    logger.info(f"Sentence: {sentence}")
    logger.info(f"Dovish matches: {dovish_matched}, Count: {dovish_count}")
    logger.info(f"Hawkish matches: {hawkish_matched}, Count: {hawkish_count}")
    logger.info(f"Label: {label}\n")
    
    return label

# 5. 각 문장에 대해 라벨링 수행
expanded_df['Label'] = expanded_df['sentence'].apply(label_sentence)

# 6. 결과를 CSV 파일로 저장
expanded_df.to_csv('labeled_sentences.csv', index=False, encoding='utf-8-sig')

print("라벨링 완료! 결과는 'labeled_sentences.csv' 파일에 저장되었습니다.")
# Out:
# Dovish words (sample): ['비메모리', '장터', '양질', '조달', '건설기업', '평화주의', '급평가', '디플레션갭', '생산력', '수소']
# Hawkish words (sample): ['부채한도', '김건희', '외부요인', '기술기업', '장남', '현직', '라더', '사인', '탈퇴', '폭력']
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 내수와 수출 모두 감소세를 지속하면서계속 위축되고 있으나 하강속도는 다소 완만해지고 있으며 세계경제 침체, 국제금융시장 불안 등으로 인해 향후성장의 하향위험은 여전히 큰 것으로 판단됨
# Dovish matches: ['내수', '수출', '감소세', '지속', '위축', '하강', '완만', '해지', '침체', '국제', '성장', '하향', '위험'], Count: 13
# Hawkish matches: ['불안', '성장', '위험'], Count: 3
# Label: Dovish
#
# Sentence: 소비자물가는 국제유가가 안정세를 보이는 가운데 경기부진에 따른 수요압력 완화로 오름세가 둔화되었으며 앞으로도 이러한 추세가 이어질 것으로 보임.
# Dovish matches: ['국제', '유가', '안정세', '부진', '수요', '완화', '둔화', '추세', '보임'], Count: 9
# Hawkish matches: ['압력'], Count: 1
# Label: Dovish
#
# Sentence: 부동산시장에서는 거래위축 및 가격하락 현상이 지속되고 있음
# Dovish matches: ['위축', '하락', '지속'], Count: 3
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 개선된 모습을나타내었으며 금융기관의 대출태도가 완화되면서 가계 및중소기업 대출이 꾸준히 늘어나고 있음
# Dovish matches: ['개선', '금융기관', '완화', '가계', '중소기업'], Count: 5
# Hawkish matches: ['환율'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기의 과도한 위축을 방지하고 금융시장 안정을 도모하는데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '위축', '안정', '도모', '주안점', '운용'], Count: 8
# Hawkish matches: ['과도'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 내수 부진에도 불구하고 수출 감소세둔화와 적극적인 재정통화정책에 힘입어 하강속도가 완만해지고 있으나 세계경제 침체 지속, 고용사정 악화 등으로 향후 성장의 하향위험이 상존하고 있는 것으로 판단됨
# Dovish matches: ['내수', '부진', '수출', '감소세', '둔화', '힘입', '하강', '완만', '해지', '침체', '지속', '악화', '성장', '하향', '위험'], Count: 15
# Hawkish matches: ['성장', '위험'], Count: 2
# Label: Dovish
#
# Sentence: 소비자물가는 국제유가의 안정, 경기부진에 따른 수요압력완화 등으로 오름세가 둔화되었으며 앞으로도 이러한 추세가 이어질 것으로 보임.
# Dovish matches: ['국제', '유가', '안정', '부진', '수요', '완화', '둔화', '추세', '보임'], Count: 9
# Hawkish matches: ['압력'], Count: 1
# Label: Dovish
#
# Sentence: 부동산시장에서는 수도권 일부에서 거래량이 늘어나면서 가격이 반등하는 움직임을 나타내었음
# Dovish matches: [], Count: 0
# Hawkish matches: ['거래량', '움직임'], Count: 2
# Label: Hawkish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 개선 추세를지속하는 가운데 가계 및 중소기업 대출이 꾸준히 늘어나고 있으나 신용위험에 대한 우려와 시중자금의 단기화 현상이 지속되고 있음
# Dovish matches: ['개선', '추세', '지속', '가계', '중소기업', '신용위험', '시중', '자금', '지속'], Count: 9
# Hawkish matches: ['환율', '우려'], Count: 2
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기 회복을 뒷받침하고 금융시장 안정을 도모하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복', '안정', '도모', '주안점', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 적극적인 재정통화정책 등에 힘입어 내수부진이 완화되고 생산활동이 호전되는 등 하강을 멈춘모습이나 국제원자재가격 상승 및 주요 선진국의 경기부진으로 향후 성장의 하향위험이 상존하고 있는 것으로판단됨
# Dovish matches: ['힘입', '내수', '부진', '완화', '호전', '하강', '국제', '선진국', '부진', '성장', '하향', '위험'], Count: 12
# Hawkish matches: ['상승', '성장', '위험'], Count: 3
# Label: Dovish
#
# Sentence: 소비자물가는 경기부진에 따른 수요압력 완화, 환율의 하향안정 등으로 오름세가 둔화되었음.
# Dovish matches: ['부진', '수요', '완화', '하향', '안정', '둔화'], Count: 6
# Hawkish matches: ['압력', '환율'], Count: 2
# Label: Dovish
#
# Sentence: 부동산가격은 소폭의상승세가 지속되었음
# Dovish matches: ['부동산', '지속'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 안정적인 움직임을 보이는 가운데 가계 및 중소기업 대출이 꾸준히 늘어나고 있으나 신용위험에 대한 우려와 시중자금의 단기화 현상이 해소되지 않은 상황임
# Dovish matches: ['안정', '가계', '중소기업', '신용위험', '시중', '자금', '해소'], Count: 7
# Hawkish matches: ['환율', '움직임', '우려'], Count: 3
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 및 금융시장의 개선 움직임이 지속되도록 하는데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '지속', '주안점', '운용'], Count: 7
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 적극적인 재정통화정책 등에 힘입어 내수및 수출부진이 완화되면서 그간의 하강세에서 벗어나는모습이나 국제원자재가격 상승, 주요 선진국의 경기부진등으로 향후 성장경로의 불확실성이 높은 것으로 판단됨
# Dovish matches: ['힘입', '내수', '수출', '부진', '완화', '국제', '선진국', '부진', '성장', '경로'], Count: 10
# Hawkish matches: ['그간', '강세', '상승', '성장', '높'], Count: 5
# Label: Dovish
#
# Sentence: 소비자물가는 경기부진에 따른 수요압력 완화 등으로 오름세가 계속 둔화되었음.
# Dovish matches: ['부진', '수요', '완화', '둔화'], Count: 4
# Hawkish matches: ['압력'], Count: 1
# Label: Dovish
#
# Sentence: 부동산가격은 소폭의 상승세가지속되었음
# Dovish matches: ['부동산', '지속'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 안정적인 움직임을 이어가는 가운데 주택담보대출을 중심으로 은행대출이 꾸준히 증가하였음.
# Dovish matches: ['안정', '중심', '증가'], Count: 3
# Hawkish matches: ['환율', '움직임'], Count: 2
# Label: Dovish
#
# Sentence: 한편 신용위험에 대한 우려와 시중자금의 단기화 현상은 해소되지 않은 상황임
# Dovish matches: ['신용위험', '시중', '자금', '해소'], Count: 4
# Hawkish matches: ['우려'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지 하면서최근의 경기 개선 움직임 및 금융시장 안정이 지속되도록하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '안정', '지속', '주안점', '운용'], Count: 8
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 적극적인 재정통화정책 및 신흥시장국경제상황 호전에 힘입어 내수와 수출 부진이 더욱 완화되는 등 개선 움직임을 지속하고 있으나 주요 선진국의 경기회복 지연 가능성 등으로 향후 성장경로의 불확실성이상존하고 있는 것으로 판단됨
# Dovish matches: ['신흥시장', '호전', '힘입', '내수', '수출', '부진', '완화', '개선', '지속', '선진국', '회복', '성장', '경로'], Count: 13
# Hawkish matches: ['움직임', '성장'], Count: 2
# Label: Dovish
#
# Sentence: 소비자물가는 수요압력 완화, 환율 하락 등의 영향으로 오름세가 계속 둔화되었음.
# Dovish matches: ['수요', '완화', '하락', '둔화'], Count: 4
# Hawkish matches: ['압력', '환율'], Count: 2
# Label: Dovish
#
# Sentence: 부동산가격은 상승세가 지속되었음
# Dovish matches: ['부동산', '지속'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 시장금리 및 주가가 상승하는 가운데 주택담보대출이 계속 큰 폭으로 증가하였음.
# Dovish matches: ['증가'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Label: Neutral
#
# Sentence: 한편 신용위험에 대한 우려와 시중자금의 단기화 현상은 해소되지 않은상황임
# Dovish matches: ['신용위험', '시중', '자금', '해소'], Count: 4
# Hawkish matches: ['우려'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 개선 움직임 및 금융시장 안정이 지속되도록하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '안정', '지속', '주안점', '운용'], Count: 8
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 내수 및 수출이 회복 움직임을 보이고 생산이 증가하는 등 개선 추세를 이어가고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '내수', '수출', '회복', '증가', '개선', '추세', '성장', '경로'], Count: 9
# Hawkish matches: ['움직임', '성장'], Count: 2
# Label: Dovish
#
# Sentence: 소비자물가는 상승률이 다소 높아졌으나 대체로 안정된모습을 나타내고 있음.
# Dovish matches: ['상승률', '안정'], Count: 2
# Hawkish matches: ['높', '졌으나'], Count: 2
# Label: Neutral
#
# Sentence: 부동산가격은 오름세가 지속되었음
# Dovish matches: ['부동산', '지속'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 시장금리 및 주가가 상승한 가운데 주택담보대출이 큰 폭의 증가를 지속하였음.
# Dovish matches: ['증가', '지속'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 한편 신용위험에대한 우려와 시중자금의 단기화 현상은 다소 완화되는 움직임을 보였음
# Dovish matches: ['신용위험', '시중', '자금', '완화'], Count: 4
# Hawkish matches: ['우려', '움직임'], Count: 2
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 개선 추세 및 금융시장 안정이 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '추세', '안정', '지속', '주안점', '운용'], Count: 9
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출이 회복세를 이어가고 소비가 전년수준을 계속 상회 하는 등개선 추세를 지속하고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '수출', '회복세', '소비', '상회', '개선', '추세', '지속', '성장', '경로'], Count: 10
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 대체로 안정된 모습을 나타내었음.
# Dovish matches: ['안정'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 부동산가격은 오름세가 지속되었음
# Dovish matches: ['부동산', '지속'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 주가가 큰 폭 상승한 후 반락한 가운데총부채상환비율 확대 적용, 대출금리 상승 등으로 주택담보대출의 증가세가 둔화되었음
# Dovish matches: ['증가세', '둔화'], Count: 2
# Hawkish matches: ['상승', '반락', '상승'], Count: 3
# Label: Hawkish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 개선 추세 및 금융시장 안정이 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '추세', '안정', '지속', '주안점', '운용'], Count: 9
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출 및 내수와 생산 활동이 한층 더 개선되는 등 회복세를 나타내고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '수출', '내수', '개선', '회복세', '성장', '경로'], Count: 7
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 원/달러 환율 등이 하락요인으로 작용하면서안정세를 이어가고 있음.
# Dovish matches: ['하락', '안정세'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 부동산가격은 오름세가 주춤하는모습을 보였음
# Dovish matches: ['부동산'], Count: 1
# Hawkish matches: ['부동산'], Count: 1
# Label: Neutral
#
# Sentence: 금융시장에서는 주가, 금리 등 가격변수의 변동성이 다소확대된 가운데 총부채상환비율 확대 적용, 대출금리 상승등으로 주택담보대출 증가세의 둔화 움직임이 지속되었음
# Dovish matches: ['증가세', '둔화', '지속'], Count: 3
# Hawkish matches: ['상승', '움직임'], Count: 2
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세가 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '주안점', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출과 소비가 개선추세를 보이는 등 회복세를 이어가고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '수출', '소비', '개선', '추세', '회복세', '성장', '경로'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 상승세가 다소 확대되었으나 대체로 안정된모습을 보이고 있음.
# Dovish matches: ['안정'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 부동산가격은 오름세가 둔화되었음
# Dovish matches: ['부동산', '둔화'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 대체로 안정된움직임을 보이다가 해외 불안요인의 영향으로 변동폭이일시 확대되었으며 주택담보대출은 전월수준의 증가를 나타내었음
# Dovish matches: ['안정', '해외', '전월', '증가'], Count: 4
# Hawkish matches: ['환율', '움직임', '다가'], Count: 3
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세가 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '주안점', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출과 내수가 꾸준히 증가하는 등 회복세를 지속하고 있으며 앞으로도 이와 같은 추세가 이어질 것으로 전망됨.
# Dovish matches: ['호전', '수출', '내수', '증가', '회복세', '지속', '추세'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 다만 주요선진국의 본격적인 경기회복 지연 우려 등으로 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['선진국', '회복', '성장', '경로'], Count: 4
# Hawkish matches: ['우려', '성장'], Count: 2
# Label: Dovish
#
# Sentence: 소비자물가는 석유류가격을 중심으로 오름세가 확대되었으며 폭설의 영향이 더해져 상승률이 일시 더 높아질 것으로 예상됨.
# Dovish matches: ['중심', '상승률'], Count: 2
# Hawkish matches: ['폭설', '더해져', '높'], Count: 3
# Label: Hawkish
#
# Sentence: 부동산가격은 상승세가 둔화되고 있음
# Dovish matches: ['부동산', '둔화'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 경기개선 흐름 등을 반영하여 장단기 시장금리 및 주가가 상당 폭 상승하였으며 주택담보대출은꾸준한 증가세를 보였음
# Dovish matches: ['개선', '상당폭', '증가세'], Count: 3
# Hawkish matches: ['장단기', '상승'], Count: 2
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화 기조를 유지하면서경기회복세 지속에 도움이 되는 방향으로 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 수출과 내수가 꾸준히 증가하고 생산활동이 활발한 모습을 보이는 등 회복세를 지속하고 있으며앞으로도 이와 같은 추세가 이어질 것으로 전망됨.
# Dovish matches: ['수출', '내수', '증가', '회복세', '지속', '추세'], Count: 6
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 다만일부 유럽국가의 재정위기 우려 등으로 향후 성장경로의불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['국가', '성장', '경로'], Count: 3
# Hawkish matches: ['우려', '성장'], Count: 2
# Label: Dovish
#
# Sentence: 소비자물가는 오름세가 확대되었으나 최근의 국제원자재가격 움직임 등에 비추어 앞으로 안정된 모습을 보일 것으로 예상됨.
# Dovish matches: ['국제', '비추', '안정'], Count: 3
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 부동산가격은 오름세가 제한되고 있음
# Dovish matches: ['부동산'], Count: 1
# Hawkish matches: ['부동산', '제한'], Count: 2
# Label: Hawkish
#
# Sentence: 금융시장에서는 해외 불안요인의 영향으로 환율과 주가등 가격변수가 큰 폭의 변동을 보였으며 주택담보대출은계절요인 등으로 증가폭이 축소되었음
# Dovish matches: ['해외', '계절요인', '증가', '축소'], Count: 4
# Hawkish matches: ['환율'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세 지속에 도움이 되는 방향으로 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 최근 국내 경기는 수출이 확대되고 내수가 꾸준히 증가하는등 회복세를 지속하고 있으며 앞으로도 이와 같은 추세가이어질 것으로 전망됨.
# Dovish matches: ['수출', '내수', '증가', '회복세', '지속', '추세'], Count: 6
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 다만 일부 국가의 과다채무 문제등으로 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['국가', '채무', '문제', '성장', '경로'], Count: 5
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 상승세가 다소 둔화되었으며 최근의 국제원자재가격 움직임 등에 비추어 당분간 안정된 모습을 보일것으로 예상됨.
# Dovish matches: ['둔화', '국제', '비추', '안정'], Count: 4
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 부동산 시장에서는 가격이 완만하게 상승하였으나 거래는 부진하였음
# Dovish matches: ['완만', '부진'], Count: 2
# Hawkish matches: ['상승', '였으나', '거래'], Count: 3
# Label: Hawkish
#
# Sentence: 금융시장에서는 일부 유럽국가의 재정위기 등 해외 불안요인이 완화되면서 주가가 반등하고 환율이 하락하였으며주택담보대출은 계절요인 등으로 소폭 증가에 그쳤음
# Dovish matches: ['국가', '해외', '완화', '하락', '계절요인', '증가'], Count: 6
# Hawkish matches: ['환율'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세 지속에 도움이 되는 방향으로 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 보이고 있는 가운데 미국, 일본 등 주요 선진국 경제의 개선 추세가 다소강화되는 움직임을 나타내고 있음.
# Dovish matches: ['호조', '선진국', '개선', '추세', '강화'], Count: 5
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 다만 일부 유럽국가의재정문제 등 위험요인이 잠재하고 있음
# Dovish matches: ['국가', '문제', '위험요인'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내 경기는 건설투자가 다소 부진한 모습이나 수출이 호조를 보이고 소비와 설비투자도 꾸준히 증가하는 등 회복세를 지속하고 있음
# Dovish matches: ['건설', '투자', '부진', '수출', '호조', '소비', '설비', '투자', '증가', '회복세', '지속'], Count: 11
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내 경기의 회복세는 앞으로도 이어질 것으로 전망되나해외 위험요인 등에 비추어 향후 성장경로의 불확실성은상존하고 있는 것으로 판단됨
# Dovish matches: ['회복세', '해외', '위험요인', '비추', '성장', '경로'], Count: 6
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 서비스가격을 중심으로 상승세가 둔화되었으며 당분간 안정된 모습을 보일 것으로 예상됨.
# Dovish matches: ['서비스', '중심', '둔화', '안정'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 부동산시장에서는 거래가 활발하지 않은 가운데 가격 오름세가제한되고 있음
# Dovish matches: [], Count: 0
# Hawkish matches: ['거래', '제한'], Count: 2
# Label: Hawkish
#
# Sentence: 금융시장에서는 외국인 증권투자자금 유입이 확대되는 가운데 주가가 상승하고 장단기 시장금리가 하락하였음.
# Dovish matches: ['투자자금', '하락'], Count: 2
# Hawkish matches: ['외국인', '상승', '장단기'], Count: 3
# Label: Hawkish
#
# Sentence: 주택담보대출은 대출금리 하락, 입주·분양물량 증가 등의 영향으로 증가규모가 소폭 확대되었음
# Dovish matches: ['하락', '증가', '증가'], Count: 3
# Hawkish matches: ['물량'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세 지속에 도움이 되는 방향으로 운용하되 국내외금융경제상황을 종합적으로 고려해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있는 가운데 미국,일본 등 주요 선진국 경제도 개선추세를 보이고 있다.
# Dovish matches: ['호조', '지속', '선진국', '개선', '추세'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 다만 남유럽국가들의 재정문제가 근본적으로 해결되지 않음에 따라 국제금융시장이 수시로 불안한 움직임을 나타낼 위험이 잠재하고 있다.
# Dovish matches: ['국가', '문제', '근본적', '해결', '국제', '위험'], Count: 6
# Hawkish matches: ['남유럽', '불안', '움직임', '위험'], Count: 4
# Label: Dovish
#
# Sentence: 국내 경기는 회복세가 뚜렷해지고 있는 모습이다.
# Dovish matches: ['회복세', '해지'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 건설투자가 여전히 부진하나 수출이 호조를 지속하고 설비투자와 소비도 꾸준히늘어나고 있으며 고용사정도 민간부문을 중심으로 개선되고 있다.
# Dovish matches: ['건설', '투자', '부진', '하나', '수출', '호조', '지속', '설비', '투자', '소비', '민간', '중심', '개선'], Count: 13
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내 경기의 회복세는 앞으로도 이어질 것으로 전망되나 해외 위험요인 등에 비추어 향후 성장경로의 불확실성은 상존하고 있는것으로 판단된다.
# Dovish matches: ['회복세', '해외', '위험요인', '비추', '성장', '경로'], Count: 6
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 이상기후에 따른 농축수산물가격 상승 등으로 오름세가 일시 확대되었다.
# Dovish matches: ['기후'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Label: Neutral
#
# Sentence: 앞으로 물가는 당분간 안정된 모습을 보일것이나 경기회복으로 수요압력이 점차 증대될 것으로 예상된다.
# Dovish matches: ['안정', '회복', '수요', '점차'], Count: 4
# Hawkish matches: ['압력'], Count: 1
# Label: Dovish
#
# Sentence: 부동산시장에서는 거래가 활발하지 않은 가운데 수도권을 중심으로주택매매가격이 약세를 나타내었다.
# Dovish matches: ['중심'], Count: 1
# Hawkish matches: ['거래', '약세'], Count: 2
# Label: Hawkish
#
# Sentence: 금융시장에서는 외국인 증권투자자금 유입 확대와 함께 장단기 시장금리가 하락하였으나 남유럽국가 재정문제 등으로 가격변수의변동성이 크게 확대되었다.
# Dovish matches: ['투자자금', '함께', '하락', '국가', '문제'], Count: 5
# Hawkish matches: ['외국인', '장단기', '였으나', '남유럽', '크'], Count: 5
# Label: Neutral
#
# Sentence: 주택담보대출은 대출금리 하락에도 불구하고 주택거래 부진 등의 영향으로 증가규모에 변화를 보이지않고 있다.
# Dovish matches: ['하락', '주택', '부진', '증가'], Count: 4
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 금융완화기조를 유지하면서 경기회복세 지속에도움이 되는 방향으로 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용', '수행'], Count: 8
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있는 가운데 미국,일본 등 주요 선진국 경제도 개선 움직임을 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '개선'], Count: 4
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 그러나일부 유럽국가의 재정문제로 인해 국제금융시장이 수시로 불안한모습을 나타내고 그 영향이 세계경제의 회복세에 미칠 위험이 잠재하고 있다.
# Dovish matches: ['국가', '문제', '국제', '회복세', '위험'], Count: 5
# Hawkish matches: ['불안', '위험'], Count: 2
# Label: Dovish
#
# Sentence: 국내경기는 상승세를 지속하고 있는 것으로 보인다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 소비, 투자 등내수의 증가세가 일시 주춤한 모습이나 수출이 호조를 지속하고고용사정도 민간부문을 중심으로 한층 개선되고 있다.
# Dovish matches: ['소비', '투자', '내수', '증가세', '수출', '호조', '지속', '민간', '중심', '개선'], Count: 10
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경기의 상승세는 앞으로도 이어질 것으로 전망되나 해외 위험요인 등에 비추어 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단된다.
# Dovish matches: ['해외', '위험요인', '비추', '성장', '경로'], Count: 5
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 석유류가격을 중심으로 오름세가 소폭 확대되었으며앞으로 경기상승세가 지속되면서 수요압력이 점차 증대될 것으로예상된다.
# Dovish matches: ['중심', '지속', '수요', '점차'], Count: 4
# Hawkish matches: ['압력'], Count: 1
# Label: Dovish
#
# Sentence: 부동산시장에서는 수도권을 중심으로 주택매매가격이 약세를 보이고 있다.
# Dovish matches: ['중심'], Count: 1
# Hawkish matches: ['약세'], Count: 1
# Label: Neutral
#
# Sentence: 금융시장에서는 일부 유럽국가 재정문제, 한반도의 지정학적 위험증대 등으로 주가와 환율 등 가격변수가 큰 폭으로 변동하였다.
# Dovish matches: ['국가', '문제', '위험'], Count: 3
# Hawkish matches: ['지정학', '위험', '환율'], Count: 3
# Label: Neutral
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않았음에도 불구하고 대출금리하락 등의 영향으로 증가규모가 소폭 확대되었다.
# Dovish matches: ['주택', '하락', '증가'], Count: 3
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 금융완화기조를 유지하면서 우리 경제가 물가안정의 기조 위에서 견조한 성장을 지속할 수 있도록 하는 방향으로 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해나갈 것이다.
# Dovish matches: ['금융', '완화', '유지', '안정', '견조', '성장', '지속', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.00%에서 2.25%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제의 호조가 지속되는 가운데 미국 등주요 선진국 경제도 대체로 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '회복세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 다만 일부유럽국가의 재정문제로 인한 국제금융시장 불안, 주요국 경기의변동성 확대 등이 수시로 재연될 위험성을 배제할 수 없다.
# Dovish matches: ['국가', '문제', '국제', '위험'], Count: 4
# Hawkish matches: ['불안', '재연', '위험', '배제'], Count: 4
# Label: Neutral
#
# Sentence: 국내경기는 상승세를 지속하고 있다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 수출이 높은 신장세를 보이고소비, 투자 등 내수가 꾸준히 증가하고 있으며 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['수출', '신장세', '소비', '투자', '내수', '증가', '민간', '중심', '개선', '추세'], Count: 10
# Hawkish matches: ['높'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승세를 이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 소비자물가는 상승률이 2%대 중후반에 머물고 있으나 앞으로 경기상승세 지속에 따른 수요압력 증대 등으로 상승압력이 계속 커질것으로 예상된다.
# Dovish matches: ['상승률', '지속', '수요'], Count: 3
# Hawkish matches: ['압력', '상승', '압력', '커질'], Count: 4
# Label: Hawkish
#
# Sentence: 부동산시장에서는 주택매매가격이 수도권은 하락하고 지방은 상승하는 추세가 지속되고 있다.
# Dovish matches: ['하락', '추세', '지속'], Count: 3
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 장기시장금리가 국내경기 상황 등을 반영하여 상승하였으며 주가와 환율은 해외 불안요인의 영향 등으로 큰 폭의변동을 나타내었다.
# Dovish matches: ['해외'], Count: 1
# Hawkish matches: ['상승', '환율'], Count: 2
# Label: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않았음에도 불구하고 낮은 대출금리 등의 영향으로 증가규모가 확대되었다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 금융완화기조를 유지하면서 우리 경제가 물가안정의 기조 위에서 견조한 성장을 지속할 수 있도록 하는 방향으로 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해나갈 것이다.
# Dovish matches: ['금융', '완화', '유지', '안정', '견조', '성장', '지속', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있는 가운데 주요선진국 경제도 대체로 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '회복세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 일부 유럽국가의재정문제로 인한 국제금융시장 불안은 완화되었으나 주요국 경기의변동성 확대 등이 위험요인으로 작용할 가능성을 배제할 수 없다.
# Dovish matches: ['국가', '문제', '국제', '완화', '위험요인'], Count: 5
# Hawkish matches: ['불안', '배제'], Count: 2
# Label: Dovish
#
# Sentence: 국내경기는 상승세를 지속하고 있다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 수출이 계속 호조를 보이고소비, 투자 등 내수가 꾸준히 증가하고 있으며 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['수출', '호조', '소비', '투자', '내수', '증가', '민간', '중심', '개선', '추세'], Count: 10
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승세를 이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 소비자물가는 상승률이 2%대 중후반에 머물고 있으나 앞으로 경기상승세 지속에 따른 수요압력 증대 등으로 상승압력이 계속 커질것으로 예상된다.
# Dovish matches: ['상승률', '지속', '수요'], Count: 3
# Hawkish matches: ['압력', '상승', '압력', '커질'], Count: 4
# Label: Hawkish
#
# Sentence: 부동산시장에서는 주택매매가격이 수도권은 하락하고 지방은 상승하는 추세가 지속되고 있다.
# Dovish matches: ['하락', '추세', '지속'], Count: 3
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 기준금리 인상의 영향 등으로 단기시장금리와 은행 여수신금리가 상승하였으며, 한편 외국인 증권투자자금이 큰 폭으로 유입되는 가운데 주가가 상승하였다.
# Dovish matches: ['여수신', '투자자금'], Count: 2
# Hawkish matches: ['기준금리', '인상', '상승', '외국인', '상승'], Count: 5
# Label: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않았음에도 불구하고 낮은 대출금리 등의 영향으로꾸준히 증가하였다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 금융완화기조하에서 견조한 성장을 지속하는 가운데 물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 미국 등의 성장세 둔화 움직임이 나타났으나 대체로 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '성장세', '둔화', '회복세'], Count: 6
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 주요국 경기의 변동성 확대 등이 세계경제의 위험요인으로 작용할 가능성이 있다.
# Dovish matches: ['위험요인'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경기는 상승세를 지속하고 있다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 수출이 계속 호조를 보이고소비가 꾸준히 증가하고 있으며 고용사정도 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['수출', '호조', '소비', '증가', '민간', '중심', '개선', '추세'], Count: 8
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승세를 이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 소비자물가는 상승률이 2%대 중후반 수준에 있으나 앞으로 경기상승세 지속에 따른 수요압력 증대 등으로 상승압력이 계속 커질 것으로 예상된다.
# Dovish matches: ['상승률', '지속', '수요'], Count: 3
# Hawkish matches: ['압력', '상승', '압력', '커질'], Count: 4
# Label: Hawkish
#
# Sentence: 부동산시장에서는 주택매매가격이 수도권은 하락하고 지방은 상승하는 현상이 지속되었다.
# Dovish matches: ['하락', '지속'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 단기시장금리와 은행 여수신금리가 상승세를 이어갔으나 외국인 채권투자자금 유입 등의 영향으로 장기시장금리는하락하였다.
# Dovish matches: ['여수신', '갔으나', '자금', '하락'], Count: 4
# Hawkish matches: ['외국인', '채권투자'], Count: 2
# Label: Dovish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않은 가운데 증가폭이 다소 줄어들었다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 금융완화기조하에서 견조한 성장을 지속하는 가운데 물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제는 미국 등의 경기회복 속도가 다소 둔화되고 있으나 대체로 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '회복', '둔화', '완만', '회복세'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 주요국 경기 및 환율의 변동성 확대 등이 세계경제의 위험요인으로 작용할 가능성이 있다.
# Dovish matches: ['위험요인'], Count: 1
# Hawkish matches: ['환율'], Count: 1
# Label: Neutral
#
# Sentence: 국내경기는 소비가 주춤하였으나 수출이 호조를 지속하고 설비투자가 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['소비', '수출', '호조', '지속', '설비', '투자', '증가', '유지'], Count: 8
# Hawkish matches: ['였으나', '상승'], Count: 2
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 농산물가격 급등 등으로 상승률이 높아졌으며 앞으로 경기상승이 이어지면서 수요측면의 상승압력이 지속될 것으로예상된다.
# Dovish matches: ['농산물', '상승률', '수요측면', '지속'], Count: 4
# Hawkish matches: ['높', '졌으며', '상승', '상승', '압력'], Count: 5
# Label: Hawkish
#
# Sentence: 부동산시장에서는 주택매매가격이 수도권은 하락하고지방은 상승하는 현상이 지속되었다.
# Dovish matches: ['하락', '지속'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 외국인증권투자자금 유입 확대 등의 영향으로 주가가 상승하고 환율과 시장금리가 하락하였다.
# Dovish matches: ['투자자금', '하락'], Count: 2
# Hawkish matches: ['외국인', '상승', '환율'], Count: 3
# Label: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않은 가운데서도 입주물량 증가 등으로 증가폭이 확대되었다.
# Dovish matches: ['주택', '증가', '증가'], Count: 3
# Hawkish matches: ['거래', '물량'], Count: 2
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 금융완화기조하에서 견조한 성장을 지속하는 가운데 물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.25%에서 2.50%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 대체로 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '완만', '회복세'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 주요국 경기및 환율의 변동성 확대 등이 세계경제의 위험요인으로 작용할 가능성을 배제할 수 없다.
# Dovish matches: ['위험요인'], Count: 1
# Hawkish matches: ['환율', '배제'], Count: 2
# Label: Hawkish
#
# Sentence: 국내경기는 설비투자가 주춤하였으나 수출이 호조를 지속하고 소비가 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['설비', '투자', '수출', '호조', '지속', '소비', '증가', '유지'], Count: 8
# Hawkish matches: ['였으나', '상승'], Count: 2
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 농산물가격을 중심으로 상승률이 더욱 높아졌다.
# Dovish matches: ['농산물', '중심', '상승률'], Count: 3
# Hawkish matches: ['높'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 채소류가격의 안정 등으로 물가상승률이 다소 낮아질 것이나경기상승이 이어지고 국제원자재 가격이 오르면서 상승압력이 지속될 것으로 예상된다.
# Dovish matches: ['안정', '상승률', '국제', '지속'], Count: 4
# Hawkish matches: ['상승', '오르', '상승', '압력'], Count: 4
# Label: Neutral
#
# Sentence: 부동산시장에서는 지방의 주택매매가격 상승세가 지속되는 가운데 수도권의 하락폭 축소 움직임이 나타났다.
# Dovish matches: ['지속', '하락', '축소'], Count: 3
# Hawkish matches: ['움직임'], Count: 1
# Label: Dovish
#
# Sentence: 금융시장에서는 외국인증권투자자금 유입이 지속되면서 주가가 상승하고 환율이 하락하였으며 장기시장금리는 큰 폭 하락 후 높은물가상승률의 영향 등으로 반등하였다.
# Dovish matches: ['투자자금', '지속', '하락', '하락', '상승률'], Count: 5
# Hawkish matches: ['외국인', '상승', '환율', '높'], Count: 4
# Label: Dovish
#
# Sentence: 주택담보대출은 주택거래가활발하지 않은 가운데서도 비교적 큰 폭의 증가를 지속하였다.
# Dovish matches: ['주택', '증가', '지속'], Count: 3
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 7
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.50%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 대체로 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '완만', '회복세'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 주요국 경기의 변동성 확대, 일부 유럽국가의 재정문제로 인한 국제금융시장불안 등이 세계경제의 위험요인으로 작용할 가능성을 배제할 수없다.
# Dovish matches: ['국가', '문제', '국제', '위험요인'], Count: 4
# Hawkish matches: ['불안', '배제'], Count: 2
# Label: Dovish
#
# Sentence: 국내경기는 상승기조를 유지하고 있는 것으로 판단된다.
# Dovish matches: ['유지'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Label: Neutral
#
# Sentence: 건설투자가 계속 부진하고 설비투자가 감소하였으나 수출이 호조를 지속하고 소비가 꾸준히 증가하고 있다.
# Dovish matches: ['건설', '투자', '부진', '설비', '투자', '감소', '수출', '호조', '지속', '소비', '증가'], Count: 11
# Hawkish matches: ['였으나'], Count: 1
# Label: Dovish
#
# Sentence: 고용사정은 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가는 채소류가격의 안정 등으로 상승률이 크게 낮아졌으나 앞으로 경기상승이 이어지고 국제 원자재 가격이 오르면서 상승압력이 지속될 것으로 예상된다.
# Dovish matches: ['안정', '상승률', '국제', '지속'], Count: 4
# Hawkish matches: ['크', '졌으나', '상승', '오르', '상승', '압력'], Count: 6
# Label: Hawkish
#
# Sentence: 부동산시장에서는 지방의 주택매매가격 상승세가 지속되고 수도권의 하락폭이 축소되었다.
# Dovish matches: ['지속', '하락', '축소'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융시장에서는 유럽 재정문제 재부각, 지정학적 위험 등으로 주가와 환율이 큰 폭의 변동을 나타내었다.
# Dovish matches: ['문제', '위험'], Count: 2
# Hawkish matches: ['지정학', '위험', '환율'], Count: 3
# Label: Hawkish
#
# Sentence: 장기시장금리는 국고채 발행물량 축소계획, 외국인채권매수 지속 등으로 하락하였다.
# Dovish matches: ['축소', '계획', '채권', '지속', '하락'], Count: 5
# Hawkish matches: ['국고채', '발행물량', '외국인', '채권', '매수'], Count: 5
# Label: Neutral
#
# Sentence: 주택담보대출은 주택거래가 다소 늘어난 가운데 증가폭이 확대되었다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 7
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.50%에서 2.75%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '완만', '회복세'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를지속할 것으로 전망되나 일부 유럽국가의 재정문제로 인한 국제금융시장 불안, 국제원자재가격의 변동성 확대 등이 위험요인으로 작용할 가능성을 배제할 수는 없다.
# Dovish matches: ['회복세', '지속', '국가', '문제', '국제', '국제', '위험요인'], Count: 7
# Hawkish matches: ['불안', '배제'], Count: 2
# Label: Dovish
#
# Sentence: 국내경기는 설비투자가 감소하였으나 수출이 호조를 지속하고 소비가 꾸준히 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['설비', '투자', '감소', '수출', '호조', '지속', '소비', '증가', '유지'], Count: 9
# Hawkish matches: ['였으나', '상승'], Count: 2
# Label: Dovish
#
# Sentence: 고용사정도민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 석유류 및 농산물 가격의 상승 등에 기인하여 지난달 3.5% 수준에 이르렀다.
# Dovish matches: ['상승률', '농산물'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 경기상승이 이어지고 국제원자재가격이 오르면서 물가상승압력이 지속되고 인플레이션 기대심리가 높아질 것으로 예상된다.
# Dovish matches: ['국제', '지속'], Count: 2
# Hawkish matches: ['상승', '오르', '상승', '압력', '인플레이션', '높'], Count: 6
# Label: Hawkish
#
# Sentence: 부동산시장에서는 전세가격 상승이 지속되는 가운데 주택매매가격은 지방에서는 오름세가 지속되고 수도권에서도 상승 움직임이 나타났다.
# Dovish matches: ['지속', '지속'], Count: 2
# Hawkish matches: ['상승', '상승', '움직임'], Count: 3
# Label: Hawkish
#
# Sentence: 금융시장에서는 외국인 주식투자자금 유입 확대, 지정학적 위험 완화 기대 등으로 주가가 크게 상승하고 환율은 하락하였다.
# Dovish matches: ['투자자금', '위험', '완화', '하락'], Count: 4
# Hawkish matches: ['외국인', '지정학', '위험', '크', '상승', '환율'], Count: 6
# Label: Hawkish
#
# Sentence: 장기시장금리는 물가상승 기대, 외국인의 채권 순매도 등의 영향으로 상승하였다.
# Dovish matches: ['채권'], Count: 1
# Hawkish matches: ['상승', '외국인', '채권', '상승'], Count: 4
# Label: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 늘어난 가운데 큰 폭으로 증가하였다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데물가안정기조가 확고히 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '운용', '수행'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.75%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제가 계속 호조를 나타내고 선진국경제도 회복세를 이어가고 있다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 지속할것으로 전망되나 국제원자재가격의 변동성 확대, 일부 유럽국가의 재정문제로 인한 국제금융시장 불안 등이 위험요인으로 남아 있다.
# Dovish matches: ['회복세', '지속', '국제', '국가', '문제', '국제', '위험요인'], Count: 7
# Hawkish matches: ['불안'], Count: 1
# Label: Dovish
#
# Sentence: 국내경기는 수출이 높은 신장세를 지속하고 내수가 꾸준히 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '신장세', '지속', '내수', '증가', '유지'], Count: 6
# Hawkish matches: ['높', '상승'], Count: 2
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 석유류 및 농산물 가격을 중심으로 크게 높아졌다.
# Dovish matches: ['상승률', '농산물', '중심'], Count: 3
# Hawkish matches: ['크', '높'], Count: 2
# Label: Dovish
#
# Sentence: 앞으로 경기상승이 이어지면서 높은 인플레이션 기대심리가유지되고 물가상승압력도 지속될 것으로 예상된다.
# Dovish matches: ['유지', '지속'], Count: 2
# Hawkish matches: ['상승', '높', '인플레이션', '상승', '압력'], Count: 5
# Label: Hawkish
#
# Sentence: 부동산시장에서는 전세가격이 계속 상승하였으며 주택매매가격은 지방에서 오름세가 지속되고 수도권에서도 상승 움직임을 보였다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: ['상승', '상승', '움직임'], Count: 3
# Label: Hawkish
#
# Sentence: 금융시장에서는 장기시장금리가 기준금리 인상, 물가상승 기대, 국고채 발행물량 증가 등의 영향으로 큰 폭 상승하였다.
# Dovish matches: ['증가'], Count: 1
# Hawkish matches: ['기준금리', '인상', '상승', '국고채', '발행물량', '상승'], Count: 6
# Label: Hawkish
#
# Sentence: 주가는 경기상승세에 힘입어 큰 폭 상승하였다가 반락하였으며 환율은 하락하였다.
# Dovish matches: ['힘입', '하락'], Count: 2
# Hawkish matches: ['상승', '다가', '반락', '환율'], Count: 4
# Label: Hawkish
#
# Sentence: 주택담보대출은 계절요인 등으로 소폭 증가에 그쳤다.
# Dovish matches: ['계절요인', '증가'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '운용', '수행'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.75%에서 3.00%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제가 계속 호조를 나타내고 선진국경제도 회복세를 이어가고 있다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 세계경제는 북아프리카•중동지역의 정정불안, 유가를 비롯한 국제원자재가격 상승, 일부유럽국가의 재정문제 등의 하방위험 요인이 있으나 회복세를 지속할 것으로 전망된다.
# Dovish matches: ['지역', '유가', '국제', '국가', '문제', '하방', '위험요인', '회복세', '지속'], Count: 9
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 국내경기는 수출이 높은 신장세를 지속하고 내수가 꾸준히 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '신장세', '지속', '내수', '증가', '유지'], Count: 6
# Hawkish matches: ['높', '상승'], Count: 2
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 석유류, 농축수산물 및 개인서비스 가격 상승등으로 지난달 4.5% 수준으로 높아졌다.
# Dovish matches: ['상승률'], Count: 1
# Hawkish matches: ['상승', '높'], Count: 2
# Label: Hawkish
#
# Sentence: 앞으로 경기상승으로 인한수요압력 증대, 국제원자재가격 불안, 인플레이션 기대심리 증대등으로 높은 물가오름세가 지속될 가능성이 있다.
# Dovish matches: ['수요', '국제', '지속'], Count: 3
# Hawkish matches: ['상승', '압력', '불안', '인플레이션', '높'], Count: 5
# Label: Hawkish
#
# Sentence: 주택매매가격은수도권에서 상승 움직임이 이어지고 지방에서는 오름세가 확대되었으며 전세가격은 계속 상승하였다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승', '움직임', '상승'], Count: 3
# Label: Hawkish
#
# Sentence: 금융시장에서는 해외위험요인, 물가오름세 확대 등의 영향으로 주가와 장기시장금리의 변동성이 증대되었다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 주택담보대출은 전월보다 증가폭이 다소 확대되었다.
# Dovish matches: ['전월', '보다', '증가'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는데 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '중점', '운용'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(3.00%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제가 계속 호조를 나타내고 선진국경제도 회복세를 이어가고 있다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 지속할 것으로 전망되나 북아프리카•중동지역의 정정불안, 일부 유럽국가의 재정문제, 일본 대지진 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '지속', '지역', '국가', '문제', '하방', '위험요인'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경기는 소비와 설비투자가 주춤하였으나 수출이 높은 신장세를 보인 데 힘입어 상승기조를 유지하고 있다.
# Dovish matches: ['소비', '설비', '투자', '수출', '신장세', '힘입', '유지'], Count: 7
# Hawkish matches: ['였으나', '높', '상승'], Count: 3
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 석유류 및 개인서비스 가격 상승 등으로 지난달 4.7% 수준에 이르렀다.
# Dovish matches: ['상승률'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Label: Neutral
#
# Sentence: 앞으로 경기상승으로 인한 수요압력증대, 국제원자재가격 불안, 인플레이션 기대심리 증대 등으로 높은 물가오름세가 지속될 가능성이 커지고 있다.
# Dovish matches: ['수요', '국제', '지속'], Count: 3
# Hawkish matches: ['상승', '압력', '불안', '인플레이션', '높', '커지'], Count: 6
# Label: Hawkish
#
# Sentence: 주택매매가격은 수도권에서 상승 움직임이 이어지고 지방에서는 오름세가 확대되었으며 전세가격은 계속 상승하였다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승', '움직임', '상승'], Count: 3
# Label: Hawkish
#
# Sentence: 금융시장에서는 해외위험요인의 영향으로 가격변수가 큰 폭의 등락을 보인 가운데 국내경기 상승세 등으로 주가는 최고 수준을 경신하고 환율은 크게 하락하였다.
# Dovish matches: ['해외', '위험요인', '하락'], Count: 3
# Hawkish matches: ['최고', '경신', '환율', '크'], Count: 4
# Label: Hawkish
#
# Sentence: 장기시장금리는 하락 후 소폭 반등하였다.
# Dovish matches: ['하락'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 주택담보대출은 전월보다 증가폭이 확대되었다.
# Dovish matches: ['전월', '보다', '증가'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는 데 보다 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '보다', '중점', '운용'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(3.00%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제가 계속 호조를 나타내고 선진국경제도 회복세를 이어가고 있다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 지속할 것으로 전망되나 일부 유럽국가의 재정문제, 북아프리카중동지역의 정정불안, 일본 대지진의 영향 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '지속', '국가', '문제', '지역', '하방', '위험요인'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경기는 수출이 계속 호조를 보이고 내수가 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '호조', '내수', '증가', '유지'], Count: 5
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 채소류가격의 하락 등으로 전월보다는 낮아졌으나, 앞으로 경기상승으로 인한 수요압력 증대, 국제유가 불안, 인플레이션 기대심리 증대 등으로 높은 물가오름세가 지속될 가능성이있다.
# Dovish matches: ['상승률', '하락', '전월', '보다', '수요', '국제', '유가', '지속'], Count: 8
# Hawkish matches: ['졌으나', '상승', '압력', '불안', '인플레이션', '높'], Count: 6
# Label: Dovish
#
# Sentence: 주택매매가격은 수도권에서 상승 움직임이 주춤하였으나 지방에서는 높은 오름세가 지속되었다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: ['상승', '움직임', '였으나', '높'], Count: 4
# Label: Hawkish
#
# Sentence: 전세가격은 계속 상승하였다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승'], Count: 1
# Label: Hawkish
#
# Sentence: 금융시장에서는 경기 상승세 지속, 외국인 투자자금 유입 등으로주가는 상승하고 환율은 하락하였다.
# Dovish matches: ['지속', '투자자금', '하락'], Count: 3
# Hawkish matches: ['외국인', '상승', '환율'], Count: 3
# Label: Neutral
#
# Sentence: 장기시장금리는 좁은 범위내에서 등락하는 모습을 보였다.
# Dovish matches: ['범위'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 주택담보대출은 전월보다 증가폭이확대되었다.
# Dovish matches: ['전월', '보다', '증가'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는 데 보다 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '보다', '중점', '운용'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 3.00%에서 3.25%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제를 보면 선진국 경제는 회복세가 다소 지연되는 모습을보였으나 신흥시장국 경제는 계속 호조를 나타내고 있다.
# Dovish matches: ['선진국', '회복세', '호조'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로세계경제는 회복세를 이어갈 것으로 전망되나 일부 유럽국가의 재정문제, 북아프리카•중동지역의 정정불안, 일본 대지진의 영향 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '국가', '문제', '지역', '하방', '위험요인'], Count: 6
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경기는 내수가 주춤하였으나 수출이 계속 높은 신장세를 보인데 힘입어 상승기조를 유지하고 있다.
# Dovish matches: ['내수', '수출', '신장세', '힘입', '유지'], Count: 5
# Hawkish matches: ['였으나', '높', '상승'], Count: 3
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 지난달에도 4%대 초반의 여전히 높은 수준을나타내었다.
# Dovish matches: ['상승률'], Count: 1
# Hawkish matches: ['초반', '높'], Count: 2
# Label: Hawkish
#
# Sentence: 앞으로 경기상승으로 인한 수요 증대, 인플레이션 기대심리 등으로 높은 물가상승압력이 이어질 것으로 예상된다.
# Dovish matches: ['수요'], Count: 1
# Hawkish matches: ['상승', '인플레이션', '높', '상승', '압력'], Count: 5
# Label: Hawkish
#
# Sentence: 근원인플레이션율은 그동안의 유가 및 농산물가격 상승 등의 영향이가공식품가격, 개인서비스요금 등에 파급되면서 3%대 중반으로 높아졌으며, 앞으로도 오름세가 지속될 가능성이 있다.
# Dovish matches: ['유가', '농산물', '요금', '지속'], Count: 4
# Hawkish matches: ['그동안', '상승', '높', '졌으며'], Count: 4
# Label: Neutral
#
# Sentence: 주택매매가격은 수도권에서는 상승 움직임이 멈추었으며 지방에서는 높은 오름세가 계속되었다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승', '움직임', '멈추', '높'], Count: 4
# Label: Hawkish
#
# Sentence: 전세가격은 계절적 비수기 등의 영향으로 전월보다 낮은 상승률을 보였다.
# Dovish matches: ['전월', '보다', '상승률'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융시장에서는 해외 위험요인의 영향 등으로 주가와 장기시장금리가 하락하고 환율은 상승하였다.
# Dovish matches: ['해외', '위험요인', '하락'], Count: 3
# Hawkish matches: ['환율', '상승'], Count: 2
# Label: Dovish
#
# Sentence: 주택담보대출은 전월보다는 증가폭이 축소되었으나 꾸준한 증가세를 나타내었다.
# Dovish matches: ['전월', '보다', '증가', '축소', '증가세'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는 데 보다 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '보다', '중점', '운용'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(3.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제는 계속 호조를 나타내었으나 미국 등 선진국 경제는 회복세가 일시 주춤하는 모습을 보였다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 이어갈 것으로 전망되나 유럽지역의 국가채무문제, 주요국 경기의 변동성 확대 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '지역', '국가', '채무', '문제', '하방', '위험요인'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경기는 수출이 견조한 신장세를 보이고 내수가 완만하게 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '견조', '신장세', '내수', '완만', '증가', '유지'], Count: 7
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 일부 농축산물가격의 큰 폭 상승에 주로 기인하여 지난달 4.4% 수준으로 높아졌다.
# Dovish matches: ['상승률', '농축산물'], Count: 2
# Hawkish matches: ['상승', '높'], Count: 2
# Label: Neutral
#
# Sentence: 앞으로 경기상승기조에따른 수요압력, 인플레이션 기대심리 등으로 높은 수준의 물가상승률이 이어질 것으로 예상된다.
# Dovish matches: ['수요', '상승률'], Count: 2
# Hawkish matches: ['상승', '압력', '인플레이션', '높'], Count: 4
# Label: Hawkish
#
# Sentence: 근원인플레이션율은 가공식품가격및 개인서비스요금이 계속 오르면서 3.7% 수준으로 상승하였으며당분간 오름세가 지속될 것으로 보인다.
# Dovish matches: ['요금', '지속'], Count: 2
# Hawkish matches: ['오르', '상승'], Count: 2
# Label: Neutral
#
# Sentence: 주택매매가격은 수도권에서는 약세를 나타내었으며 지방에서는 오름폭이 축소되었다.
# Dovish matches: ['축소'], Count: 1
# Hawkish matches: ['약세', '오름폭'], Count: 2
# Label: Hawkish
#
# Sentence: 전세가격은 계절적 비수기 등의 영향으로 상승률이 전월보다 낮아졌다.
# Dovish matches: ['상승률', '전월', '보다'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# ...
# Dovish matches: ['상승률', '하락', '상승률', '둔화'], Count: 4
# Hawkish matches: ['졌으며', '에너지제외지수'], Count: 2
# Label: Dovish
#
# Sentence: 단기 기대인플레이션율도 2.8%로 낮아졌다.
# Dovish matches: [], Count: 0
# Hawkish matches: [], Count: 0
# Label: Neutral
#
# Sentence: 앞으로물가상승률은 낮은 수요압력으로 안정된 흐름을 이어갈 것으로 예상된다.
# Dovish matches: ['상승률', '수요', '안정'], Count: 3
# Hawkish matches: ['압력'], Count: 1
# Label: Dovish
#
# Sentence: 소비자물가 상승률은 당분간 2%를 하회하면서 금년 상승률이 지난 8월 전망치(2.5%)를 소폭 하회할 것으로 보이며, 근원물가 상승률은 2% 내외의 안정세가 이어지면서 금년 상승률이 지난 전망(2.2%)에 부합할 것으로 예상된다.
# Dovish matches: ['상승률', '하회', '상승률', '전망치', '하회', '상승률', '내외', '안정세', '상승률', '부합'], Count: 10
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 내년도 상승률은 소비자물가 및 근원물가 모두 지난 전망치(2.1% 및 2.0%)에 대체로 부합할 것으로 보이지만 중동지역 리스크의 전개양상에 따른 국제유가 변동, 환율 움직임,공공요금 조정 등과 관련한 불확실성이 높은 상황이다.
# Dovish matches: ['상승률', '전망치', '부합', '국제', '유가', '조정'], Count: 6
# Hawkish matches: ['양상', '환율', '움직임', '높'], Count: 4
# Label: Dovish
#
# Sentence: 금융‧외환시장에서는 국내외 통화정책에 대한 기대 변화에 따라 장기 국고채금리가 하락하였다 반등하였고 원/달러 환율은 미 달러화 흐름, 지정학적 리스크등에 영향받아 등락하였다.
# Dovish matches: ['금융', '하락'], Count: 2
# Hawkish matches: ['외환시장', '국고채', '달러화', '지정학'], Count: 4
# Label: Hawkish
#
# Sentence: 주택시장은 수도권에서는 가격 상승세가 둔화되고거래량도 축소되었으며 지방에서는 부진이 이어졌다.
# Dovish matches: ['둔화', '축소', '부진'], Count: 3
# Hawkish matches: ['거래량'], Count: 1
# Label: Dovish
#
# Sentence: 이에 따라 가계대출 증가규모도 상당폭 축소되었다.
# Dovish matches: ['가계', '증가', '상당폭', '축소'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경제는 물가상승률이 목표수준에서 안정되고 완만한 성장세를 이어갈 것으로 예상되지만 성장 전망경로의 불확실성이 증대되었다.
# Dovish matches: ['상승률', '안정', '완만', '성장세', '성장', '경로'], Count: 6
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 금융안정 측면에서는 수도권 주택가격과 가계부채 증가세가 거시건전성정책 강화의 영향으로 점차 둔화될 것으로 보이지만 기준금리 인하가 가계부채에 미치는영향 등 관련 리스크에 여전히 유의할 필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '증가세', '건전성', '강화', '점차', '둔화', '인하', '가계', '부채'], Count: 11
# Hawkish matches: ['기준금리', '인하'], Count: 2
# Label: Dovish
#
# Sentence: 따라서 향후 통화정책은 물가, 성장, 금융안정 등 정책변수 간 상충관계를 면밀히 점검하면서 앞으로의 인하 속도 등을 신중히 결정해 나갈 것이다.
# Dovish matches: ['성장', '금융안정', '상충관계', '면밀히', '점검', '인하'], Count: 6
# Hawkish matches: ['따라서', '성장', '인하', '결정'], Count: 4
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의3.25% 수준에서 3.00%로 하향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['하향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 환율 변동성이 확대되었지만, 물가상승률의 안정세와 가계부채의 둔화 흐름이 이어지는가운데 성장의 하방압력이 증대되었다.
# Dovish matches: ['상승률', '안정세', '가계', '부채', '둔화', '성장', '하방'], Count: 7
# Hawkish matches: ['환율', '성장', '압력'], Count: 3
# Label: Dovish
#
# Sentence: 이에 따라 기준금리를 추가 인하하여 경기의 하방리스크를 완화하는 것이 적절하다고 판단하였다.
# Dovish matches: ['인하', '하방', '완화'], Count: 3
# Hawkish matches: ['기준금리', '인하', '적절'], Count: 3
# Label: Neutral
#
# Sentence: 세계경제는 미국 신정부의 경제정책 향방에 따른 경기 및 인플레이션의 불확실성이 증대되었다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['인플레이션'], Count: 1
# Label: Hawkish
#
# Sentence: 국제금융시장에서는 주요국의 정책금리 인하 기조가 이어졌지만 미 장기 국채금리가 큰 폭 상승하고 달러화도 상당폭 강세를 나타내었다.
# Dovish matches: ['국제', '인하', '상당폭'], Count: 3
# Hawkish matches: ['인하', '국채', '상승', '달러화', '강세'], Count: 5
# Label: Hawkish
#
# Sentence: 앞으로 세계경제와 국제금융시장은 미국 신정부의 경제정책 추진양상, 주요국 통화정책 변화, 지정학적 리스크 등에 영향받을 것으로 보인다.
# Dovish matches: ['국제', '추진'], Count: 2
# Hawkish matches: ['양상', '지정학'], Count: 2
# Label: Neutral
#
# Sentence: 국내경제는 내수 회복세가 완만한 가운데 수출 증가세가 둔화되면서 성장 흐름이 약화되었다.
# Dovish matches: ['내수', '회복세', '완만', '수출', '증가세', '둔화', '성장', '약화'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Label: Dovish
#
# Sentence: 고용은 실업률이 낮은 수준을 보이고 있지만 취업자수 증가규모는 점차 둔화되는 모습이다.
# Dovish matches: ['증가', '점차', '둔화'], Count: 3
# Hawkish matches: ['실업률'], Count: 1
# Label: Dovish
#
# Sentence: 앞으로도 국내경제는 소비가 완만한 회복세를 이어가겠으나 수출 증가세는 주력 업종에서의 경쟁 심화, 보호무역주의 강화 등으로당초 예상보다 낮아질 것으로 보인다.
# Dovish matches: ['소비', '완만', '회복세', '수출', '증가세', '주력업종', '심화', '강화', '보다'], Count: 9
# Hawkish matches: ['보호무역주의'], Count: 1
# Label: Dovish
#
# Sentence: 이에 따라 금년 및 내년 성장률이 각각지난 8월 전망치(2.4% 및 2.1%)를 하회하는 2.2% 및 1.9%를 나타낼 것으로 예상된다.
# Dovish matches: ['성장률', '전망치', '하회'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 다만 이러한 성장경로에는 통상환경 변화 및 IT 수출 흐름, 내수 회복 속도 등과 관련한 불확실성이 높은 상황이다.
# Dovish matches: ['성장', '경로', '통상', '환경변화', '수출', '내수', '회복'], Count: 7
# Hawkish matches: ['성장', '높'], Count: 2
# Label: Dovish
#
# Sentence: 국내 물가는 안정세를 지속하였다.
# Dovish matches: ['안정세', '지속'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 10월중 소비자물가 상승률이 석유류가격 하락에 따라 일시적으로 크게 낮아져 1.3%를 기록하였으며 근원물가 상승률(식료품및 에너지 제외 지수)도 1.8%로 둔화되었다.
# Dovish matches: ['상승률', '하락', '상승률', '둔화'], Count: 4
# Hawkish matches: ['크', '에너지제외지수'], Count: 2
# Label: Dovish
#
# Sentence: 단기 기대인플레이션율은 전월과 같은 수준(2.8%)을 유지하였다.
# Dovish matches: ['전월', '유지'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 물가상승률은 환율 상승이 상방압력으로 작용하겠지만 국제유가 하락, 낮은 수요압력 등으로 안정세를 이어갈 것으로 예상된다.
# Dovish matches: ['상승률', '국제', '유가', '하락', '수요', '안정세'], Count: 6
# Hawkish matches: ['환율', '상승', '압력', '압력'], Count: 4
# Label: Dovish
#
# Sentence: 이에 따라 금년 및 내년 소비자물가 상승률은 각각 2.3%, 1.9%로 지난 전망치(2.5%, 2.1%)를 하회할 전망이다.
# Dovish matches: ['상승률', '전망치', '하회'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 근원물가 상승률은 금년은 지난 전망에 부합하는 2.2%로, 내년은 지난 전망(2.0%)보다 소폭 낮은 1.9%로 예상된다.
# Dovish matches: ['상승률', '부합', '보다'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 향후 물가경로는 환율 및 국제유가 움직임, 국내외 경기 흐름, 공공요금 조정 등에 영향받을 것으로 보인다.
# Dovish matches: ['경로', '국제', '유가', '조정'], Count: 4
# Hawkish matches: ['환율', '움직임'], Count: 2
# Label: Dovish
#
# Sentence: 금융·외환시장에서는 국고채금리가 큰 폭 상승한 미 국채금리와 차별화된 움직임을 보이며 하락하였고 원/달러 환율은 미 달러화 강세에 영향받아 상당폭 상승하였다.
# Dovish matches: ['금융', '차별화', '하락', '상당폭'], Count: 4
# Hawkish matches: ['외환시장', '국고채', '상승', '한미', '국채', '움직임', '달러화', '강세', '상승'], Count: 9
# Label: Hawkish
#
# Sentence: 주가는 주요 기업의 실적 전망 둔화 등으로 하락하였다.
# Dovish matches: ['기업', '실적', '둔화', '하락'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 주택가격은수도권에서는 상승폭이 축소되고 지방에서는 하락세가 이어졌다.
# Dovish matches: ['축소'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Label: Neutral
#
# Sentence: 가계대출은 계절적 요인 등으로 증가규모가 소폭 확대되었지만 거시건전성정책의 영향이 이어지면서 주택관련대출을 중심으로 당분간 둔화 추세를 이어갈 것으로 판단된다.
# Dovish matches: ['가계', '증가', '건전성', '주택', '중심', '둔화', '추세'], Count: 7
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경제는 물가상승률이 안정되는 가운데 성장경로의 불확실성은 높은 것으로 판단된다.
# Dovish matches: ['상승률', '안정', '성장', '경로'], Count: 4
# Hawkish matches: ['성장', '높'], Count: 2
# Label: Dovish
#
# Sentence: 금융안정 측면에서는 가계부채 둔화 흐름이 당분간 이어질 것으로 예상되지만 환율이 높은 변동성을 나타낼 가능성에 유의할 필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '둔화'], Count: 4
# Hawkish matches: ['환율', '높'], Count: 2
# Label: Dovish
#
# Sentence: 따라서 향후 통화정책은 금리인하가 물가와 성장, 가계부채와 환율등 금융안정에 미치는 영향과 정책변수 간 상충관계를 면밀히 점검하면서 앞으로의 인하 속도 등을 결정해 나갈 것이다.
# Dovish matches: ['인하', '성장', '가계', '부채', '금융안정', '상충관계', '면밀히', '점검', '인하'], Count: 9
# Hawkish matches: ['따라서', '인하', '성장', '환율', '인하', '결정'], Count: 6
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의3.00% 수준에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 물가상승률 안정세와가계부채 둔화 흐름이 이어지는 가운데, 예상치 못한 정치적 리스크 확대로 성장의 하방위험이 커지고 환율 변동성이 증대되었다.
# Dovish matches: ['상승률', '안정세', '가계', '부채', '둔화', '성장', '하방', '위험'], Count: 8
# Hawkish matches: ['정치', '성장', '위험', '커지', '환율'], Count: 5
# Label: Dovish
#
# Sentence: 향후 국내 정치 상황과 주요국 경제정책의 변화에 따라 경제전망 및 외환시장의 불확실성이 커진 만큼 현재의 기준금리 수준을 유지하면서 대내외 여건 변화를 좀 더 점검하는 것이 적절하다고 판단하였다.
# Dovish matches: ['유지', '점검'], Count: 2
# Hawkish matches: ['정치', '외환시장', '커진', '만큼', '기준금리', '적절'], Count: 6
# Label: Hawkish
#
# Sentence: 세계경제는 국가별로 경기 흐름이 차별화되는 가운데 미국 신정부의 경제정책향방 및 연준의 금리인하 속도, 주요국의 정치 상황 등에 따른 성장 및 물가 전망의 불확실성이 증대되었다.
# Dovish matches: ['국가', '차별화', '인하', '성장'], Count: 4
# Hawkish matches: ['연준', '인하', '정치', '성장'], Count: 4
# Label: Neutral
#
# Sentence: 이에 영향받아 국제금융시장에서는 미 달러화가강세 흐름을 지속하고 장기 국채금리가 상승하는 등 주요 가격변수의 변동성이확대되었다.
# Dovish matches: ['국제', '지속'], Count: 2
# Hawkish matches: ['달러화', '강세', '국채', '상승'], Count: 4
# Label: Hawkish
#
# Sentence: 앞으로 세계경제와 국제금융시장은 미국 신정부의 경제정책 추진양상, 주요국의 통화정책 및 정치 상황, 지정학적 리스크 등에 영향받을 것으로 보인다.
# Dovish matches: ['국제', '추진'], Count: 2
# Hawkish matches: ['양상', '정치', '지정학'], Count: 3
# Label: Hawkish
#
# Sentence: 국내경제는 12월중 수출 증가율이 다소 높아졌으나 소비 회복세가 약화되고 건설투자 부진이 이어졌다.
# Dovish matches: ['수출', '증가율', '소비', '회복세', '약화', '건설', '투자', '부진'], Count: 8
# Hawkish matches: ['높', '졌으나'], Count: 2
# Label: Dovish
#
# Sentence: 고용은 취업자수 증가규모가 줄어드는 등 둔화 흐름을이어갔다.
# Dovish matches: ['증가', '둔화'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경제는 수출 증가세가 둔화되고 소비심리 위축 등으로 내수 회복세가 예상보다 더딜 것으로 보인다.
# Dovish matches: ['수출', '증가세', '둔화', '소비', '위축', '내수', '회복세', '보다', '더딜'], Count: 9
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 지난해 및 금년 성장률은 11월 전망치(24년 2.2%, 25년 1.9%)를 하회할 가능성이 큰 것으로 보이며, 향후 성장경로에는 국내 정치 상황 변화, 정부의 경기대응책, 미 신정부의 정책방향 등과 관련한불확실성이 높은 상황이다.
# Dovish matches: ['지난해', '성장률', '전망치', '하회', '성장', '경로', '정부'], Count: 7
# Hawkish matches: ['성장', '정치', '높'], Count: 3
# Label: Dovish
#
# Sentence: 국내 물가는 안정세를 지속하였다.
# Dovish matches: ['안정세', '지속'], Count: 2
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 12월중 소비자물가 상승률이 석유류가격 상승등으로 1.9%로 높아졌지만 근원물가 상승률(식료품 및 에너지 제외 지수)은 1.8%로소폭 낮아졌다.
# Dovish matches: ['상승률', '상승률'], Count: 2
# Hawkish matches: ['상승', '높', '에너지제외지수'], Count: 3
# Label: Hawkish
#
# Sentence: 단기 기대인플레이션율은 2%대 후반 수준을 지속하였다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로물가상승률은 낮은 수요압력 등으로 안정적인 흐름을 이어갈 것으로 예상되지만높아진 환율이 상방요인으로 작용할 것으로 보이며, 국제유가 움직임, 국내외 경기 흐름 등과 관련한 불확실성이 커진 상황이다.
# Dovish matches: ['상승률', '수요', '안정', '국제', '유가'], Count: 5
# Hawkish matches: ['압력', '높', '환율', '움직임', '커진'], Count: 5
# Label: Neutral
#
# Sentence: 금융‧외환시장에서는 원/달러 환율이 국내 정치 불확실성 증대, 미 연준의 금리인하 속도 조절 가능성 등의 영향으로 큰 폭 상승하였다.
# Dovish matches: ['금융', '인하'], Count: 2
# Hawkish matches: ['외환시장', '정치', '미연준', '인하', '속도조절', '상승'], Count: 6
# Label: Hawkish
#
# Sentence: 주가는 상당폭 조정되었다가 금년 들어 반등하였고, 장기 국고채금리는 경기둔화 우려 등으로 하락하였다.
# Dovish matches: ['상당폭', '조정', '둔화', '하락'], Count: 4
# Hawkish matches: ['다가', '국고채', '우려'], Count: 3
# Label: Dovish
#
# Sentence: 가계대출은 주택거래 감소 등의 영향으로 둔화 추세를 지속하였으며 전국주택가격은 하락 전환하였다.
# Dovish matches: ['가계', '주택', '감소', '둔화', '추세', '지속', '전국', '하락', '전환'], Count: 9
# Hawkish matches: ['거래'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경제는 물가상승률이 안정적인 흐름을 이어가고 있으나정치적 리스크 확대로 성장의 하방위험이 증대되고 경제전망의 불확실성도 커진상황이다.
# Dovish matches: ['상승률', '안정', '성장', '하방', '위험'], Count: 5
# Hawkish matches: ['정치', '성장', '위험', '커진'], Count: 4
# Label: Dovish
#
# Sentence: 금융안정 측면에서는 가계부채 둔화 추세가 당분간 이어질 것으로 보이지만 환율 변동성 확대가 물가와 금융안정에 미치는 영향에 대해서는 유의할필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '둔화', '추세', '금융안정'], Count: 6
# Hawkish matches: ['환율'], Count: 1
# Label: Dovish
#
# Sentence: 따라서 향후 통화정책은 국내 정치 상황 및 대내외 경제정책 변화와 이에 따른 물가, 가계부채 및 환율의 흐름을 면밀히 점검하면서 성장의 하방리스크가 완화될 수 있도록 기준금리의 추가 인하 시기 및 속도 등을 결정해 나갈 것이다.
# Dovish matches: ['가계', '부채', '면밀히', '점검', '성장', '하방', '완화', '인하'], Count: 8
# Hawkish matches: ['따라서', '정치', '환율', '성장', '기준금리', '인하', '결정'], Count: 7
# Label: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의3.00% 수준에서 2.75%로 하향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['하향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Label: Dovish
#
# Sentence: 외환시장의 경계감이 여전하지만 물가상승률 안정세와 가계부채 둔화 흐름이 지속되는가운데 성장률이 크게 낮아질 것으로 전망되는 만큼 기준금리를 추가 인하하여경기 하방압력을 완화하는 것이 적절하다고 판단하였다.
# Dovish matches: ['상승률', '안정세', '가계', '부채', '둔화', '지속', '성장률', '인하', '하방', '완화'], Count: 10
# Hawkish matches: ['외환시장', '경계감', '여전', '크', '만큼', '기준금리', '인하', '압력', '적절'], Count: 9
# Label: Dovish
#
# Sentence: 세계경제는 미국 관세정책 등의 영향으로 성장의 하방위험이 확대되고 물가경로의 불확실성도 높아졌다.
# Dovish matches: ['성장', '하방', '위험', '경로'], Count: 4
# Hawkish matches: ['성장', '위험', '높'], Count: 3
# Label: Dovish
#
# Sentence: 국제금융시장에서는 그간 크게 확대되었던 미 신정부경제정책에 대한 우려가 다소 완화되고 러시아‧우크라이나 종전 가능성이 부각되면서 미 달러화 강세 흐름이 일부 되돌려지고 주요국의 장기 국채금리는 하락하였다.
# Dovish matches: ['국제', '완화', '하락'], Count: 3
# Hawkish matches: ['그간', '크', '우려', '러시아', '달러화', '강세', '국채'], Count: 7
# Label: Hawkish
#
# Sentence: 앞으로 세계경제와 국제금융시장은 미국의 관세정책 추진 상황, 주요국의 통화정책 변화, 지정학적 리스크 등에 영향받을 것으로 보인다.
# Dovish matches: ['국제', '추진'], Count: 2
# Hawkish matches: ['지정학'], Count: 1
# Label: Dovish
#
# Sentence: 국내 경제상황을 보면 비상계엄 사태에 따른 정치 불확실성 확대, 기상여건 악화 등으로 소비가 부진한 가운데 수출 증가세가 약화되었다.
# Dovish matches: ['기상', '악화', '소비', '부진', '수출', '증가세', '약화'], Count: 7
# Hawkish matches: ['비상계엄', '사태', '정치'], Count: 3
# Label: Dovish
#
# Sentence: 고용은 주요 업종의 취업자수 감소세가 이어지는 등 둔화 흐름을 지속하였다.
# Dovish matches: ['업종', '감소세', '둔화', '지속'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 국내경제는경제심리 위축, 미국의 관세정책 등의 영향으로 내수 회복세와 수출 증가세가당초 예상보다 낮을 것으로 예상된다.
# Dovish matches: ['위축', '내수', '회복세', '수출', '증가세', '보다'], Count: 6
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 이에 따라 금년 성장률은 지난 11월 전망치(1.9%)를 큰 폭 하회하는 1.5%로 전망된다.
# Dovish matches: ['성장률', '전망치', '하회'], Count: 3
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 향후 성장경로에는 주요국 통상정책과 미 연준의 통화정책 방향, 국내 정치 상황 변화 및 정부의 경기부양책 등과 관련한 불확실성이 높은 상황이다.
# Dovish matches: ['성장', '경로', '통상', '정부'], Count: 4
# Hawkish matches: ['성장', '미연준', '정치', '높'], Count: 4
# Label: Neutral
#
# Sentence: 소비자물가 상승률은 국제유가 및 환율 상승의 영향으로 1월중 2.2%로 높아졌으나 근원물가 상승률(식료품 및 에너지 제외 지수)은 1.9%로 안정세를 이어갔다.
# Dovish matches: ['상승률', '국제', '유가', '상승률', '안정세'], Count: 5
# Hawkish matches: ['환율', '상승', '높', '졌으나', '에너지제외지수'], Count: 5
# Label: Neutral
#
# Sentence: 단기 기대인플레이션율은 2월중 2.7%로 소폭 하락하였다.
# Dovish matches: ['하락'], Count: 1
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 앞으로 물가상승률은환율이 상방요인으로 작용하겠지만 낮은 수요압력 등의 영향으로 2% 내외의 안정적인 흐름을 지속할 것으로 보인다.
# Dovish matches: ['상승률', '수요', '내외', '안정', '지속'], Count: 5
# Hawkish matches: ['환율', '압력'], Count: 2
# Label: Dovish
#
# Sentence: 이에 따라 금년중 소비자물가 상승률은지난해 11월 전망(1.9%)에 부합하는 1.9%로 전망되며, 근원물가 상승률은 지난전망치(1.9%)를 소폭 하회하는 1.8%로 예상된다.
# Dovish matches: ['상승률', '지난해', '부합', '상승률', '전망치', '하회'], Count: 6
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 향후 물가경로는 환율 및 국제유가 움직임, 국내외 경기 흐름, 정부의 물가안정 대책 등에 영향받을 것으로 보인다.
# Dovish matches: ['경로', '국제', '유가', '정부', '안정'], Count: 5
# Hawkish matches: ['환율', '움직임'], Count: 2
# Label: Dovish
#
# Sentence: 금융·외환시장에서는 원/달러 환율이 국내 정치 불확실성, 미국의 관세정책 및연준 통화정책에 대한 기대 변화 등에 영향받으며 높은 변동성을 이어가다 하락하였다.
# Dovish matches: ['금융', '하락'], Count: 2
# Hawkish matches: ['외환시장', '정치', '연준', '높'], Count: 4
# Label: Hawkish
#
# Sentence: 장기 국고채금리는 국내외 금리인하 기대에 주로 영향받아 하락 후 반등하였다.
# Dovish matches: ['인하', '하락'], Count: 2
# Hawkish matches: ['국고채', '인하'], Count: 2
# Label: Neutral
#
# Sentence: 주택가격은 서울을 제외한 대부분 지역에서 하락하였고 가계대출 증가규모도 둔화 추세를 이어갔다.
# Dovish matches: ['제외', '지역', '하락', '가계', '증가', '둔화', '추세'], Count: 7
# Hawkish matches: ['서울'], Count: 1
# Label: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 국내경제는 물가상승률이 안정적인 흐름을 이어가는 가운데낮은 성장세가 당분간 지속될 것으로 전망된다.
# Dovish matches: ['상승률', '안정', '성장세', '지속'], Count: 4
# Hawkish matches: [], Count: 0
# Label: Dovish
#
# Sentence: 금융안정 측면에서는 가계부채둔화 추세가 이어질 것으로 보이지만 금리하락 기조로 인한 재확대 가능성과 높은 환율 변동성에는 유의할 필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '둔화', '추세', '하락'], Count: 6
# Hawkish matches: ['높', '환율'], Count: 2
# Label: Dovish
#
# Sentence: 따라서 향후 통화정책은 대내외 경제정책 및 국내 정치 상황의 변화, 그간의 금리 인하가 물가, 성장 및 금융안정 상황에 미치는 영향 등을 면밀히 점검하면서 앞으로의 기준금리 추가 인하 시기및 속도 등을 결정해 나갈 것이다.
# Dovish matches: ['인하', '성장', '금융안정', '면밀히', '점검', '인하'], Count: 6
# Hawkish matches: ['따라서', '정치', '그간', '인하', '성장', '기준금리', '인하', '결정'], Count: 8
# Label: Hawkish
# 라벨링 완료! 결과는 'labeled_sentences.csv' 파일에 저장되었습니다.

# %% [markdown]
# ### 나이브베이즈 분류기로 학습 및 평균 정확도 계산

# %%
import pandas as pd
import numpy as np
from ekonlpy.tag import Mecab
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import logging

# 로깅 설정 (디버깅용)
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger(__name__)

# ekonlpy의 Mecab 토크나이저 객체 생성
mecab = Mecab()

# 1. 데이터 로드
try:
    df = pd.read_csv('문장라벨.csv')  # 수작업으로 라벨링된 데이터
except FileNotFoundError as e:
    print(f"파일 로드 오류: {e}")
    exit()

# 결측값 처리
df['sentence'] = df['sentence'].fillna('')
df['Label'] = df['Label'].fillna('Neutral')

# 2. Hawkish와 Dovish 문장만 필터링 (이진 분류)
binary_df = df[df['Label'].isin(['Hawkish', 'Dovish'])].copy()
logger.info(f"Hawkish와 Dovish 문장 수: {len(binary_df)}")

# 3. 토큰화 함수 정의
def tokenize(text):
    return mecab.morphs(text)

# 4. 나이브 베이즈 분류 실험
n_iterations = 30
accuracies = []

# TF-IDF 벡터라이저 설정
vectorizer = TfidfVectorizer(tokenizer=tokenize, lowercase=False)

# 30회 반복 실험
for i in range(n_iterations):
    # 60% 학습 데이터, 40% 테스트 데이터 분할
    X_train, X_test, y_train, y_test = train_test_split(
        binary_df['sentence'], binary_df['Label'], 
        test_size=0.4, random_state=i, stratify=binary_df['Label']
    )

    # TF-IDF 벡터화
    X_train_tfidf = vectorizer.fit_transform(X_train)
    X_test_tfidf = vectorizer.transform(X_test)

    # 나이브 베이즈 분류기 학습
    nb_classifier = MultinomialNB()
    nb_classifier.fit(X_train_tfidf, y_train)

    # 테스트 데이터로 예측
    y_pred = nb_classifier.predict(X_test_tfidf)

    # 정확도 계산
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)
    logger.info(f"Iteration {i+1}: Accuracy = {accuracy:.4f}")

# 5. 평균 정확도 계산
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
logger.info(f"\n평균 정확도: {mean_accuracy:.4f}")
logger.info(f"표준편차: {std_accuracy:.4f}")

# 6. 결과 평가
if mean_accuracy >= 0.86:
    logger.info("분류기의 평균 정확도가 약 86%로 기준 이상(above par)입니다.")
else:
    logger.info("분류기의 평균 정확도가 기준(86%)에 미치지 못합니다.")

# 7. 결과 저장 (필요 시)
results_df = pd.DataFrame({
    'Iteration': range(1, n_iterations+1),
    'Accuracy': accuracies
})
results_df.to_csv('재실험.csv', index=False, encoding='utf-8-sig')
logger.info("실험 결과가 'nbc_classification_results.csv' 파일에 저장되었습니다.")
# Out:
# Hawkish와 Dovish 문장 수: 2239
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 1: Accuracy = 0.9051
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 2: Accuracy = 0.8996
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 3: Accuracy = 0.8984
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 4: Accuracy = 0.8973
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 5: Accuracy = 0.8951
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 6: Accuracy = 0.8895
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 7: Accuracy = 0.8962
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 8: Accuracy = 0.9040
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 9: Accuracy = 0.9096
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 10: Accuracy = 0.9007
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 11: Accuracy = 0.8996
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 12: Accuracy = 0.9018
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 13: Accuracy = 0.8895
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 14: Accuracy = 0.8973
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 15: Accuracy = 0.8862
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 16: Accuracy = 0.9018
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 17: Accuracy = 0.9007
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 18: Accuracy = 0.8873
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 19: Accuracy = 0.8917
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 20: Accuracy = 0.9018
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 21: Accuracy = 0.9040
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 22: Accuracy = 0.9018
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 23: Accuracy = 0.9007
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 24: Accuracy = 0.8873
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 25: Accuracy = 0.8940
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 26: Accuracy = 0.9007
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 27: Accuracy = 0.9051
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 28: Accuracy = 0.8917
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 29: Accuracy = 0.8984
# c:\Users\yoons\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Iteration 30: Accuracy = 0.8940
#
# 평균 정확도: 0.8977
# 표준편차: 0.0059
# 분류기의 평균 정확도가 약 86%로 기준 이상(above par)입니다.
# 실험 결과가 'nbc_classification_results.csv' 파일에 저장되었습니다.

# %% [markdown]
# ### 말이 안되는 점수인데? 오류가 난게 분명하다
#
# 라벨링한 데이터를 갖고 하나하나 살펴보며, 수작업으로 라벨링을 진행

# %%
import pandas as pd
from ekonlpy.tag import Mecab
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import logging

# 로깅 설정 (디버깅용)
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger(__name__)

# ekonlpy의 Mecab 토크나이저 객체 생성
mecab = Mecab()

# 1. 감정 사전 로드 및 전처리
try:
    dovish_dict = pd.read_csv('final_dovish.csv')
    hawkish_dict = pd.read_csv('final_hawkish.csv')
except FileNotFoundError as e:
    print(f"파일 로드 오류: {e}")
    exit()

dovish_dict = dovish_dict.dropna(subset=['Dovish'])
hawkish_dict = hawkish_dict.dropna(subset=['Hawkish'])

dovish_words = set(dovish_dict['Dovish'].str.strip())
hawkish_words = set(hawkish_dict['Hawkish'].str.strip())

logger.info(f"Dovish words (sample): {list(dovish_words)[:10]}")
logger.info(f"Hawkish words (sample): {list(hawkish_words)[:10]}")

# 2. 테스트 데이터 로드
try:
    test_df = pd.read_csv('문장라벨.csv')
except FileNotFoundError:
    print("새로운 테스트 데이터 파일이 없습니다. 기존 데이터에서 추출합니다.")
    labeled_df = pd.read_csv('labeled_sentences.csv')
    test_df = labeled_df.sample(frac=0.2, random_state=42)
    test_df = test_df[test_df['Label'].isin(['Hawkish', 'Dovish'])].copy()

test_df['sentence'] = test_df['sentence'].fillna('')
test_df['Label'] = test_df['Label'].fillna('Neutral')

test_df = test_df[test_df['Label'].isin(['Hawkish', 'Dovish'])].copy()
logger.info(f"테스트 데이터 크기: {len(test_df)} 문장")
logger.info(f"테스트 데이터 클래스 분포:\n{test_df['Label'].value_counts()}")

# 3. 문장을 라벨링하는 함수 정의 (디버깅 포함)
def label_sentence(sentence):
    tokens = mecab.morphs(sentence)
    dovish_matched = [t for t in tokens if t in dovish_words]
    hawkish_matched = [t for t in tokens if t in hawkish_words]
    dovish_count = len(dovish_matched)
    hawkish_count = len(hawkish_matched)
    logger.info(f"Sentence: {sentence}")
    logger.info(f"Dovish matches: {dovish_matched}, Count: {dovish_count}")
    logger.info(f"Hawkish matches: {hawkish_matched}, Count: {hawkish_count}")
    if hawkish_count > dovish_count:
        label = 'Hawkish'
    elif dovish_count > hawkish_count:
        label = 'Dovish'
    else:
        label = 'Neutral'
    logger.info(f"Predicted: {label}\n")
    return label

# 4. 예측 수행
test_df['Predicted_Label'] = test_df['sentence'].apply(label_sentence)

# 중립 제외 로직 제거 (필요 시 주석 해제)
# test_df = test_df[test_df['Predicted_Label'].isin(['Hawkish', 'Dovish'])].copy()
logger.info(f"최종 예측 데이터 크기: {len(test_df)} 문장")
logger.info(f"예측 라벨 클래스 분포:\n{test_df['Predicted_Label'].value_counts()}")

# 5. 평가 지표 계산
true_labels = test_df['Label'].values
pred_labels = test_df['Predicted_Label'].values

# 예측과 실제 라벨 비교 (일부만 출력)
for idx, (true, pred) in enumerate(zip(true_labels[:10], pred_labels[:10])):
    logger.info(f"Sample {idx+1}: True={true}, Predicted={pred}")

# 중립 예측이 포함된 경우 제외 (필요 시 조정)
eval_df = test_df[test_df['Predicted_Label'].isin(['Hawkish', 'Dovish'])].copy()
if len(eval_df) == 0:
    logger.info("평가할 데이터가 없습니다. 모든 예측이 중립(Neutral)입니다.")
    exit()

true_labels = eval_df['Label'].values
pred_labels = eval_df['Predicted_Label'].values

accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label='Hawkish')
recall = recall_score(true_labels, pred_labels, pos_label='Hawkish')
f1 = f1_score(true_labels, pred_labels, pos_label='Hawkish')

cm = confusion_matrix(true_labels, pred_labels, labels=['Hawkish', 'Dovish'])
tn, fp, fn, tp = cm.ravel()

# 6. 결과 출력
logger.info("\n=== 평가 결과 ===")
logger.info(f"True Positives (TP): {tp}")
logger.info(f"True Negatives (TN): {tn}")
logger.info(f"False Positives (FP): {fp}")
logger.info(f"False Negatives (FN): {fn}")
logger.info(f"정확도 (Accuracy): {accuracy:.4f}")
logger.info(f"정밀도 (Precision): {precision:.4f}")
logger.info(f"재현율 (Recall): {recall:.4f}")
logger.info(f"F1 점수 (F1 Score): {f1:.4f}")

# 7. 결과 저장
eval_df.to_csv('test_predictions_with_metrics.csv', index=False, encoding='utf-8-sig')
logger.info("예측 결과 및 평가 지표가 'test_predictions_with_metrics.csv' 파일에 저장되었습니다.")
# Out:
# Dovish words (sample): ['올리브영', '중국건설은행', '자체사업', '국제화', '웰빙', '궤도', '경영실태평가', '청정에너지', '정부자금', '하나다']
# Hawkish words (sample): ['중요도', '노도', '선뜻', '불편', '손발', '튤립', '출입', '출발', '결정자', '증상']
# 테스트 데이터 크기: 2239 문장
# 테스트 데이터 클래스 분포:
# Label
# Dovish     1913
# Hawkish     326
# Name: count, dtype: int64
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 내수와 수출 모두 감소세를 지속하면서계속 위축되고 있으나 하강속도는 다소 완만해지고 있으며 세계경제 침체, 국제금융시장 불안 등으로 인해 향후성장의 하향위험은 여전히 큰 것으로 판단됨
# Dovish matches: ['내수', '수출', '감소세', '지속', '위축', '하강', '완만', '해지', '침체', '국제', '성장', '하향', '위험'], Count: 13
# Hawkish matches: ['불안', '성장', '위험'], Count: 3
# Predicted: Dovish
#
# Sentence: 소비자물가는 국제유가가 안정세를 보이는 가운데 경기부진에 따른 수요압력 완화로 오름세가 둔화되었으며 앞으로도 이러한 추세가 이어질 것으로 보임.
# Dovish matches: ['국제', '유가', '안정세', '부진', '수요', '완화', '둔화', '추세', '보임'], Count: 9
# Hawkish matches: ['압력'], Count: 1
# Predicted: Dovish
#
# Sentence: 부동산시장에서는 거래위축 및 가격하락 현상이 지속되고 있음
# Dovish matches: ['위축', '하락', '지속'], Count: 3
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 개선된 모습을나타내었으며 금융기관의 대출태도가 완화되면서 가계 및중소기업 대출이 꾸준히 늘어나고 있음
# Dovish matches: ['개선', '금융기관', '완화', '가계', '중소기업'], Count: 5
# Hawkish matches: ['환율'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기의 과도한 위축을 방지하고 금융시장 안정을 도모하는데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '위축', '안정', '도모', '주안점', '운용'], Count: 8
# Hawkish matches: ['과도'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 내수 부진에도 불구하고 수출 감소세둔화와 적극적인 재정통화정책에 힘입어 하강속도가 완만해지고 있으나 세계경제 침체 지속, 고용사정 악화 등으로 향후 성장의 하향위험이 상존하고 있는 것으로 판단됨
# Dovish matches: ['내수', '부진', '수출', '감소세', '둔화', '힘입', '하강', '완만', '해지', '침체', '지속', '악화', '성장', '하향', '위험'], Count: 15
# Hawkish matches: ['성장', '위험'], Count: 2
# Predicted: Dovish
#
# Sentence: 소비자물가는 국제유가의 안정, 경기부진에 따른 수요압력완화 등으로 오름세가 둔화되었으며 앞으로도 이러한 추세가 이어질 것으로 보임.
# Dovish matches: ['국제', '유가', '안정', '부진', '수요', '완화', '둔화', '추세', '보임'], Count: 9
# Hawkish matches: ['압력'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 개선 추세를지속하는 가운데 가계 및 중소기업 대출이 꾸준히 늘어나고 있으나 신용위험에 대한 우려와 시중자금의 단기화 현상이 지속되고 있음
# Dovish matches: ['개선', '추세', '지속', '가계', '중소기업', '신용위험', '시중', '자금', '지속'], Count: 9
# Hawkish matches: ['환율', '우려'], Count: 2
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기 회복을 뒷받침하고 금융시장 안정을 도모하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복', '안정', '도모', '주안점', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 적극적인 재정통화정책 등에 힘입어 내수부진이 완화되고 생산활동이 호전되는 등 하강을 멈춘모습이나 국제원자재가격 상승 및 주요 선진국의 경기부진으로 향후 성장의 하향위험이 상존하고 있는 것으로판단됨
# Dovish matches: ['힘입', '내수', '부진', '완화', '호전', '하강', '국제', '선진국', '부진', '성장', '하향', '위험'], Count: 12
# Hawkish matches: ['상승', '성장', '위험'], Count: 3
# Predicted: Dovish
#
# Sentence: 소비자물가는 경기부진에 따른 수요압력 완화, 환율의 하향안정 등으로 오름세가 둔화되었음.
# Dovish matches: ['부진', '수요', '완화', '하향', '안정', '둔화'], Count: 6
# Hawkish matches: ['압력', '환율'], Count: 2
# Predicted: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 안정적인 움직임을 보이는 가운데 가계 및 중소기업 대출이 꾸준히 늘어나고 있으나 신용위험에 대한 우려와 시중자금의 단기화 현상이 해소되지 않은 상황임
# Dovish matches: ['안정', '가계', '중소기업', '신용위험', '시중', '자금', '해소'], Count: 7
# Hawkish matches: ['환율', '움직임', '우려'], Count: 3
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 및 금융시장의 개선 움직임이 지속되도록 하는데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '지속', '주안점', '운용'], Count: 7
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 적극적인 재정통화정책 등에 힘입어 내수및 수출부진이 완화되면서 그간의 하강세에서 벗어나는모습이나 국제원자재가격 상승, 주요 선진국의 경기부진등으로 향후 성장경로의 불확실성이 높은 것으로 판단됨
# Dovish matches: ['힘입', '내수', '수출', '부진', '완화', '국제', '선진국', '부진', '성장', '경로'], Count: 10
# Hawkish matches: ['그간', '강세', '상승', '성장', '높'], Count: 5
# Predicted: Dovish
#
# Sentence: 소비자물가는 경기부진에 따른 수요압력 완화 등으로 오름세가 계속 둔화되었음.
# Dovish matches: ['부진', '수요', '완화', '둔화'], Count: 4
# Hawkish matches: ['압력'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 안정적인 움직임을 이어가는 가운데 주택담보대출을 중심으로 은행대출이 꾸준히 증가하였음.
# Dovish matches: ['안정', '중심', '증가'], Count: 3
# Hawkish matches: ['환율', '움직임'], Count: 2
# Predicted: Dovish
#
# Sentence: 한편 신용위험에 대한 우려와 시중자금의 단기화 현상은 해소되지 않은 상황임
# Dovish matches: ['신용위험', '시중', '자금', '해소'], Count: 4
# Hawkish matches: ['우려'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지 하면서최근의 경기 개선 움직임 및 금융시장 안정이 지속되도록하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '안정', '지속', '주안점', '운용'], Count: 8
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 적극적인 재정통화정책 및 신흥시장국경제상황 호전에 힘입어 내수와 수출 부진이 더욱 완화되는 등 개선 움직임을 지속하고 있으나 주요 선진국의 경기회복 지연 가능성 등으로 향후 성장경로의 불확실성이상존하고 있는 것으로 판단됨
# Dovish matches: ['신흥시장', '호전', '힘입', '내수', '수출', '부진', '완화', '개선', '지속', '선진국', '회복', '성장', '경로'], Count: 13
# Hawkish matches: ['움직임', '성장'], Count: 2
# Predicted: Dovish
#
# Sentence: 소비자물가는 수요압력 완화, 환율 하락 등의 영향으로 오름세가 계속 둔화되었음.
# Dovish matches: ['수요', '완화', '하락', '둔화'], Count: 4
# Hawkish matches: ['압력', '환율'], Count: 2
# Predicted: Dovish
#
# Sentence: 금융시장에서는 시장금리 및 주가가 상승하는 가운데 주택담보대출이 계속 큰 폭으로 증가하였음.
# Dovish matches: ['증가'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Predicted: Neutral
#
# Sentence: 한편 신용위험에 대한 우려와 시중자금의 단기화 현상은 해소되지 않은상황임
# Dovish matches: ['신용위험', '시중', '자금', '해소'], Count: 4
# Hawkish matches: ['우려'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 개선 움직임 및 금융시장 안정이 지속되도록하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '안정', '지속', '주안점', '운용'], Count: 8
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 내수 및 수출이 회복 움직임을 보이고 생산이 증가하는 등 개선 추세를 이어가고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '내수', '수출', '회복', '증가', '개선', '추세', '성장', '경로'], Count: 9
# Hawkish matches: ['움직임', '성장'], Count: 2
# Predicted: Dovish
#
# Sentence: 부동산가격은 오름세가 지속되었음
# Dovish matches: ['부동산', '지속'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 시장금리 및 주가가 상승한 가운데 주택담보대출이 큰 폭의 증가를 지속하였음.
# Dovish matches: ['증가', '지속'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 한편 신용위험에대한 우려와 시중자금의 단기화 현상은 다소 완화되는 움직임을 보였음
# Dovish matches: ['신용위험', '시중', '자금', '완화'], Count: 4
# Hawkish matches: ['우려', '움직임'], Count: 2
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 개선 추세 및 금융시장 안정이 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '추세', '안정', '지속', '주안점', '운용'], Count: 9
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출이 회복세를 이어가고 소비가 전년수준을 계속 상회 하는 등개선 추세를 지속하고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '수출', '회복세', '소비', '상회', '개선', '추세', '지속', '성장', '경로'], Count: 10
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 대체로 안정된 모습을 나타내었음.
# Dovish matches: ['안정'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 부동산가격은 오름세가 지속되었음
# Dovish matches: ['부동산', '지속'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 주가가 큰 폭 상승한 후 반락한 가운데총부채상환비율 확대 적용, 대출금리 상승 등으로 주택담보대출의 증가세가 둔화되었음
# Dovish matches: ['증가세', '둔화'], Count: 2
# Hawkish matches: ['상승', '반락', '상승'], Count: 3
# Predicted: Hawkish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 최근의 경기 개선 추세 및 금융시장 안정이 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '개선', '추세', '안정', '지속', '주안점', '운용'], Count: 9
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출 및 내수와 생산 활동이 한층 더 개선되는 등 회복세를 나타내고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '수출', '내수', '개선', '회복세', '성장', '경로'], Count: 7
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 원/달러 환율 등이 하락요인으로 작용하면서안정세를 이어가고 있음.
# Dovish matches: ['하락', '안정세'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융시장에서는 주가, 금리 등 가격변수의 변동성이 다소확대된 가운데 총부채상환비율 확대 적용, 대출금리 상승등으로 주택담보대출 증가세의 둔화 움직임이 지속되었음
# Dovish matches: ['증가세', '둔화', '지속'], Count: 3
# Hawkish matches: ['상승', '움직임'], Count: 2
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세가 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '주안점', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출과 소비가 개선추세를 보이는 등 회복세를 이어가고 있으나 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['호전', '수출', '소비', '개선', '추세', '회복세', '성장', '경로'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 부동산가격은 오름세가 둔화되었음
# Dovish matches: ['부동산', '둔화'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 환율, 주가 등 가격변수가 대체로 안정된움직임을 보이다가 해외 불안요인의 영향으로 변동폭이일시 확대되었으며 주택담보대출은 전월수준의 증가를 나타내었음
# Dovish matches: ['안정', '해외', '전월', '증가'], Count: 4
# Hawkish matches: ['환율', '움직임', '다가'], Count: 3
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세가 지속되도록 하는 데 주안점을 두고 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '주안점', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 세계경제 상황 호전 등으로 수출과 내수가 꾸준히 증가하는 등 회복세를 지속하고 있으며 앞으로도 이와 같은 추세가 이어질 것으로 전망됨.
# Dovish matches: ['호전', '수출', '내수', '증가', '회복세', '지속', '추세'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 다만 주요선진국의 본격적인 경기회복 지연 우려 등으로 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['선진국', '회복', '성장', '경로'], Count: 4
# Hawkish matches: ['우려', '성장'], Count: 2
# Predicted: Dovish
#
# Sentence: 소비자물가는 석유류가격을 중심으로 오름세가 확대되었으며 폭설의 영향이 더해져 상승률이 일시 더 높아질 것으로 예상됨.
# Dovish matches: ['중심', '상승률'], Count: 2
# Hawkish matches: ['폭설', '더해져', '높'], Count: 3
# Predicted: Hawkish
#
# Sentence: 부동산가격은 상승세가 둔화되고 있음
# Dovish matches: ['부동산', '둔화'], Count: 2
# Hawkish matches: ['부동산'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 경기개선 흐름 등을 반영하여 장단기 시장금리 및 주가가 상당 폭 상승하였으며 주택담보대출은꾸준한 증가세를 보였음
# Dovish matches: ['개선', '상당폭', '증가세'], Count: 3
# Hawkish matches: ['장단기', '상승'], Count: 2
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화 기조를 유지하면서경기회복세 지속에 도움이 되는 방향으로 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 수출과 내수가 꾸준히 증가하고 생산활동이 활발한 모습을 보이는 등 회복세를 지속하고 있으며앞으로도 이와 같은 추세가 이어질 것으로 전망됨.
# Dovish matches: ['수출', '내수', '증가', '회복세', '지속', '추세'], Count: 6
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 다만일부 유럽국가의 재정위기 우려 등으로 향후 성장경로의불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['국가', '성장', '경로'], Count: 3
# Hawkish matches: ['우려', '성장'], Count: 2
# Predicted: Dovish
#
# Sentence: 소비자물가는 오름세가 확대되었으나 최근의 국제원자재가격 움직임 등에 비추어 앞으로 안정된 모습을 보일 것으로 예상됨.
# Dovish matches: ['국제', '비추', '안정'], Count: 3
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 해외 불안요인의 영향으로 환율과 주가등 가격변수가 큰 폭의 변동을 보였으며 주택담보대출은계절요인 등으로 증가폭이 축소되었음
# Dovish matches: ['해외', '계절요인', '증가', '축소'], Count: 4
# Hawkish matches: ['환율'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세 지속에 도움이 되는 방향으로 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 최근 국내 경기는 수출이 확대되고 내수가 꾸준히 증가하는등 회복세를 지속하고 있으며 앞으로도 이와 같은 추세가이어질 것으로 전망됨.
# Dovish matches: ['수출', '내수', '증가', '회복세', '지속', '추세'], Count: 6
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 다만 일부 국가의 과다채무 문제등으로 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단됨
# Dovish matches: ['국가', '채무', '문제', '성장', '경로'], Count: 5
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 상승세가 다소 둔화되었으며 최근의 국제원자재가격 움직임 등에 비추어 당분간 안정된 모습을 보일것으로 예상됨.
# Dovish matches: ['둔화', '국제', '비추', '안정'], Count: 4
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 일부 유럽국가의 재정위기 등 해외 불안요인이 완화되면서 주가가 반등하고 환율이 하락하였으며주택담보대출은 계절요인 등으로 소폭 증가에 그쳤음
# Dovish matches: ['국가', '해외', '완화', '하락', '계절요인', '증가'], Count: 6
# Hawkish matches: ['환율'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세 지속에 도움이 되는 방향으로 운용해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을운용하기로 하였음
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 보이고 있는 가운데 미국, 일본 등 주요 선진국 경제의 개선 추세가 다소강화되는 움직임을 나타내고 있음.
# Dovish matches: ['호조', '선진국', '개선', '추세', '강화'], Count: 5
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 다만 일부 유럽국가의재정문제 등 위험요인이 잠재하고 있음
# Dovish matches: ['국가', '문제', '위험요인'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내 경기는 건설투자가 다소 부진한 모습이나 수출이 호조를 보이고 소비와 설비투자도 꾸준히 증가하는 등 회복세를 지속하고 있음
# Dovish matches: ['건설', '투자', '부진', '수출', '호조', '소비', '설비', '투자', '증가', '회복세', '지속'], Count: 11
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내 경기의 회복세는 앞으로도 이어질 것으로 전망되나해외 위험요인 등에 비추어 향후 성장경로의 불확실성은상존하고 있는 것으로 판단됨
# Dovish matches: ['회복세', '해외', '위험요인', '비추', '성장', '경로'], Count: 6
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 서비스가격을 중심으로 상승세가 둔화되었으며 당분간 안정된 모습을 보일 것으로 예상됨.
# Dovish matches: ['서비스', '중심', '둔화', '안정'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융시장에서는 외국인 증권투자자금 유입이 확대되는 가운데 주가가 상승하고 장단기 시장금리가 하락하였음.
# Dovish matches: ['투자자금', '하락'], Count: 2
# Hawkish matches: ['외국인', '상승', '장단기'], Count: 3
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 대출금리 하락, 입주·분양물량 증가 등의 영향으로 증가규모가 소폭 확대되었음
# Dovish matches: ['하락', '증가', '증가'], Count: 3
# Hawkish matches: ['물량'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 당분간 금융완화기조를 유지하면서 경기회복세 지속에 도움이 되는 방향으로 운용하되 국내외금융경제상황을 종합적으로 고려해 나갈 것임
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있는 가운데 미국,일본 등 주요 선진국 경제도 개선추세를 보이고 있다.
# Dovish matches: ['호조', '지속', '선진국', '개선', '추세'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 다만 남유럽국가들의 재정문제가 근본적으로 해결되지 않음에 따라 국제금융시장이 수시로 불안한 움직임을 나타낼 위험이 잠재하고 있다.
# Dovish matches: ['국가', '문제', '근본적', '해결', '국제', '위험'], Count: 6
# Hawkish matches: ['남유럽', '불안', '움직임', '위험'], Count: 4
# Predicted: Dovish
#
# Sentence: 국내 경기는 회복세가 뚜렷해지고 있는 모습이다.
# Dovish matches: ['회복세', '해지'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 건설투자가 여전히 부진하나 수출이 호조를 지속하고 설비투자와 소비도 꾸준히늘어나고 있으며 고용사정도 민간부문을 중심으로 개선되고 있다.
# Dovish matches: ['건설', '투자', '부진', '하나', '수출', '호조', '지속', '설비', '투자', '소비', '민간', '중심', '개선'], Count: 13
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내 경기의 회복세는 앞으로도 이어질 것으로 전망되나 해외 위험요인 등에 비추어 향후 성장경로의 불확실성은 상존하고 있는것으로 판단된다.
# Dovish matches: ['회복세', '해외', '위험요인', '비추', '성장', '경로'], Count: 6
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 이상기후에 따른 농축수산물가격 상승 등으로 오름세가 일시 확대되었다.
# Dovish matches: ['기후'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Predicted: Neutral
#
# Sentence: 앞으로 물가는 당분간 안정된 모습을 보일것이나 경기회복으로 수요압력이 점차 증대될 것으로 예상된다.
# Dovish matches: ['안정', '회복', '수요', '점차'], Count: 4
# Hawkish matches: ['압력'], Count: 1
# Predicted: Dovish
#
# Sentence: 부동산시장에서는 거래가 활발하지 않은 가운데 수도권을 중심으로주택매매가격이 약세를 나타내었다.
# Dovish matches: ['중심'], Count: 1
# Hawkish matches: ['거래', '약세'], Count: 2
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 대출금리 하락에도 불구하고 주택거래 부진 등의 영향으로 증가규모에 변화를 보이지않고 있다.
# Dovish matches: ['하락', '주택', '부진', '증가'], Count: 4
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 금융완화기조를 유지하면서 경기회복세 지속에도움이 되는 방향으로 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '유지', '회복세', '지속', '도움', '운용', '수행'], Count: 8
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.00%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있는 가운데 미국,일본 등 주요 선진국 경제도 개선 움직임을 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '개선'], Count: 4
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 그러나일부 유럽국가의 재정문제로 인해 국제금융시장이 수시로 불안한모습을 나타내고 그 영향이 세계경제의 회복세에 미칠 위험이 잠재하고 있다.
# Dovish matches: ['국가', '문제', '국제', '회복세', '위험'], Count: 5
# Hawkish matches: ['불안', '위험'], Count: 2
# Predicted: Dovish
#
# Sentence: 국내경기는 상승세를 지속하고 있는 것으로 보인다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 소비, 투자 등내수의 증가세가 일시 주춤한 모습이나 수출이 호조를 지속하고고용사정도 민간부문을 중심으로 한층 개선되고 있다.
# Dovish matches: ['소비', '투자', '내수', '증가세', '수출', '호조', '지속', '민간', '중심', '개선'], Count: 10
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경기의 상승세는 앞으로도 이어질 것으로 전망되나 해외 위험요인 등에 비추어 향후 성장경로의 불확실성은 상존하고 있는 것으로 판단된다.
# Dovish matches: ['해외', '위험요인', '비추', '성장', '경로'], Count: 5
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 석유류가격을 중심으로 오름세가 소폭 확대되었으며앞으로 경기상승세가 지속되면서 수요압력이 점차 증대될 것으로예상된다.
# Dovish matches: ['중심', '지속', '수요', '점차'], Count: 4
# Hawkish matches: ['압력'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 일부 유럽국가 재정문제, 한반도의 지정학적 위험증대 등으로 주가와 환율 등 가격변수가 큰 폭으로 변동하였다.
# Dovish matches: ['국가', '문제', '위험'], Count: 3
# Hawkish matches: ['지정학', '위험', '환율'], Count: 3
# Predicted: Neutral
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않았음에도 불구하고 대출금리하락 등의 영향으로 증가규모가 소폭 확대되었다.
# Dovish matches: ['주택', '하락', '증가'], Count: 3
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 금융완화기조를 유지하면서 우리 경제가 물가안정의 기조 위에서 견조한 성장을 지속할 수 있도록 하는 방향으로 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해나갈 것이다.
# Dovish matches: ['금융', '완화', '유지', '안정', '견조', '성장', '지속', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.00%에서 2.25%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제의 호조가 지속되는 가운데 미국 등주요 선진국 경제도 대체로 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '회복세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 다만 일부유럽국가의 재정문제로 인한 국제금융시장 불안, 주요국 경기의변동성 확대 등이 수시로 재연될 위험성을 배제할 수 없다.
# Dovish matches: ['국가', '문제', '국제', '위험'], Count: 4
# Hawkish matches: ['불안', '재연', '위험', '배제'], Count: 4
# Predicted: Neutral
#
# Sentence: 국내경기는 상승세를 지속하고 있다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 수출이 높은 신장세를 보이고소비, 투자 등 내수가 꾸준히 증가하고 있으며 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['수출', '신장세', '소비', '투자', '내수', '증가', '민간', '중심', '개선', '추세'], Count: 10
# Hawkish matches: ['높'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승세를 이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 소비자물가는 상승률이 2%대 중후반에 머물고 있으나 앞으로 경기상승세 지속에 따른 수요압력 증대 등으로 상승압력이 계속 커질것으로 예상된다.
# Dovish matches: ['상승률', '지속', '수요'], Count: 3
# Hawkish matches: ['압력', '상승', '압력', '커질'], Count: 4
# Predicted: Hawkish
#
# Sentence: 금융시장에서는 장기시장금리가 국내경기 상황 등을 반영하여 상승하였으며 주가와 환율은 해외 불안요인의 영향 등으로 큰 폭의변동을 나타내었다.
# Dovish matches: ['해외'], Count: 1
# Hawkish matches: ['상승', '환율'], Count: 2
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않았음에도 불구하고 낮은 대출금리 등의 영향으로 증가규모가 확대되었다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 금융완화기조를 유지하면서 우리 경제가 물가안정의 기조 위에서 견조한 성장을 지속할 수 있도록 하는 방향으로 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해나갈 것이다.
# Dovish matches: ['금융', '완화', '유지', '안정', '견조', '성장', '지속', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있는 가운데 주요선진국 경제도 대체로 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '회복세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 일부 유럽국가의재정문제로 인한 국제금융시장 불안은 완화되었으나 주요국 경기의변동성 확대 등이 위험요인으로 작용할 가능성을 배제할 수 없다.
# Dovish matches: ['국가', '문제', '국제', '완화', '위험요인'], Count: 5
# Hawkish matches: ['불안', '배제'], Count: 2
# Predicted: Dovish
#
# Sentence: 국내경기는 상승세를 지속하고 있다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 수출이 계속 호조를 보이고소비, 투자 등 내수가 꾸준히 증가하고 있으며 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['수출', '호조', '소비', '투자', '내수', '증가', '민간', '중심', '개선', '추세'], Count: 10
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승세를 이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 소비자물가는 상승률이 2%대 중후반에 머물고 있으나 앞으로 경기상승세 지속에 따른 수요압력 증대 등으로 상승압력이 계속 커질것으로 예상된다.
# Dovish matches: ['상승률', '지속', '수요'], Count: 3
# Hawkish matches: ['압력', '상승', '압력', '커질'], Count: 4
# Predicted: Hawkish
#
# Sentence: 금융시장에서는 기준금리 인상의 영향 등으로 단기시장금리와 은행 여수신금리가 상승하였으며, 한편 외국인 증권투자자금이 큰 폭으로 유입되는 가운데 주가가 상승하였다.
# Dovish matches: ['여수신', '투자자금'], Count: 2
# Hawkish matches: ['기준금리', '인상', '상승', '외국인', '상승'], Count: 5
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않았음에도 불구하고 낮은 대출금리 등의 영향으로꾸준히 증가하였다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 금융완화기조하에서 견조한 성장을 지속하는 가운데 물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 미국 등의 성장세 둔화 움직임이 나타났으나 대체로 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '성장세', '둔화', '회복세'], Count: 6
# Hawkish matches: ['움직임'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 주요국 경기의 변동성 확대 등이 세계경제의 위험요인으로 작용할 가능성이 있다.
# Dovish matches: ['위험요인'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경기는 상승세를 지속하고 있다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 수출이 계속 호조를 보이고소비가 꾸준히 증가하고 있으며 고용사정도 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['수출', '호조', '소비', '증가', '민간', '중심', '개선', '추세'], Count: 8
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승세를 이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 소비자물가는 상승률이 2%대 중후반 수준에 있으나 앞으로 경기상승세 지속에 따른 수요압력 증대 등으로 상승압력이 계속 커질 것으로 예상된다.
# Dovish matches: ['상승률', '지속', '수요'], Count: 3
# Hawkish matches: ['압력', '상승', '압력', '커질'], Count: 4
# Predicted: Hawkish
#
# Sentence: 금융시장에서는 단기시장금리와 은행 여수신금리가 상승세를 이어갔으나 외국인 채권투자자금 유입 등의 영향으로 장기시장금리는하락하였다.
# Dovish matches: ['여수신', '갔으나', '자금', '하락'], Count: 4
# Hawkish matches: ['외국인', '채권투자'], Count: 2
# Predicted: Dovish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않은 가운데 증가폭이 다소 줄어들었다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 금융완화기조하에서 견조한 성장을 지속하는 가운데 물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제는 미국 등의 경기회복 속도가 다소 둔화되고 있으나 대체로 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '회복', '둔화', '완만', '회복세'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 주요국 경기 및 환율의 변동성 확대 등이 세계경제의 위험요인으로 작용할 가능성이 있다.
# Dovish matches: ['위험요인'], Count: 1
# Hawkish matches: ['환율'], Count: 1
# Predicted: Neutral
#
# Sentence: 국내경기는 소비가 주춤하였으나 수출이 호조를 지속하고 설비투자가 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['소비', '수출', '호조', '지속', '설비', '투자', '증가', '유지'], Count: 8
# Hawkish matches: ['였으나', '상승'], Count: 2
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 농산물가격 급등 등으로 상승률이 높아졌으며 앞으로 경기상승이 이어지면서 수요측면의 상승압력이 지속될 것으로예상된다.
# Dovish matches: ['농산물', '상승률', '수요측면', '지속'], Count: 4
# Hawkish matches: ['높', '졌으며', '상승', '상승', '압력'], Count: 5
# Predicted: Hawkish
#
# Sentence: 부동산시장에서는 주택매매가격이 수도권은 하락하고지방은 상승하는 현상이 지속되었다.
# Dovish matches: ['하락', '지속'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융시장에서는 외국인증권투자자금 유입 확대 등의 영향으로 주가가 상승하고 환율과 시장금리가 하락하였다.
# Dovish matches: ['투자자금', '하락'], Count: 2
# Hawkish matches: ['외국인', '상승', '환율'], Count: 3
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 활발하지 않은 가운데서도 입주물량 증가 등으로 증가폭이 확대되었다.
# Dovish matches: ['주택', '증가', '증가'], Count: 3
# Hawkish matches: ['거래', '물량'], Count: 2
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 금융완화기조하에서 견조한 성장을 지속하는 가운데 물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['금융', '완화', '견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.25%에서 2.50%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 대체로 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '완만', '회복세'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 주요국 경기및 환율의 변동성 확대 등이 세계경제의 위험요인으로 작용할 가능성을 배제할 수 없다.
# Dovish matches: ['위험요인'], Count: 1
# Hawkish matches: ['환율', '배제'], Count: 2
# Predicted: Hawkish
#
# Sentence: 국내경기는 설비투자가 주춤하였으나 수출이 호조를 지속하고 소비가 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['설비', '투자', '수출', '호조', '지속', '소비', '증가', '유지'], Count: 8
# Hawkish matches: ['였으나', '상승'], Count: 2
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 농산물가격을 중심으로 상승률이 더욱 높아졌다.
# Dovish matches: ['농산물', '중심', '상승률'], Count: 3
# Hawkish matches: ['높'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 채소류가격의 안정 등으로 물가상승률이 다소 낮아질 것이나경기상승이 이어지고 국제원자재 가격이 오르면서 상승압력이 지속될 것으로 예상된다.
# Dovish matches: ['안정', '상승률', '국제', '지속'], Count: 4
# Hawkish matches: ['상승', '오르', '상승', '압력'], Count: 4
# Predicted: Neutral
#
# Sentence: 금융시장에서는 외국인증권투자자금 유입이 지속되면서 주가가 상승하고 환율이 하락하였으며 장기시장금리는 큰 폭 하락 후 높은물가상승률의 영향 등으로 반등하였다.
# Dovish matches: ['투자자금', '지속', '하락', '하락', '상승률'], Count: 5
# Hawkish matches: ['외국인', '상승', '환율', '높'], Count: 4
# Predicted: Dovish
#
# Sentence: 주택담보대출은 주택거래가활발하지 않은 가운데서도 비교적 큰 폭의 증가를 지속하였다.
# Dovish matches: ['주택', '증가', '지속'], Count: 3
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 7
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.50%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 대체로 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '완만', '회복세'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 주요국 경기의 변동성 확대, 일부 유럽국가의 재정문제로 인한 국제금융시장불안 등이 세계경제의 위험요인으로 작용할 가능성을 배제할 수없다.
# Dovish matches: ['국가', '문제', '국제', '위험요인'], Count: 4
# Hawkish matches: ['불안', '배제'], Count: 2
# Predicted: Dovish
#
# Sentence: 국내경기는 상승기조를 유지하고 있는 것으로 판단된다.
# Dovish matches: ['유지'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Predicted: Neutral
#
# Sentence: 건설투자가 계속 부진하고 설비투자가 감소하였으나 수출이 호조를 지속하고 소비가 꾸준히 증가하고 있다.
# Dovish matches: ['건설', '투자', '부진', '설비', '투자', '감소', '수출', '호조', '지속', '소비', '증가'], Count: 11
# Hawkish matches: ['였으나'], Count: 1
# Predicted: Dovish
#
# Sentence: 고용사정은 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가는 채소류가격의 안정 등으로 상승률이 크게 낮아졌으나 앞으로 경기상승이 이어지고 국제 원자재 가격이 오르면서 상승압력이 지속될 것으로 예상된다.
# Dovish matches: ['안정', '상승률', '국제', '지속'], Count: 4
# Hawkish matches: ['크', '졌으나', '상승', '오르', '상승', '압력'], Count: 6
# Predicted: Hawkish
#
# Sentence: 금융시장에서는 유럽 재정문제 재부각, 지정학적 위험 등으로 주가와 환율이 큰 폭의 변동을 나타내었다.
# Dovish matches: ['문제', '위험'], Count: 2
# Hawkish matches: ['지정학', '위험', '환율'], Count: 3
# Predicted: Hawkish
#
# Sentence: 장기시장금리는 국고채 발행물량 축소계획, 외국인채권매수 지속 등으로 하락하였다.
# Dovish matches: ['축소', '계획', '채권', '지속', '하락'], Count: 5
# Hawkish matches: ['국고채', '발행물량', '외국인', '채권', '매수'], Count: 5
# Predicted: Neutral
#
# Sentence: 주택담보대출은 주택거래가 다소 늘어난 가운데 증가폭이 확대되었다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데물가안정이 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '유지', '운용', '수행'], Count: 7
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.50%에서 2.75%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제는 신흥시장국 경제가 호조를 지속하고 있으며 선진국 경제도 완만한 회복세를 이어가고 있다.
# Dovish matches: ['호조', '지속', '선진국', '완만', '회복세'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를지속할 것으로 전망되나 일부 유럽국가의 재정문제로 인한 국제금융시장 불안, 국제원자재가격의 변동성 확대 등이 위험요인으로 작용할 가능성을 배제할 수는 없다.
# Dovish matches: ['회복세', '지속', '국가', '문제', '국제', '국제', '위험요인'], Count: 7
# Hawkish matches: ['불안', '배제'], Count: 2
# Predicted: Dovish
#
# Sentence: 국내경기는 설비투자가 감소하였으나 수출이 호조를 지속하고 소비가 꾸준히 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['설비', '투자', '감소', '수출', '호조', '지속', '소비', '증가', '유지'], Count: 9
# Hawkish matches: ['였으나', '상승'], Count: 2
# Predicted: Dovish
#
# Sentence: 고용사정도민간부문을 중심으로 개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 석유류 및 농산물 가격의 상승 등에 기인하여 지난달 3.5% 수준에 이르렀다.
# Dovish matches: ['상승률', '농산물'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 경기상승이 이어지고 국제원자재가격이 오르면서 물가상승압력이 지속되고 인플레이션 기대심리가 높아질 것으로 예상된다.
# Dovish matches: ['국제', '지속'], Count: 2
# Hawkish matches: ['상승', '오르', '상승', '압력', '인플레이션', '높'], Count: 6
# Predicted: Hawkish
#
# Sentence: 부동산시장에서는 전세가격 상승이 지속되는 가운데 주택매매가격은 지방에서는 오름세가 지속되고 수도권에서도 상승 움직임이 나타났다.
# Dovish matches: ['지속', '지속'], Count: 2
# Hawkish matches: ['상승', '상승', '움직임'], Count: 3
# Predicted: Hawkish
#
# Sentence: 장기시장금리는 물가상승 기대, 외국인의 채권 순매도 등의 영향으로 상승하였다.
# Dovish matches: ['채권'], Count: 1
# Hawkish matches: ['상승', '외국인', '채권', '상승'], Count: 4
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 주택거래가 늘어난 가운데 큰 폭으로 증가하였다.
# Dovish matches: ['주택', '증가'], Count: 2
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데물가안정기조가 확고히 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '운용', '수행'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(2.75%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제가 계속 호조를 나타내고 선진국경제도 회복세를 이어가고 있다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 지속할것으로 전망되나 국제원자재가격의 변동성 확대, 일부 유럽국가의 재정문제로 인한 국제금융시장 불안 등이 위험요인으로 남아 있다.
# Dovish matches: ['회복세', '지속', '국제', '국가', '문제', '국제', '위험요인'], Count: 7
# Hawkish matches: ['불안'], Count: 1
# Predicted: Dovish
#
# Sentence: 국내경기는 수출이 높은 신장세를 지속하고 내수가 꾸준히 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '신장세', '지속', '내수', '증가', '유지'], Count: 6
# Hawkish matches: ['높', '상승'], Count: 2
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 석유류 및 농산물 가격을 중심으로 크게 높아졌다.
# Dovish matches: ['상승률', '농산물', '중심'], Count: 3
# Hawkish matches: ['크', '높'], Count: 2
# Predicted: Dovish
#
# Sentence: 앞으로 경기상승이 이어지면서 높은 인플레이션 기대심리가유지되고 물가상승압력도 지속될 것으로 예상된다.
# Dovish matches: ['유지', '지속'], Count: 2
# Hawkish matches: ['상승', '높', '인플레이션', '상승', '압력'], Count: 5
# Predicted: Hawkish
#
# Sentence: 부동산시장에서는 전세가격이 계속 상승하였으며 주택매매가격은 지방에서 오름세가 지속되고 수도권에서도 상승 움직임을 보였다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: ['상승', '상승', '움직임'], Count: 3
# Predicted: Hawkish
#
# Sentence: 금융시장에서는 장기시장금리가 기준금리 인상, 물가상승 기대, 국고채 발행물량 증가 등의 영향으로 큰 폭 상승하였다.
# Dovish matches: ['증가'], Count: 1
# Hawkish matches: ['기준금리', '인상', '상승', '국고채', '발행물량', '상승'], Count: 6
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 계절요인 등으로 소폭 증가에 그쳤다.
# Dovish matches: ['계절요인', '증가'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지될 수 있도록 운용하되 국내외 금융경제상황을 종합적으로 고려하여 수행해 나갈 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '운용', '수행'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 2.75%에서 3.00%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제가 계속 호조를 나타내고 선진국경제도 회복세를 이어가고 있다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 세계경제는 북아프리카•중동지역의 정정불안, 유가를 비롯한 국제원자재가격 상승, 일부유럽국가의 재정문제 등의 하방위험 요인이 있으나 회복세를 지속할 것으로 전망된다.
# Dovish matches: ['지역', '유가', '국제', '국가', '문제', '하방', '위험요인', '회복세', '지속'], Count: 9
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 국내경기는 수출이 높은 신장세를 지속하고 내수가 꾸준히 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '신장세', '지속', '내수', '증가', '유지'], Count: 6
# Hawkish matches: ['높', '상승'], Count: 2
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로개선추세를 나타내고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 석유류, 농축수산물 및 개인서비스 가격 상승등으로 지난달 4.5% 수준으로 높아졌다.
# Dovish matches: ['상승률'], Count: 1
# Hawkish matches: ['상승', '높'], Count: 2
# Predicted: Hawkish
#
# Sentence: 앞으로 경기상승으로 인한수요압력 증대, 국제원자재가격 불안, 인플레이션 기대심리 증대등으로 높은 물가오름세가 지속될 가능성이 있다.
# Dovish matches: ['수요', '국제', '지속'], Count: 3
# Hawkish matches: ['상승', '압력', '불안', '인플레이션', '높'], Count: 5
# Predicted: Hawkish
#
# Sentence: 주택매매가격은수도권에서 상승 움직임이 이어지고 지방에서는 오름세가 확대되었으며 전세가격은 계속 상승하였다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승', '움직임', '상승'], Count: 3
# Predicted: Hawkish
#
# Sentence: 금융시장에서는 해외위험요인, 물가오름세 확대 등의 영향으로 주가와 장기시장금리의 변동성이 증대되었다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 주택담보대출은 전월보다 증가폭이 다소 확대되었다.
# Dovish matches: ['전월', '보다', '증가'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는데 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '중점', '운용'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(3.00%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제가 계속 호조를 나타내고 선진국경제도 회복세를 이어가고 있다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 지속할 것으로 전망되나 북아프리카•중동지역의 정정불안, 일부 유럽국가의 재정문제, 일본 대지진 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '지속', '지역', '국가', '문제', '하방', '위험요인'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경기는 소비와 설비투자가 주춤하였으나 수출이 높은 신장세를 보인 데 힘입어 상승기조를 유지하고 있다.
# Dovish matches: ['소비', '설비', '투자', '수출', '신장세', '힘입', '유지'], Count: 7
# Hawkish matches: ['였으나', '높', '상승'], Count: 3
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 석유류 및 개인서비스 가격 상승 등으로 지난달 4.7% 수준에 이르렀다.
# Dovish matches: ['상승률'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Predicted: Neutral
#
# Sentence: 앞으로 경기상승으로 인한 수요압력증대, 국제원자재가격 불안, 인플레이션 기대심리 증대 등으로 높은 물가오름세가 지속될 가능성이 커지고 있다.
# Dovish matches: ['수요', '국제', '지속'], Count: 3
# Hawkish matches: ['상승', '압력', '불안', '인플레이션', '높', '커지'], Count: 6
# Predicted: Hawkish
#
# Sentence: 주택매매가격은 수도권에서 상승 움직임이 이어지고 지방에서는 오름세가 확대되었으며 전세가격은 계속 상승하였다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승', '움직임', '상승'], Count: 3
# Predicted: Hawkish
#
# Sentence: 금융시장에서는 해외위험요인의 영향으로 가격변수가 큰 폭의 등락을 보인 가운데 국내경기 상승세 등으로 주가는 최고 수준을 경신하고 환율은 크게 하락하였다.
# Dovish matches: ['해외', '위험요인', '하락'], Count: 3
# Hawkish matches: ['최고', '경신', '환율', '크'], Count: 4
# Predicted: Hawkish
#
# Sentence: 주택담보대출은 전월보다 증가폭이 확대되었다.
# Dovish matches: ['전월', '보다', '증가'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는 데 보다 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '보다', '중점', '운용'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 지속할 것으로 전망되나 일부 유럽국가의 재정문제, 북아프리카중동지역의 정정불안, 일본 대지진의 영향 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '지속', '국가', '문제', '지역', '하방', '위험요인'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경기는 수출이 계속 호조를 보이고 내수가 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '호조', '내수', '증가', '유지'], Count: 5
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 채소류가격의 하락 등으로 전월보다는 낮아졌으나, 앞으로 경기상승으로 인한 수요압력 증대, 국제유가 불안, 인플레이션 기대심리 증대 등으로 높은 물가오름세가 지속될 가능성이있다.
# Dovish matches: ['상승률', '하락', '전월', '보다', '수요', '국제', '유가', '지속'], Count: 8
# Hawkish matches: ['졌으나', '상승', '압력', '불안', '인플레이션', '높'], Count: 6
# Predicted: Dovish
#
# Sentence: 주택매매가격은 수도권에서 상승 움직임이 주춤하였으나 지방에서는 높은 오름세가 지속되었다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: ['상승', '움직임', '였으나', '높'], Count: 4
# Predicted: Hawkish
#
# Sentence: 전세가격은 계속 상승하였다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승'], Count: 1
# Predicted: Hawkish
#
# Sentence: 장기시장금리는 좁은 범위내에서 등락하는 모습을 보였다.
# Dovish matches: ['범위'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 주택담보대출은 전월보다 증가폭이확대되었다.
# Dovish matches: ['전월', '보다', '증가'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는 데 보다 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '보다', '중점', '운용'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의 3.00%에서 3.25%로 상향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['상향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제를 보면 선진국 경제는 회복세가 다소 지연되는 모습을보였으나 신흥시장국 경제는 계속 호조를 나타내고 있다.
# Dovish matches: ['선진국', '회복세', '호조'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로세계경제는 회복세를 이어갈 것으로 전망되나 일부 유럽국가의 재정문제, 북아프리카•중동지역의 정정불안, 일본 대지진의 영향 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '국가', '문제', '지역', '하방', '위험요인'], Count: 6
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경기는 내수가 주춤하였으나 수출이 계속 높은 신장세를 보인데 힘입어 상승기조를 유지하고 있다.
# Dovish matches: ['내수', '수출', '신장세', '힘입', '유지'], Count: 5
# Hawkish matches: ['였으나', '높', '상승'], Count: 3
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 지난달에도 4%대 초반의 여전히 높은 수준을나타내었다.
# Dovish matches: ['상승률'], Count: 1
# Hawkish matches: ['초반', '높'], Count: 2
# Predicted: Hawkish
#
# Sentence: 앞으로 경기상승으로 인한 수요 증대, 인플레이션 기대심리 등으로 높은 물가상승압력이 이어질 것으로 예상된다.
# Dovish matches: ['수요'], Count: 1
# Hawkish matches: ['상승', '인플레이션', '높', '상승', '압력'], Count: 5
# Predicted: Hawkish
#
# Sentence: 근원인플레이션율은 그동안의 유가 및 농산물가격 상승 등의 영향이가공식품가격, 개인서비스요금 등에 파급되면서 3%대 중반으로 높아졌으며, 앞으로도 오름세가 지속될 가능성이 있다.
# Dovish matches: ['유가', '농산물', '요금', '지속'], Count: 4
# Hawkish matches: ['그동안', '상승', '높', '졌으며'], Count: 4
# Predicted: Neutral
#
# Sentence: 주택매매가격은 수도권에서는 상승 움직임이 멈추었으며 지방에서는 높은 오름세가 계속되었다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['상승', '움직임', '멈추', '높'], Count: 4
# Predicted: Hawkish
#
# Sentence: 전세가격은 계절적 비수기 등의 영향으로 전월보다 낮은 상승률을 보였다.
# Dovish matches: ['전월', '보다', '상승률'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융시장에서는 해외 위험요인의 영향 등으로 주가와 장기시장금리가 하락하고 환율은 상승하였다.
# Dovish matches: ['해외', '위험요인', '하락'], Count: 3
# Hawkish matches: ['환율', '상승'], Count: 2
# Predicted: Dovish
#
# Sentence: 주택담보대출은 전월보다는 증가폭이 축소되었으나 꾸준한 증가세를 나타내었다.
# Dovish matches: ['전월', '보다', '증가', '축소', '증가세'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는 데 보다 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '보다', '중점', '운용'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(3.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제는 계속 호조를 나타내었으나 미국 등 선진국 경제는 회복세가 일시 주춤하는 모습을 보였다.
# Dovish matches: ['호조', '선진국', '회복세'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 이어갈 것으로 전망되나 유럽지역의 국가채무문제, 주요국 경기의 변동성 확대 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '지역', '국가', '채무', '문제', '하방', '위험요인'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경기는 수출이 견조한 신장세를 보이고 내수가 완만하게 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '견조', '신장세', '내수', '완만', '증가', '유지'], Count: 7
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 해외 위험요인이 상존하는 가운데 상승기조를이어갈 것으로 전망된다.
# Dovish matches: ['해외', '위험요인'], Count: 2
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 일부 농축산물가격의 큰 폭 상승에 주로 기인하여 지난달 4.4% 수준으로 높아졌다.
# Dovish matches: ['상승률', '농축산물'], Count: 2
# Hawkish matches: ['상승', '높'], Count: 2
# Predicted: Neutral
#
# Sentence: 앞으로 경기상승기조에따른 수요압력, 인플레이션 기대심리 등으로 높은 수준의 물가상승률이 이어질 것으로 예상된다.
# Dovish matches: ['수요', '상승률'], Count: 2
# Hawkish matches: ['상승', '압력', '인플레이션', '높'], Count: 4
# Predicted: Hawkish
#
# Sentence: 근원인플레이션율은 가공식품가격및 개인서비스요금이 계속 오르면서 3.7% 수준으로 상승하였으며당분간 오름세가 지속될 것으로 보인다.
# Dovish matches: ['요금', '지속'], Count: 2
# Hawkish matches: ['오르', '상승'], Count: 2
# Predicted: Neutral
#
# Sentence: 주택매매가격은 수도권에서는 약세를 나타내었으며 지방에서는 오름폭이 축소되었다.
# Dovish matches: ['축소'], Count: 1
# Hawkish matches: ['약세', '오름폭'], Count: 2
# Predicted: Hawkish
#
# Sentence: 전세가격은 계절적 비수기 등의 영향으로 상승률이 전월보다 낮아졌다.
# Dovish matches: ['상승률', '전월', '보다'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융시장에서는 유럽지역 국가채무문제를 비롯한 해외 위험요인의영향 등으로 금리, 주가, 환율 등 가격변수의 변동폭이 확대되었다.
# Dovish matches: ['지역', '국가', '채무', '문제', '해외', '위험요인'], Count: 6
# Hawkish matches: ['환율'], Count: 1
# Predicted: Dovish
#
# Sentence: 주택담보대출은 꾸준한 증가세를 나타내었다.
# Dovish matches: ['증가세'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 통화정책은 국내외 금융경제상황을 종합적으로 고려하면서우리 경제가 견조한 성장을 지속하는 가운데 물가안정기조가 확고히 유지되도록 하는 데 보다 중점을 두고 운용할 것이다.
# Dovish matches: ['견조', '성장', '지속', '안정', '확고히', '유지', '보다', '중점', '운용'], Count: 9
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현 수준(3.25%)에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 세계경제를 보면 신흥시장국 경제는 호조를 나타내었으나 미국 등선진국 경제는 회복세가 약화되는 모습을 보였다.
# Dovish matches: ['호조', '선진국', '회복세', '약화'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 세계경제는 회복세를 이어갈 것으로 전망되나 주요국 경기의 둔화 지속 가능성, 유럽지역의 국가채무문제 확산, 국제금융시장 불안 등이 하방위험 요인으로 작용할 가능성이 있다.
# Dovish matches: ['회복세', '둔화', '지속', '지역', '국가', '채무', '문제', '국제', '하방', '위험요인'], Count: 10
# Hawkish matches: ['불안'], Count: 1
# Predicted: Dovish
#
# Sentence: 국내경기는 수출이 견조한 신장세를 보이고 내수가 완만하게 증가하는 등 상승기조를 유지하고 있다.
# Dovish matches: ['수출', '견조', '신장세', '내수', '완만', '증가', '유지'], Count: 7
# Hawkish matches: ['상승'], Count: 1
# Predicted: Dovish
#
# Sentence: 고용사정도 민간부문을 중심으로 개선추세를 지속하고 있다.
# Dovish matches: ['민간', '중심', '개선', '추세', '지속'], Count: 5
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경기는 상승기조를 이어갈 것이나 해외 위험요인의 영향으로 성장 경로의 불확실성이 높아진 것으로 판단된다.
# Dovish matches: ['해외', '위험요인', '성장', '경로'], Count: 4
# Hawkish matches: ['상승', '성장', '높'], Count: 3
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 채소류 등 농산물가격의 큰 폭 상승에 주로기인하여 지난달 4.7% 수준으로 높아졌다.
# Dovish matches: ['상승률', '농산물'], Count: 2
# Hawkish matches: ['상승', '높'], Count: 2
# Predicted: Neutral
#
# Sentence: 앞으로 경기상승기조에따른 수요압력, 인플레이션 기대심리 등으로 높은 수준의 물가상승률이 이어질 것으로 예상된다.
# Dovish matches: ['수요', '상승률'], Count: 2
# Hawkish matches: ['상승', '압력', '인플레이션', '높'], Count: 4
# Predicted: Hawkish
#
# Sentence: 근원인플레이션율은 3.8% 수준으로상승하였으며 당분간 오름세가 지속될 것으로 보인다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: ['상승'], Count: 1
# Predicted: Neutral
#
# Sentence: 주택매매가격은 수도권에서는 약세를, 지방에서는 전월과 비슷한 상승률을 나타내었다.
# Dovish matches: ['전월', '상승률'], Count: 2
# Hawkish matches: ['약세'], Count: 1
# ...
# Dovish matches: ['완만', '성장세', '내수', '회복'], Count: 4
# Hawkish matches: ['커진'], Count: 1
# Predicted: Dovish
#
# Sentence: 향후성장경로는 내수 회복 속도, 주요국 경기 및 IT 수출 흐름 등에 영향받을 것으로보인다.
# Dovish matches: ['성장', '경로', '내수', '회복', '수출'], Count: 5
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 국내 물가상승률은 안정세가 뚜렷해졌다.
# Dovish matches: ['상승률', '안정세'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 9월중 소비자물가 상승률이 석유류가격의 큰 폭 하락으로 1.6%로 낮아졌으며 근원물가 상승률(식료품 및 에너지 제외지수)은 2.0%로 둔화되었다.
# Dovish matches: ['상승률', '하락', '상승률', '둔화'], Count: 4
# Hawkish matches: ['졌으며', '에너지제외지수'], Count: 2
# Predicted: Dovish
#
# Sentence: 단기 기대인플레이션율도 2.8%로 낮아졌다.
# Dovish matches: [], Count: 0
# Hawkish matches: [], Count: 0
# Predicted: Neutral
#
# Sentence: 앞으로물가상승률은 낮은 수요압력으로 안정된 흐름을 이어갈 것으로 예상된다.
# Dovish matches: ['상승률', '수요', '안정'], Count: 3
# Hawkish matches: ['압력'], Count: 1
# Predicted: Dovish
#
# Sentence: 소비자물가 상승률은 당분간 2%를 하회하면서 금년 상승률이 지난 8월 전망치(2.5%)를 소폭 하회할 것으로 보이며, 근원물가 상승률은 2% 내외의 안정세가 이어지면서 금년 상승률이 지난 전망(2.2%)에 부합할 것으로 예상된다.
# Dovish matches: ['상승률', '하회', '상승률', '전망치', '하회', '상승률', '내외', '안정세', '상승률', '부합'], Count: 10
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 내년도 상승률은 소비자물가 및 근원물가 모두 지난 전망치(2.1% 및 2.0%)에 대체로 부합할 것으로 보이지만 중동지역 리스크의 전개양상에 따른 국제유가 변동, 환율 움직임,공공요금 조정 등과 관련한 불확실성이 높은 상황이다.
# Dovish matches: ['상승률', '전망치', '부합', '국제', '유가', '조정'], Count: 6
# Hawkish matches: ['양상', '환율', '움직임', '높'], Count: 4
# Predicted: Dovish
#
# Sentence: 금융‧외환시장에서는 국내외 통화정책에 대한 기대 변화에 따라 장기 국고채금리가 하락하였다 반등하였고 원/달러 환율은 미 달러화 흐름, 지정학적 리스크등에 영향받아 등락하였다.
# Dovish matches: ['금융', '하락'], Count: 2
# Hawkish matches: ['외환시장', '국고채', '달러화', '지정학'], Count: 4
# Predicted: Hawkish
#
# Sentence: 주택시장은 수도권에서는 가격 상승세가 둔화되고거래량도 축소되었으며 지방에서는 부진이 이어졌다.
# Dovish matches: ['둔화', '축소', '부진'], Count: 3
# Hawkish matches: ['거래량'], Count: 1
# Predicted: Dovish
#
# Sentence: 이에 따라 가계대출 증가규모도 상당폭 축소되었다.
# Dovish matches: ['가계', '증가', '상당폭', '축소'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경제는 물가상승률이 목표수준에서 안정되고 완만한 성장세를 이어갈 것으로 예상되지만 성장 전망경로의 불확실성이 증대되었다.
# Dovish matches: ['상승률', '안정', '완만', '성장세', '성장', '경로'], Count: 6
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융안정 측면에서는 수도권 주택가격과 가계부채 증가세가 거시건전성정책 강화의 영향으로 점차 둔화될 것으로 보이지만 기준금리 인하가 가계부채에 미치는영향 등 관련 리스크에 여전히 유의할 필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '증가세', '건전성', '강화', '점차', '둔화', '인하', '가계', '부채'], Count: 11
# Hawkish matches: ['기준금리', '인하'], Count: 2
# Predicted: Dovish
#
# Sentence: 따라서 향후 통화정책은 물가, 성장, 금융안정 등 정책변수 간 상충관계를 면밀히 점검하면서 앞으로의 인하 속도 등을 신중히 결정해 나갈 것이다.
# Dovish matches: ['성장', '금융안정', '상충관계', '면밀히', '점검', '인하'], Count: 6
# Hawkish matches: ['따라서', '성장', '인하', '결정'], Count: 4
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의3.25% 수준에서 3.00%로 하향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['하향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 환율 변동성이 확대되었지만, 물가상승률의 안정세와 가계부채의 둔화 흐름이 이어지는가운데 성장의 하방압력이 증대되었다.
# Dovish matches: ['상승률', '안정세', '가계', '부채', '둔화', '성장', '하방'], Count: 7
# Hawkish matches: ['환율', '성장', '압력'], Count: 3
# Predicted: Dovish
#
# Sentence: 세계경제는 미국 신정부의 경제정책 향방에 따른 경기 및 인플레이션의 불확실성이 증대되었다.
# Dovish matches: [], Count: 0
# Hawkish matches: ['인플레이션'], Count: 1
# Predicted: Hawkish
#
# Sentence: 국제금융시장에서는 주요국의 정책금리 인하 기조가 이어졌지만 미 장기 국채금리가 큰 폭 상승하고 달러화도 상당폭 강세를 나타내었다.
# Dovish matches: ['국제', '인하', '상당폭'], Count: 3
# Hawkish matches: ['인하', '국채', '상승', '달러화', '강세'], Count: 5
# Predicted: Hawkish
#
# Sentence: 국내경제는 내수 회복세가 완만한 가운데 수출 증가세가 둔화되면서 성장 흐름이 약화되었다.
# Dovish matches: ['내수', '회복세', '완만', '수출', '증가세', '둔화', '성장', '약화'], Count: 8
# Hawkish matches: ['성장'], Count: 1
# Predicted: Dovish
#
# Sentence: 고용은 실업률이 낮은 수준을 보이고 있지만 취업자수 증가규모는 점차 둔화되는 모습이다.
# Dovish matches: ['증가', '점차', '둔화'], Count: 3
# Hawkish matches: ['실업률'], Count: 1
# Predicted: Dovish
#
# Sentence: 앞으로도 국내경제는 소비가 완만한 회복세를 이어가겠으나 수출 증가세는 주력 업종에서의 경쟁 심화, 보호무역주의 강화 등으로당초 예상보다 낮아질 것으로 보인다.
# Dovish matches: ['소비', '완만', '회복세', '수출', '증가세', '주력업종', '심화', '강화', '보다'], Count: 9
# Hawkish matches: ['보호무역주의'], Count: 1
# Predicted: Dovish
#
# Sentence: 이에 따라 금년 및 내년 성장률이 각각지난 8월 전망치(2.4% 및 2.1%)를 하회하는 2.2% 및 1.9%를 나타낼 것으로 예상된다.
# Dovish matches: ['성장률', '전망치', '하회'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 다만 이러한 성장경로에는 통상환경 변화 및 IT 수출 흐름, 내수 회복 속도 등과 관련한 불확실성이 높은 상황이다.
# Dovish matches: ['성장', '경로', '통상', '환경변화', '수출', '내수', '회복'], Count: 7
# Hawkish matches: ['성장', '높'], Count: 2
# Predicted: Dovish
#
# Sentence: 국내 물가는 안정세를 지속하였다.
# Dovish matches: ['안정세', '지속'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 10월중 소비자물가 상승률이 석유류가격 하락에 따라 일시적으로 크게 낮아져 1.3%를 기록하였으며 근원물가 상승률(식료품및 에너지 제외 지수)도 1.8%로 둔화되었다.
# Dovish matches: ['상승률', '하락', '상승률', '둔화'], Count: 4
# Hawkish matches: ['크', '에너지제외지수'], Count: 2
# Predicted: Dovish
#
# Sentence: 단기 기대인플레이션율은 전월과 같은 수준(2.8%)을 유지하였다.
# Dovish matches: ['전월', '유지'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 물가상승률은 환율 상승이 상방압력으로 작용하겠지만 국제유가 하락, 낮은 수요압력 등으로 안정세를 이어갈 것으로 예상된다.
# Dovish matches: ['상승률', '국제', '유가', '하락', '수요', '안정세'], Count: 6
# Hawkish matches: ['환율', '상승', '압력', '압력'], Count: 4
# Predicted: Dovish
#
# Sentence: 이에 따라 금년 및 내년 소비자물가 상승률은 각각 2.3%, 1.9%로 지난 전망치(2.5%, 2.1%)를 하회할 전망이다.
# Dovish matches: ['상승률', '전망치', '하회'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 근원물가 상승률은 금년은 지난 전망에 부합하는 2.2%로, 내년은 지난 전망(2.0%)보다 소폭 낮은 1.9%로 예상된다.
# Dovish matches: ['상승률', '부합', '보다'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 향후 물가경로는 환율 및 국제유가 움직임, 국내외 경기 흐름, 공공요금 조정 등에 영향받을 것으로 보인다.
# Dovish matches: ['경로', '국제', '유가', '조정'], Count: 4
# Hawkish matches: ['환율', '움직임'], Count: 2
# Predicted: Dovish
#
# Sentence: 금융·외환시장에서는 국고채금리가 큰 폭 상승한 미 국채금리와 차별화된 움직임을 보이며 하락하였고 원/달러 환율은 미 달러화 강세에 영향받아 상당폭 상승하였다.
# Dovish matches: ['금융', '차별화', '하락', '상당폭'], Count: 4
# Hawkish matches: ['외환시장', '국고채', '상승', '한미', '국채', '움직임', '달러화', '강세', '상승'], Count: 9
# Predicted: Hawkish
#
# Sentence: 주가는 주요 기업의 실적 전망 둔화 등으로 하락하였다.
# Dovish matches: ['기업', '실적', '둔화', '하락'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 가계대출은 계절적 요인 등으로 증가규모가 소폭 확대되었지만 거시건전성정책의 영향이 이어지면서 주택관련대출을 중심으로 당분간 둔화 추세를 이어갈 것으로 판단된다.
# Dovish matches: ['가계', '증가', '건전성', '주택', '중심', '둔화', '추세'], Count: 7
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경제는 물가상승률이 안정되는 가운데 성장경로의 불확실성은 높은 것으로 판단된다.
# Dovish matches: ['상승률', '안정', '성장', '경로'], Count: 4
# Hawkish matches: ['성장', '높'], Count: 2
# Predicted: Dovish
#
# Sentence: 금융안정 측면에서는 가계부채 둔화 흐름이 당분간 이어질 것으로 예상되지만 환율이 높은 변동성을 나타낼 가능성에 유의할 필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '둔화'], Count: 4
# Hawkish matches: ['환율', '높'], Count: 2
# Predicted: Dovish
#
# Sentence: 따라서 향후 통화정책은 금리인하가 물가와 성장, 가계부채와 환율등 금융안정에 미치는 영향과 정책변수 간 상충관계를 면밀히 점검하면서 앞으로의 인하 속도 등을 결정해 나갈 것이다.
# Dovish matches: ['인하', '성장', '가계', '부채', '금융안정', '상충관계', '면밀히', '점검', '인하'], Count: 9
# Hawkish matches: ['따라서', '인하', '성장', '환율', '인하', '결정'], Count: 6
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의3.00% 수준에서 유지하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['유지', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 물가상승률 안정세와가계부채 둔화 흐름이 이어지는 가운데, 예상치 못한 정치적 리스크 확대로 성장의 하방위험이 커지고 환율 변동성이 증대되었다.
# Dovish matches: ['상승률', '안정세', '가계', '부채', '둔화', '성장', '하방', '위험'], Count: 8
# Hawkish matches: ['정치', '성장', '위험', '커지', '환율'], Count: 5
# Predicted: Dovish
#
# Sentence: 향후 국내 정치 상황과 주요국 경제정책의 변화에 따라 경제전망 및 외환시장의 불확실성이 커진 만큼 현재의 기준금리 수준을 유지하면서 대내외 여건 변화를 좀 더 점검하는 것이 적절하다고 판단하였다.
# Dovish matches: ['유지', '점검'], Count: 2
# Hawkish matches: ['정치', '외환시장', '커진', '만큼', '기준금리', '적절'], Count: 6
# Predicted: Hawkish
#
# Sentence: 이에 영향받아 국제금융시장에서는 미 달러화가강세 흐름을 지속하고 장기 국채금리가 상승하는 등 주요 가격변수의 변동성이확대되었다.
# Dovish matches: ['국제', '지속'], Count: 2
# Hawkish matches: ['달러화', '강세', '국채', '상승'], Count: 4
# Predicted: Hawkish
#
# Sentence: 앞으로 세계경제와 국제금융시장은 미국 신정부의 경제정책 추진양상, 주요국의 통화정책 및 정치 상황, 지정학적 리스크 등에 영향받을 것으로 보인다.
# Dovish matches: ['국제', '추진'], Count: 2
# Hawkish matches: ['양상', '정치', '지정학'], Count: 3
# Predicted: Hawkish
#
# Sentence: 국내경제는 12월중 수출 증가율이 다소 높아졌으나 소비 회복세가 약화되고 건설투자 부진이 이어졌다.
# Dovish matches: ['수출', '증가율', '소비', '회복세', '약화', '건설', '투자', '부진'], Count: 8
# Hawkish matches: ['높', '졌으나'], Count: 2
# Predicted: Dovish
#
# Sentence: 고용은 취업자수 증가규모가 줄어드는 등 둔화 흐름을이어갔다.
# Dovish matches: ['증가', '둔화'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경제는 수출 증가세가 둔화되고 소비심리 위축 등으로 내수 회복세가 예상보다 더딜 것으로 보인다.
# Dovish matches: ['수출', '증가세', '둔화', '소비', '위축', '내수', '회복세', '보다', '더딜'], Count: 9
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 지난해 및 금년 성장률은 11월 전망치(24년 2.2%, 25년 1.9%)를 하회할 가능성이 큰 것으로 보이며, 향후 성장경로에는 국내 정치 상황 변화, 정부의 경기대응책, 미 신정부의 정책방향 등과 관련한불확실성이 높은 상황이다.
# Dovish matches: ['지난해', '성장률', '전망치', '하회', '성장', '경로', '정부'], Count: 7
# Hawkish matches: ['성장', '정치', '높'], Count: 3
# Predicted: Dovish
#
# Sentence: 국내 물가는 안정세를 지속하였다.
# Dovish matches: ['안정세', '지속'], Count: 2
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 12월중 소비자물가 상승률이 석유류가격 상승등으로 1.9%로 높아졌지만 근원물가 상승률(식료품 및 에너지 제외 지수)은 1.8%로소폭 낮아졌다.
# Dovish matches: ['상승률', '상승률'], Count: 2
# Hawkish matches: ['상승', '높', '에너지제외지수'], Count: 3
# Predicted: Hawkish
#
# Sentence: 단기 기대인플레이션율은 2%대 후반 수준을 지속하였다.
# Dovish matches: ['지속'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융‧외환시장에서는 원/달러 환율이 국내 정치 불확실성 증대, 미 연준의 금리인하 속도 조절 가능성 등의 영향으로 큰 폭 상승하였다.
# Dovish matches: ['금융', '인하'], Count: 2
# Hawkish matches: ['외환시장', '정치', '미연준', '인하', '속도조절', '상승'], Count: 6
# Predicted: Hawkish
#
# Sentence: 주가는 상당폭 조정되었다가 금년 들어 반등하였고, 장기 국고채금리는 경기둔화 우려 등으로 하락하였다.
# Dovish matches: ['상당폭', '조정', '둔화', '하락'], Count: 4
# Hawkish matches: ['다가', '국고채', '우려'], Count: 3
# Predicted: Dovish
#
# Sentence: 가계대출은 주택거래 감소 등의 영향으로 둔화 추세를 지속하였으며 전국주택가격은 하락 전환하였다.
# Dovish matches: ['가계', '주택', '감소', '둔화', '추세', '지속', '전국', '하락', '전환'], Count: 9
# Hawkish matches: ['거래'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경제는 물가상승률이 안정적인 흐름을 이어가고 있으나정치적 리스크 확대로 성장의 하방위험이 증대되고 경제전망의 불확실성도 커진상황이다.
# Dovish matches: ['상승률', '안정', '성장', '하방', '위험'], Count: 5
# Hawkish matches: ['정치', '성장', '위험', '커진'], Count: 4
# Predicted: Dovish
#
# Sentence: 금융안정 측면에서는 가계부채 둔화 추세가 당분간 이어질 것으로 보이지만 환율 변동성 확대가 물가와 금융안정에 미치는 영향에 대해서는 유의할필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '둔화', '추세', '금융안정'], Count: 6
# Hawkish matches: ['환율'], Count: 1
# Predicted: Dovish
#
# Sentence: 따라서 향후 통화정책은 국내 정치 상황 및 대내외 경제정책 변화와 이에 따른 물가, 가계부채 및 환율의 흐름을 면밀히 점검하면서 성장의 하방리스크가 완화될 수 있도록 기준금리의 추가 인하 시기 및 속도 등을 결정해 나갈 것이다.
# Dovish matches: ['가계', '부채', '면밀히', '점검', '성장', '하방', '완화', '인하'], Count: 8
# Hawkish matches: ['따라서', '정치', '환율', '성장', '기준금리', '인하', '결정'], Count: 7
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 다음 통화정책방향 결정시까지 한국은행 기준금리를 현재의3.00% 수준에서 2.75%로 하향 조정하여 통화정책을 운용하기로 하였다.
# Dovish matches: ['하향조정', '운용'], Count: 2
# Hawkish matches: ['기준금리'], Count: 1
# Predicted: Dovish
#
# Sentence: 외환시장의 경계감이 여전하지만 물가상승률 안정세와 가계부채 둔화 흐름이 지속되는가운데 성장률이 크게 낮아질 것으로 전망되는 만큼 기준금리를 추가 인하하여경기 하방압력을 완화하는 것이 적절하다고 판단하였다.
# Dovish matches: ['상승률', '안정세', '가계', '부채', '둔화', '지속', '성장률', '인하', '하방', '완화'], Count: 10
# Hawkish matches: ['외환시장', '경계감', '여전', '크', '만큼', '기준금리', '인하', '압력', '적절'], Count: 9
# Predicted: Dovish
#
# Sentence: 세계경제는 미국 관세정책 등의 영향으로 성장의 하방위험이 확대되고 물가경로의 불확실성도 높아졌다.
# Dovish matches: ['성장', '하방', '위험', '경로'], Count: 4
# Hawkish matches: ['성장', '위험', '높'], Count: 3
# Predicted: Dovish
#
# Sentence: 국제금융시장에서는 그간 크게 확대되었던 미 신정부경제정책에 대한 우려가 다소 완화되고 러시아‧우크라이나 종전 가능성이 부각되면서 미 달러화 강세 흐름이 일부 되돌려지고 주요국의 장기 국채금리는 하락하였다.
# Dovish matches: ['국제', '완화', '하락'], Count: 3
# Hawkish matches: ['그간', '크', '우려', '러시아', '달러화', '강세', '국채'], Count: 7
# Predicted: Hawkish
#
# Sentence: 앞으로 세계경제와 국제금융시장은 미국의 관세정책 추진 상황, 주요국의 통화정책 변화, 지정학적 리스크 등에 영향받을 것으로 보인다.
# Dovish matches: ['국제', '추진'], Count: 2
# Hawkish matches: ['지정학'], Count: 1
# Predicted: Dovish
#
# Sentence: 국내 경제상황을 보면 비상계엄 사태에 따른 정치 불확실성 확대, 기상여건 악화 등으로 소비가 부진한 가운데 수출 증가세가 약화되었다.
# Dovish matches: ['기상', '악화', '소비', '부진', '수출', '증가세', '약화'], Count: 7
# Hawkish matches: ['비상계엄', '사태', '정치'], Count: 3
# Predicted: Dovish
#
# Sentence: 고용은 주요 업종의 취업자수 감소세가 이어지는 등 둔화 흐름을 지속하였다.
# Dovish matches: ['업종', '감소세', '둔화', '지속'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 국내경제는경제심리 위축, 미국의 관세정책 등의 영향으로 내수 회복세와 수출 증가세가당초 예상보다 낮을 것으로 예상된다.
# Dovish matches: ['위축', '내수', '회복세', '수출', '증가세', '보다'], Count: 6
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 이에 따라 금년 성장률은 지난 11월 전망치(1.9%)를 큰 폭 하회하는 1.5%로 전망된다.
# Dovish matches: ['성장률', '전망치', '하회'], Count: 3
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 단기 기대인플레이션율은 2월중 2.7%로 소폭 하락하였다.
# Dovish matches: ['하락'], Count: 1
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 앞으로 물가상승률은환율이 상방요인으로 작용하겠지만 낮은 수요압력 등의 영향으로 2% 내외의 안정적인 흐름을 지속할 것으로 보인다.
# Dovish matches: ['상승률', '수요', '내외', '안정', '지속'], Count: 5
# Hawkish matches: ['환율', '압력'], Count: 2
# Predicted: Dovish
#
# Sentence: 이에 따라 금년중 소비자물가 상승률은지난해 11월 전망(1.9%)에 부합하는 1.9%로 전망되며, 근원물가 상승률은 지난전망치(1.9%)를 소폭 하회하는 1.8%로 예상된다.
# Dovish matches: ['상승률', '지난해', '부합', '상승률', '전망치', '하회'], Count: 6
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 향후 물가경로는 환율 및 국제유가 움직임, 국내외 경기 흐름, 정부의 물가안정 대책 등에 영향받을 것으로 보인다.
# Dovish matches: ['경로', '국제', '유가', '정부', '안정'], Count: 5
# Hawkish matches: ['환율', '움직임'], Count: 2
# Predicted: Dovish
#
# Sentence: 금융·외환시장에서는 원/달러 환율이 국내 정치 불확실성, 미국의 관세정책 및연준 통화정책에 대한 기대 변화 등에 영향받으며 높은 변동성을 이어가다 하락하였다.
# Dovish matches: ['금융', '하락'], Count: 2
# Hawkish matches: ['외환시장', '정치', '연준', '높'], Count: 4
# Predicted: Hawkish
#
# Sentence: 주택가격은 서울을 제외한 대부분 지역에서 하락하였고 가계대출 증가규모도 둔화 추세를 이어갔다.
# Dovish matches: ['제외', '지역', '하락', '가계', '증가', '둔화', '추세'], Count: 7
# Hawkish matches: ['서울'], Count: 1
# Predicted: Dovish
#
# Sentence: 금융통화위원회는 앞으로 성장세를 점검하면서 중기적 시계에서 물가상승률이목표수준에서 안정될 수 있도록 하는 한편 금융안정에 유의하여 통화정책을 운용해 나갈 것이다.
# Dovish matches: ['성장세', '점검', '중기', '시계', '상승률', '안정', '금융안정', '운용'], Count: 8
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 국내경제는 물가상승률이 안정적인 흐름을 이어가는 가운데낮은 성장세가 당분간 지속될 것으로 전망된다.
# Dovish matches: ['상승률', '안정', '성장세', '지속'], Count: 4
# Hawkish matches: [], Count: 0
# Predicted: Dovish
#
# Sentence: 금융안정 측면에서는 가계부채둔화 추세가 이어질 것으로 보이지만 금리하락 기조로 인한 재확대 가능성과 높은 환율 변동성에는 유의할 필요가 있다.
# Dovish matches: ['금융안정', '가계', '부채', '둔화', '추세', '하락'], Count: 6
# Hawkish matches: ['높', '환율'], Count: 2
# Predicted: Dovish
#
# Sentence: 따라서 향후 통화정책은 대내외 경제정책 및 국내 정치 상황의 변화, 그간의 금리 인하가 물가, 성장 및 금융안정 상황에 미치는 영향 등을 면밀히 점검하면서 앞으로의 기준금리 추가 인하 시기및 속도 등을 결정해 나갈 것이다.
# Dovish matches: ['인하', '성장', '금융안정', '면밀히', '점검', '인하'], Count: 6
# Hawkish matches: ['따라서', '정치', '그간', '인하', '성장', '기준금리', '인하', '결정'], Count: 8
# Predicted: Hawkish
#
# 최종 예측 데이터 크기: 2239 문장
# 예측 라벨 클래스 분포:
# Predicted_Label
# Dovish     1915
# Hawkish     308
# Neutral      16
# Name: count, dtype: int64
# Sample 1: True=Dovish, Predicted=Dovish
# Sample 2: True=Dovish, Predicted=Dovish
# Sample 3: True=Dovish, Predicted=Dovish
# Sample 4: True=Dovish, Predicted=Dovish
# Sample 5: True=Dovish, Predicted=Dovish
# Sample 6: True=Dovish, Predicted=Dovish
# Sample 7: True=Dovish, Predicted=Dovish
# Sample 8: True=Dovish, Predicted=Dovish
# Sample 9: True=Dovish, Predicted=Dovish
# Sample 10: True=Dovish, Predicted=Dovish
#
# === 평가 결과 ===
# True Positives (TP): 1901
# True Negatives (TN): 304
# False Positives (FP): 14
# False Negatives (FN): 4
# 정확도 (Accuracy): 0.9919
# 정밀도 (Precision): 0.9870
# 재현율 (Recall): 0.9560
# F1 점수 (F1 Score): 0.9712
# 예측 결과 및 평가 지표가 'test_predictions_with_metrics.csv' 파일에 저장되었습니다.
